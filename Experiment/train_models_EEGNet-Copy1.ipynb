# %%
import os
import random
import torch
import numpy as np
import pickle as pkl
from analysis import *
import argparse
from sys import platform

# %%
torch.manual_seed(12)
torch.cuda.manual_seed(12)
np.random.seed(12)
torch.backends.cudnn.deterministics = True
torch.set_num_threads(1)

# %%
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.current_device())

print(torch.cuda.device(0))
print(torch.cuda.get_device_name(0))
# Out:
# True
# 1
# 0
# <torch.cuda.device object at 0x7fe8446e9190>
# NVIDIA TITAN V

# %%
# iv: image option
length = 512
channel = 96
min_CNN = 200
n_classes = 40
classes = range(n_classes)

# %%
if platform == "linux" or platform == "linux2":
    torch_models_dir = r"/media/titan/AI Research/Data/CVPR2021-02785/CVPR2021-02785/preprocessed/torch_models"
elif platform == "win32":
    torch_models_dir = r"D:\Data\CVPR2021-02785\CVPR2021-02785\preprocessed\torch_models"
eeg_dataset, splits_path, splits_60_percent, splits_shuffled_path = os.listdir(torch_models_dir)

# %%
eeg_dataset = os.path.join(torch_models_dir, eeg_dataset)
splits_path = os.path.join(torch_models_dir, splits_60_percent)
# splits_path = os.path.join(torch_models_dir, splits_shuffled_path)
print(eeg_dataset,'\n', splits_path)
# Out:
# /media/titan/AI Research/Data/CVPR2021-02785/CVPR2021-02785/preprocessed/torch_models/imagenet40-1000-1.pth
#  /media/titan/AI Research/Data/CVPR2021-02785/CVPR2021-02785/preprocessed/torch_models/imagenet40-1000-1_splits_60_percent.pth

# %%
opt = {
    # Dataset options
    "iv": "image",
    "offset": None,
    "results_file": "results.pkl",
    "subject": 0,
    "run": "none",
    "eeg_dataset": eeg_dataset,
    "splits_path": splits_path,
    "fold": 5,
    #Training options
    "batch_size": 16,
    "optim": "Adam",
    "learning_rate": 0.001,
    "learning_rate_decay_by": 0.5,
    "learning_rate_decay_every": 10,
    "epochs": 100,
    "GPUindex": 0,
    "kind":"incremental",
    #Backend options
    "no_cuda": False,
    "classifier": None
}
opt = argparse.Namespace(**opt)
print(opt.iv)
# Out:
# image

# %%
# %load_ext autoreload
# %autoreload 2
from torch.utils.data import DataLoader
from data_loader import EEGDataset, Splitter, SplitterWithData
from EEG_Encoder.LSTM import classifier_LSTM
from EEG_Encoder.CNN import classifier_CNN
from EEG_Encoder.EEGNet import classifier_EEGNet
from EEG_Encoder.SyncNet import classifier_SyncNet
from EEG_Encoder.EEGChannelNet import classifier_EEGChannelNet
from EEG_Encoder.net_generator import Classifier
from EEG_Encoder.net_trainer import net_trainer
from p_values import *
from torchinfo import summary

# %%
def load_dataset(iv,
             offset,
             eeg_dataset,
             splits_path,
             split_num, # (0-4) - 5 fold cross validation
             total,
             classes,
             classifier,
             batch_size,
             GPUindex,
             length, # 512
             channel, # 96
             min_CNN,
             opt,
             kind):        
    # Load dataset
    dataset = EEGDataset(iv, eeg_dataset, classifier, map_idx = None)
    print("DONE: LOAD DATASET")
    # Create loaders for LSTM/MLP/CNN/SCNN/EEGNet/SyncNet/EEGChannelNet
    if kind=="from-scratch":
        relabel = False
    if kind=="incremental":
        relabel = False
    if kind=="no-model-file":
        relabel = True
    splitter = {split: SplitterWithData(iv,
                    dataset,
                    splits_path,
                    classes,
                    split_num,
                    split,
                    relabel) for split in ["train", "val", "test"]}
    loaders = {split: DataLoader(
                        splitter[split],
                        batch_size = batch_size,
                        drop_last = False,
                        shuffle = True)
                    for split in ["train", "val", "test"]}
    channel_idx = None    
    print("DONE: Create loaders for model")            
    return dataset, loaders, splitter

# %%
# EEGNet network
opt.classifier = "EEGNet"
opt.batch_size = 16
opt.kind = "from-scratch"
opt.run = "imagenet40-1000"
opt.fold = 5

# %%
dataset, loaders, splitter = load_dataset(opt.iv,
                             opt.offset,
                             opt.eeg_dataset,
                             opt.splits_path,
                             0, #split_num
                             n_classes,
                             classes,
                             opt.classifier,
                             opt.batch_size,
                             opt.GPUindex,
                             length,
                             channel,
                             min_CNN,
                             opt,
                             opt.kind)
# Out:
# DONE: LOAD DATASET
# DONE: Create loaders for model

# %%
# loaders: divide the splits data in each fold with batch_size
# Each fold has {train: 32000 idx, val: 4000 idx, test: 4000 idx}
# Each loader batch has {train: 2000 idx, val: 250idx, test: 250 idx}
print(type(dataset))
print(type(loaders))
print(len(loaders), [len(loaders[name]) for name in ["train", "val", "test"] ])
for i in range(0, 40):
    eeg, label_val = splitter["val"][i*100]
    eeg, label_train = splitter["train"][i*800]
    print(f"{i+1}: Label val: {label_val}; label train: {label_train}")
# print(splitter["val"].split_idx[:10])
# Out:
# <class 'data_loader.EEGDataset'>
# <class 'dict'>
# 3 [1200, 150, 150]
# 1: Label val: 34; label train: 28
# 2: Label val: 0; label train: 23
# 3: Label val: 20; label train: 35
# 4: Label val: 31; label train: 26
# 5: Label val: 27; label train: 38
# 6: Label val: 21; label train: 6
# 7: Label val: 20; label train: 12
# 8: Label val: 4; label train: 30
# 9: Label val: 22; label train: 39
# 10: Label val: 20; label train: 2
# 11: Label val: 0; label train: 7
# 12: Label val: 11; label train: 35
# 13: Label val: 29; label train: 38
# 14: Label val: 9; label train: 14
# 15: Label val: 36; label train: 0
# 16: Label val: 31; label train: 9
# 17: Label val: 33; label train: 27
# 18: Label val: 3; label train: 22
# 19: Label val: 21; label train: 16
# 20: Label val: 4; label train: 38
# 21: Label val: 32; label train: 13
# 22: Label val: 31; label train: 36
# 23: Label val: 26; label train: 27
# 24: Label val: 9; label train: 30
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 8
#       6 print(len(loaders), [len(loaders[name]) for name in ["train", "val", "test"] ])
#       7 for i in range(0, 40):
# ----> 8     eeg, label_val = splitter["val"][i*100]
#       9     eeg, label_train = splitter["train"][i*800]
#      10     print(f"{i+1}: Label val: {label_val}; label train: {label_train}")
#
# File ~/GithubClonedRepo/EEG-Research/Experiment/data_loader.py:69, in SplitterWithData.__getitem__(self, i)
#      67 def __getitem__(self, i):
#      68     # Get sample from dataset
# ---> 69     eeg, label = self.dataset[self.split_idx[i]]
#      70     if self.relabel:
#      71         label = self.classes.index(label)
#
# IndexError: list index out of range

# %%
net, nonclasses = Classifier(
                 n_classes,
                 classes,
                 opt.classifier,
                 opt.GPUindex,
                 length,
                 channel,
                 min_CNN,
                 opt.kind)
# print(len(nonclasses))
summary(net, input_size=(1,96, 512))
# Out:
# DONE: CREATE TORCH CLASSIFIER
# classifier_EEGNet(
#   (network): Sequential(
#     (0): ZeroPad2d((128, 127, 0, 0))
#     (1): Conv2d(1, 8, kernel_size=(1, 256), stride=(1, 1))
#     (2): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(8, 16, kernel_size=(96, 1), stride=(1, 1), groups=8)
#     (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ELU(alpha=1.0)
#     (6): AvgPool2d(kernel_size=(1, 4), stride=(1, 4), padding=0)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): ZeroPad2d((8, 7, 0, 0))
#     (9): Conv2d(16, 16, kernel_size=(1, 16), stride=(1, 1), groups=8)
#     (10): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1))
#     (11): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ELU(alpha=1.0)
#     (13): AvgPool2d(kernel_size=(1, 8), stride=(1, 8), padding=0)
#     (14): Dropout(p=0.5, inplace=False)
#   )
#   (fc): Linear(in_features=256, out_features=40, bias=True)
# )
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# classifier_EEGNet                        [1, 40]                   --
# ├─Sequential: 1-1                        [1, 16, 1, 16]            --
# │    └─ZeroPad2d: 2-1                    [1, 1, 96, 767]           --
# │    └─Conv2d: 2-2                       [1, 8, 96, 512]           2,056
# │    └─BatchNorm2d: 2-3                  [1, 8, 96, 512]           16
# │    └─Conv2d: 2-4                       [1, 16, 1, 512]           1,552
# │    └─BatchNorm2d: 2-5                  [1, 16, 1, 512]           32
# │    └─ELU: 2-6                          [1, 16, 1, 512]           --
# │    └─AvgPool2d: 2-7                    [1, 16, 1, 128]           --
# │    └─Dropout: 2-8                      [1, 16, 1, 128]           --
# │    └─ZeroPad2d: 2-9                    [1, 16, 1, 143]           --
# │    └─Conv2d: 2-10                      [1, 16, 1, 128]           528
# │    └─Conv2d: 2-11                      [1, 16, 1, 128]           272
# │    └─BatchNorm2d: 2-12                 [1, 16, 1, 128]           32
# │    └─ELU: 2-13                         [1, 16, 1, 128]           --
# │    └─AvgPool2d: 2-14                   [1, 16, 1, 16]            --
# │    └─Dropout: 2-15                     [1, 16, 1, 16]            --
# ├─Linear: 1-2                            [1, 40]                   10,280
# ==========================================================================================
# Total params: 14,768
# Trainable params: 14,768
# Non-trainable params: 0
# Total mult-adds (M): 101.96
# ==========================================================================================
# Input size (MB): 0.20
# Forward/backward pass size (MB): 6.47
# Params size (MB): 0.06
# Estimated Total Size (MB): 6.73
# ==========================================================================================

# %%
model_path = (opt.iv+
                  "-"+
                  opt.classifier+
                  "-"+
                  str(length)+
                  "-"+
                  str(channel)+
                  "-"+
                  str(0)) + "-noshuffle"
                  
channel_idx=None
print(model_path)
# Out:
# image-EEGNet-512-96-0-noshuffle

# %%
print(opt)
# Out:
# Namespace(iv='image', offset=None, results_file='results.pkl', subject=0, run='imagenet40-1000', eeg_dataset='/media/titan/AI Research/Data/CVPR2021-02785/CVPR2021-02785/preprocessed/torch_models/imagenet40-1000-1.pth', splits_path='/media/titan/AI Research/Data/CVPR2021-02785/CVPR2021-02785/preprocessed/torch_models/imagenet40-1000-1_splits_60_percent.pth', fold=5, batch_size=16, optim='Adam', learning_rate=0.001, learning_rate_decay_by=0.5, learning_rate_decay_every=10, epochs=100, GPUindex=0, kind='from-scratch', no_cuda=False, classifier='EEGNet')

# %%
if opt.kind=="from-scratch":
    loss_history, accuracy_val, accuracy_test = net_trainer(
            net,
            loaders,
            opt,
            channel_idx,
            nonclasses,
            None,
            True,
            model_path)
# Out:
# epoch 1
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.658728837966919; accuracy=0.026187501847743988
# epoch 2
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.5851898193359375; accuracy=0.029500002041459084
# epoch 3
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.6860435009002686; accuracy=0.036375001072883606
# epoch 4
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.7239606380462646; accuracy=0.04125000163912773
# epoch 5
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.687072277069092; accuracy=0.048875004053115845
# epoch 6
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.6465988159179688; accuracy=0.05250000208616257
# epoch 7
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.6315226554870605; accuracy=0.04975000396370888
# epoch 8
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.681751012802124; accuracy=0.05431250110268593
# epoch 9
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.8002872467041016; accuracy=0.05518750101327896
# epoch 10
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.7081093788146973; accuracy=0.05568750202655792
# epoch 11
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.5265743732452393; accuracy=0.05806250125169754
# epoch 12
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.510892629623413; accuracy=0.05612500384449959
# epoch 13
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.6985244750976562; accuracy=0.05881250277161598
# epoch 14
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.486410617828369; accuracy=0.06300000101327896
# epoch 15
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.5225257873535156; accuracy=0.06343750655651093
# epoch 16
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.482449531555176; accuracy=0.06181250140070915
# epoch 17
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.627398729324341; accuracy=0.06606250256299973
# epoch 18
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.7735936641693115; accuracy=0.06462500244379044
# epoch 19
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.3629953861236572; accuracy=0.061125002801418304
# epoch 20
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.6635985374450684; accuracy=0.06468750536441803
# epoch 21
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.3872876167297363; accuracy=0.06531250476837158
# epoch 22
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.6905012130737305; accuracy=0.06206250190734863
# epoch 23
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.6065618991851807; accuracy=0.06456249952316284
# epoch 24
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.449523687362671; accuracy=0.0663125067949295
# epoch 25
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.5255424976348877; accuracy=0.06550000607967377
# epoch 26
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.670607089996338; accuracy=0.0663125067949295
# epoch 27
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.3521323204040527; accuracy=0.0663125067949295
# epoch 28
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.341367244720459; accuracy=0.06825000047683716
# epoch 29
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.5261056423187256; accuracy=0.0690000057220459
# epoch 30
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.6485931873321533; accuracy=0.06931250542402267
# epoch 31
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.844844341278076; accuracy=0.06950000673532486
# epoch 32
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.4326577186584473; accuracy=0.0703750029206276
# epoch 33
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.658804178237915; accuracy=0.07087500393390656
# epoch 34
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.4799184799194336; accuracy=0.07456250488758087
# epoch 35
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.62870454788208; accuracy=0.0703125
# epoch 36
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.597630262374878; accuracy=0.07081250101327896
# epoch 37
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.4926867485046387; accuracy=0.07175000011920929
# epoch 38
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.4290425777435303; accuracy=0.06993750482797623
# epoch 39
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.512688636779785; accuracy=0.0728125050663948
# epoch 40
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.5196611881256104; accuracy=0.06956250220537186
# epoch 41
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.484018564224243; accuracy=0.07100000232458115
# epoch 42
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.431537628173828; accuracy=0.0728125050663948
# epoch 43
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.494246006011963; accuracy=0.07593750208616257
# epoch 44
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.459360122680664; accuracy=0.07312500476837158
# epoch 45
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.6114649772644043; accuracy=0.07250000536441803
# epoch 46
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.8433804512023926; accuracy=0.0728125050663948
# epoch 47
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.4122095108032227; accuracy=0.07468750327825546
# epoch 48
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.5403637886047363; accuracy=0.0755000039935112
# epoch 49
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.509439468383789; accuracy=0.07443750649690628
# epoch 50
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.265604257583618; accuracy=0.06975000351667404
# epoch 51
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.603252649307251; accuracy=0.07387500256299973
# epoch 52
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.3512516021728516; accuracy=0.07375000417232513
# epoch 53
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.3310940265655518; accuracy=0.07481250166893005
# epoch 54
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.535778760910034; accuracy=0.0754375010728836
# epoch 55
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.540297746658325; accuracy=0.07462500035762787
# epoch 56
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.434115171432495; accuracy=0.07531250268220901
# epoch 57
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.500523567199707; accuracy=0.07400000095367432
# epoch 58
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.7408950328826904; accuracy=0.07481250166893005
# epoch 59
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.5714259147644043; accuracy=0.0755000039935112
# epoch 60
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.655559539794922; accuracy=0.0794375017285347
# epoch 61
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.625504732131958; accuracy=0.07406250387430191
# epoch 62
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.687854290008545; accuracy=0.07568750530481339
# epoch 63
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.6104795932769775; accuracy=0.07862500101327896
# epoch 64
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.7532641887664795; accuracy=0.07750000059604645
# epoch 65
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.4947457313537598; accuracy=0.07700000703334808
# epoch 66
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.6206438541412354; accuracy=0.07787500321865082
# epoch 67
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.489129066467285; accuracy=0.0781875029206276
# epoch 68
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.624258279800415; accuracy=0.07450000196695328
# epoch 69
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.412217378616333; accuracy=0.07318750023841858
# epoch 70
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.683838367462158; accuracy=0.07512500137090683
# epoch 71
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.5635650157928467; accuracy=0.07637500017881393
# epoch 72
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.581113815307617; accuracy=0.07306250184774399
# epoch 73
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.740847110748291; accuracy=0.07693750411272049
# epoch 74
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.404601573944092; accuracy=0.07656250149011612
# epoch 75
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.4067938327789307; accuracy=0.08181250095367432
# epoch 76
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.464332342147827; accuracy=0.07862500101327896
# epoch 77
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.2509121894836426; accuracy=0.07768750190734863
# epoch 78
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.693193197250366; accuracy=0.07750000059604645
# epoch 79
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.420579433441162; accuracy=0.07718750089406967
# epoch 80
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.480360269546509; accuracy=0.07518750429153442
# epoch 81
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.2583112716674805; accuracy=0.07787500321865082
# epoch 82
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.5148425102233887; accuracy=0.0794375017285347
# epoch 83
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.822352647781372; accuracy=0.078125
# epoch 84
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.5929155349731445; accuracy=0.08043750375509262
# epoch 85
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.3522114753723145; accuracy=0.07912500202655792
# epoch 86
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.685443878173828; accuracy=0.07468750327825546
# epoch 87
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.26845645904541; accuracy=0.07431250065565109
# epoch 88
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.2728939056396484; accuracy=0.07731250673532486
# epoch 89
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.384922981262207; accuracy=0.07900000363588333
# epoch 90
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.8451263904571533; accuracy=0.07887500524520874
# epoch 91
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.478355646133423; accuracy=0.07712500542402267
# epoch 92
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.4938852787017822; accuracy=0.08087500184774399
# epoch 93
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.4741156101226807; accuracy=0.08175000548362732
# epoch 94
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.2704453468322754; accuracy=0.07493750005960464
# epoch 95
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.6157875061035156; accuracy=0.08037500083446503
# epoch 96
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.5435667037963867; accuracy=0.07793750613927841
# epoch 97
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.493708610534668; accuracy=0.07893750071525574
# epoch 98
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.4770750999450684; accuracy=0.08100000023841858
# epoch 99
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.789865493774414; accuracy=0.0755625069141388
# epoch 100
# Size of input:  torch.Size([16, 96, 512])
# Size of target:  torch.Size([16])
# Size of output:  torch.Size([16, 40])
# Batch 1000: Loss=3.4299213886260986; accuracy=0.08112500607967377

# %%
val =accuracy_val
test = accuracy_test

print("Validation accuracy: ", val)
print("Test accuracy: ", test)
# Out:
# Validation accuracy:  0.04416666924953461
# Test accuracy:  0

# %%
print(accuracy_val)
