# %%
import os
import random
import torch
import numpy as np
import pickle as pkl
from analysis import *
import argparse
from sys import platform

# %%
torch.manual_seed(12)
torch.cuda.manual_seed(12)
np.random.seed(12)
torch.backends.cudnn.deterministics = True
torch.set_num_threads(1)

# %%
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.current_device())


print(torch.cuda.device(0))
print(torch.cuda.get_device_name(0))
# Out:
# True
# 1
# 0
# <torch.cuda.device object at 0x7f2b6020cd60>
# NVIDIA TITAN V

# %%
# iv: image option
length = 440
channel = 128
min_CNN = 200
n_classes = 40
classes = range(n_classes)

# %%
if platform == "linux" or platform == "linux2":
    torch_models_dir = r"/media/titan/AI Research1/Data/CVPR2017"
elif platform == "win32":
    torch_models_dir = r"D:\Data\CVPR2021-02785\CVPR2021-02785\preprocessed\torch_models"
block_splits_all, block_splits_single, eeg_14_70, eeg_55_95, eeg_5_95, eeg_raw = os.listdir(torch_models_dir)
print(os.listdir(torch_models_dir))
# Out:
# ['block_splits_by_image_all.pth', 'block_splits_by_image_single.pth', 'eeg_14_70_std.pth', 'eeg_55_95_std.pth', 'eeg_5_95_std.pth', 'eeg_signals_raw_with_mean_std.pth']

# %%
eeg_dataset = os.path.join(torch_models_dir, eeg_5_95)
splits_all_path = os.path.join(torch_models_dir, block_splits_all)
splits_single_path = os.path.join(torch_models_dir, block_splits_single)
# splits_path = os.path.join(torch_models_dir, splits_shuffled_path)
print(eeg_dataset,'\n', splits_all_path, '\n', splits_single_path)
# Out:
# /media/titan/AI Research1/Data/CVPR2017/eeg_5_95_std.pth
#  /media/titan/AI Research1/Data/CVPR2017/block_splits_by_image_all.pth
#  /media/titan/AI Research1/Data/CVPR2017/block_splits_by_image_single.pth

# %%
splits_all = torch.load(splits_all_path)
splits_single = torch.load(splits_single_path)

# %%
print(len(splits_all['splits']))
print(len(splits_all['splits'][0]))

print(len(splits_all['splits'][5]['train']))
print(len(splits_all['splits'][5]['val']))
print(len(splits_all['splits'][5]['test']))
print(splits_all['splits'][0]['train'][:40])
print(splits_all['splits'][1]['train'][:40])
print(splits_all['splits'][2]['train'][:10])
print(splits_all['splits'][3]['train'][:10])
# Out:
# 6
# 3
# 7984
# 1996
# 1985
# [0, 3, 4, 5, 6, 8, 9, 10, 11, 12, 13, 15, 16, 17, 18, 19, 21, 22, 23, 24, 25, 27, 29, 33, 35, 36, 37, 38, 39, 42, 43, 44, 45, 46, 47, 48, 51, 52, 54, 55]
# [1, 2, 3, 4, 6, 8, 9, 12, 13, 20, 25, 26, 27, 28, 30, 32, 33, 35, 37, 38, 39, 40, 44, 45, 46, 50, 52, 54, 56, 58, 59, 60, 62, 65, 68, 72, 73, 74, 76, 81]
# [2, 3, 4, 5, 6, 7, 8, 10, 11, 13]
# [1, 2, 4, 7, 9, 10, 12, 13, 14, 15]

# %%
# print(splits_single)
print(len(splits_single['splits'][0]['train']))
print(len(splits_single['splits'][0]['val']))
print(len(splits_single['splits'][0]['test']))
# Out:
# 669
# 167
# 164

# %%
eeg_loaded = torch.load(eeg_dataset)

# %%
print(len(eeg_loaded))
print(eeg_loaded.keys())
dataset, labels, images = [eeg_loaded[k] for k in eeg_loaded.keys()]
print(len(labels))
print(len(images))
print(len(dataset))

print(labels)
print(images[0])
print(dataset[0]['eeg'].shape)
print(dataset[0])
# Out:
# 3
# dict_keys(['dataset', 'labels', 'images'])
# 40
# 1996
# 11965
# ['n02389026', 'n03888257', 'n03584829', 'n02607072', 'n03297495', 'n03063599', 'n03792782', 'n04086273', 'n02510455', 'n11939491', 'n02951358', 'n02281787', 'n02106662', 'n04120489', 'n03590841', 'n02992529', 'n03445777', 'n03180011', 'n02906734', 'n07873807', 'n03773504', 'n02492035', 'n03982430', 'n03709823', 'n03100240', 'n03376595', 'n03877472', 'n03775071', 'n03272010', 'n04069434', 'n03452741', 'n03792972', 'n07753592', 'n13054560', 'n03197337', 'n02504458', 'n02690373', 'n03272562', 'n04044716', 'n02124075']
# n02951358_31190
# torch.Size([128, 500])
# {'eeg': tensor([[-0.0098,  0.0195,  0.0620,  ...,  0.0638,  0.0120, -0.0118],
#         [-0.0045,  0.1303,  0.2673,  ...,  0.0894,  0.0342, -0.0082],
#         [ 0.0215, -0.2017, -0.4305,  ..., -0.2022, -0.0940,  0.0188],
#         ...,
#         [ 0.0160,  0.0707,  0.1005,  ...,  0.2066,  0.1156,  0.0036],
#         [-0.0046, -0.0084, -0.0119,  ...,  0.0007, -0.0026, -0.0053],
#         [ 0.0040,  0.0419,  0.0665,  ...,  0.0765,  0.0309, -0.0063]]), 'image': 0, 'label': 10, 'subject': 4}

# %%
opt = {
    # Dataset options
#     "iv": "image",
#     "offset": None,
    "results_file": "results.pkl",
    "subject": 0,
    "time_low": 20,
    "time_high": 460,
#     "run": "none",
    "eeg_dataset": eeg_dataset,
    "model_type": "model10",
    "splits_path": splits_all_path,
    "split_num": 0,
    "split_name": "train",
#     "fold": 5,
    #Training options
    "batch_size": 16,
    "optim": "Adam",
    "learning_rate": 0.001,
    "learning_rate_decay_by": 0.5,
    "learning_rate_decay_every": 10,
    "epochs": 100,
    "GPUindex": 0,
    "kind":"from-scratch",
    #Backend options
    "no_cuda": False,
    "classifier": None
}
opt = argparse.Namespace(**opt)
print(opt.time_low)
# Out:
# 20

# %%
# %load_ext autoreload
# %autoreload 2
from torch.utils.data import DataLoader
# from data_loader import EEGDataset, Splitter, SplitterWithData
from data_loader_CVPR2017 import EEGDataset, Splitter
from EEG_Encoder.LSTM import classifier_LSTM
from EEG_Encoder.CNN import classifier_CNN
from EEG_Encoder.EEGNet import classifier_EEGNet
from EEG_Encoder.SyncNet import classifier_SyncNet
from EEG_Encoder.EEGChannelNet import classifier_EEGChannelNet
from EEG_Encoder.net_generator import Classifier
from EEG_Encoder.net_trainer import net_trainer
import matplotlib.pyplot as plt
from p_values import *
from torchinfo import summary

# %%
def load_dataset(
#              offset,
             eeg_dataset,
             splits_path,
             split_num, # (0-5) - 6 fold cross validation
             split_name,
#              total, 
#              classes,
#              classifier,
             batch_size,
#              GPUindex,
#              length, # 500
#              channel, # 128
#              min_CNN,
             opt,
             kind="from-scratch"):        
    # Load dataset
    dataset = EEGDataset(opt, eeg_dataset)
    print("DONE: LOAD DATASET")
#     # Create loaders for LSTM/MLP/CNN/SCNN/EEGNet/SyncNet/EEGChannelNet
#     if kind=="from-scratch":
#         relabel = False
#     if kind=="incremental":
#         relabel = False
#     if kind=="no-model-file":
#         relabel = True
    splitter = {split: Splitter(dataset,
                    splits_path,
                    split_num,
                    split_name = split) for split in ["train", "val", "test"]}
    loaders = {split: DataLoader(
                        splitter[split],
                        batch_size = batch_size,
                        drop_last = False,
                        shuffle = True)
                    for split in ["train", "val", "test"]}
    channel_idx = None    
    print("DONE: Create loaders for model")            
    return dataset, loaders, splitter

# %%
# Options
opt.classifier = "EEGChannelNet"
opt.batch_size = 16
# opt.kind = "from-scratch"
# opt.run = "imagenet40-1000"
# opt.fold = 5

# %%
dataset, loaders, splitter = load_dataset(
#              offset,
             opt.eeg_dataset,
             opt.splits_path,
             opt.split_num, # (0-5) - 6 fold cross validation
             opt.split_name,
#              total, 
#              classes,
#              classifier,
             opt.batch_size,
#              GPUindex,
#              length, # 500
#              channel, # 128
#              min_CNN,
             opt,
             opt.kind)
# Out:
# DONE: LOAD DATASET
# DONE: Create loaders for model

# %%
# loaders: divide the splits data in each fold with batch_size
# Each fold has {train: 8000 idx, val: 2000 idx, test: 2000 idx}
# Each loader batch has {train: 2000 idx, val: 250 idx, test: 250 idx}
print(type(dataset))
print(type(loaders))
print(len(loaders), [len(loaders[name]) for name in ["train", "val", "test"] ])
for i, (input, target) in enumerate(loaders["train"]):
    if i<20:
        print(f"{i+1}: Target size: {target.size()}; input size: {input.size()}")
for i in range(0, 40):
    eeg, label_val = splitter["val"][i]
    eeg, label_train = splitter["train"][i]
    print(f"{i+1}: Label val: {label_val}; label train: {label_train}")
# Out:
# <class 'data_loader_CVPR2017.EEGDataset'>
# <class 'dict'>
# 3 [498, 125, 125]
# 1: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 2: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 3: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 4: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 5: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 6: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 7: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 8: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 9: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 10: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 11: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 12: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 13: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 14: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 15: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 16: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 17: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 18: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 19: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 20: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 1: Label val: 37; label train: 10
# 2: Label val: 38; label train: 10
# 3: Label val: 11; label train: 30
# 4: Label val: 10; label train: 25
# 5: Label val: 7; label train: 18
# 6: Label val: 35; label train: 3
# 7: Label val: 13; label train: 8
# 8: Label val: 2; label train: 11
# 9: Label val: 14; label train: 18
# 10: Label val: 2; label train: 28
# 11: Label val: 33; label train: 38
# 12: Label val: 26; label train: 20
# 13: Label val: 34; label train: 3
# 14: Label val: 18; label train: 28
# 15: Label val: 11; label train: 23
# 16: Label val: 32; label train: 0
# 17: Label val: 6; label train: 34
# 18: Label val: 22; label train: 20
# 19: Label val: 24; label train: 23
# 20: Label val: 24; label train: 39
# 21: Label val: 29; label train: 0
# 22: Label val: 3; label train: 34
# 23: Label val: 25; label train: 21
# 24: Label val: 11; label train: 39
# 25: Label val: 22; label train: 6
# 26: Label val: 36; label train: 26
# 27: Label val: 30; label train: 20
# 28: Label val: 32; label train: 1
# 29: Label val: 22; label train: 27
# 30: Label val: 39; label train: 37
# 31: Label val: 23; label train: 19
# 32: Label val: 4; label train: 9
# 33: Label val: 10; label train: 12
# 34: Label val: 3; label train: 18
# 35: Label val: 24; label train: 25
# 36: Label val: 27; label train: 27
# 37: Label val: 20; label train: 34
# 38: Label val: 1; label train: 35
# 39: Label val: 38; label train: 8
# 40: Label val: 15; label train: 29

# %%
net, nonclasses = Classifier(
                 n_classes,
                 classes,
                 opt.classifier,
                 opt.GPUindex,
                 length,
                 channel,
                 min_CNN,
                 opt.kind)
# print(len(nonclasses))
summary(net, input_size =(1,128, 440))
# Out:
# [W NNPACK.cpp:53] Could not initialize NNPACK! Reason: Unsupported hardware.
# DONE: CREATE TORCH CLASSIFIER
# classifier_EEGChannelNet(
#   (encoder): FeaturesExtractor(
#     (temporal_block): TemporalBlock(
#       (layers): ModuleList(
#         (0): ConvLayer2D(
#           (norm): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(1, 10, kernel_size=(1, 33), stride=(1, 2), padding=(0, 16))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#         (1): ConvLayer2D(
#           (norm): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(1, 10, kernel_size=(1, 33), stride=(1, 2), padding=(0, 32), dilation=(1, 2))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#         (2): ConvLayer2D(
#           (norm): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(1, 10, kernel_size=(1, 33), stride=(1, 2), padding=(0, 64), dilation=(1, 4))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#         (3): ConvLayer2D(
#           (norm): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(1, 10, kernel_size=(1, 33), stride=(1, 2), padding=(0, 128), dilation=(1, 8))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#       )
#     )
#     (spatial_block): SpatialBlock(
#       (layers): ModuleList(
#         (0): ConvLayer2D(
#           (norm): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(40, 50, kernel_size=(128, 1), stride=(2, 1), padding=(63, 0))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#         (1): ConvLayer2D(
#           (norm): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(40, 50, kernel_size=(64, 1), stride=(2, 1), padding=(31, 0))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#         (2): ConvLayer2D(
#           (norm): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(40, 50, kernel_size=(42, 1), stride=(2, 1), padding=(20, 0))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#         (3): ConvLayer2D(
#           (norm): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(40, 50, kernel_size=(32, 1), stride=(2, 1), padding=(15, 0))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#       )
#     )
#     (res_blocks): ModuleList(
#       (0): Sequential(
#         (0): ResidualBlock(
#           (conv1): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvLayer2D(
#           (norm): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(200, 200, kernel_size=(3, 3), stride=(2, 2))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#       )
#       (1): Sequential(
#         (0): ResidualBlock(
#           (conv1): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvLayer2D(
#           (norm): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(200, 200, kernel_size=(3, 3), stride=(2, 2))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#       )
#       (2): Sequential(
#         (0): ResidualBlock(
#           (conv1): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvLayer2D(
#           (norm): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(200, 200, kernel_size=(3, 3), stride=(2, 2))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#       )
#       (3): Sequential(
#         (0): ResidualBlock(
#           (conv1): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvLayer2D(
#           (norm): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(200, 200, kernel_size=(3, 3), stride=(2, 2))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#       )
#     )
#     (final_conv): ConvLayer2D(
#       (norm): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(200, 50, kernel_size=(3, 3), stride=(1, 1))
#       (drop): Dropout2d(p=0.2, inplace=False)
#     )
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=500, out_features=1000, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=1000, out_features=40, bias=True)
#   )
# )
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# classifier_EEGChannelNet                      [1, 40]                   --
# ├─FeaturesExtractor: 1-1                      [1, 50, 1, 10]            --
# │    └─TemporalBlock: 2-1                     [1, 40, 128, 220]         --
# │    │    └─ModuleList: 3-1                   --                        1,368
# │    └─SpatialBlock: 2-2                      [1, 200, 64, 220]         --
# │    │    └─ModuleList: 3-2                   --                        532,520
# │    └─ModuleList: 2-3                        --                        --
# │    │    └─Sequential: 3-3                   [1, 200, 31, 109]         1,081,400
# │    │    └─Sequential: 3-4                   [1, 200, 15, 54]          1,081,400
# │    │    └─Sequential: 3-5                   [1, 200, 7, 26]           1,081,400
# │    │    └─Sequential: 3-6                   [1, 200, 3, 12]           1,081,400
# │    └─ConvLayer2D: 2-4                       [1, 50, 1, 10]            --
# │    │    └─BatchNorm2d: 3-7                  [1, 200, 3, 12]           400
# │    │    └─ReLU: 3-8                         [1, 200, 3, 12]           --
# │    │    └─Conv2d: 3-9                       [1, 50, 1, 10]            90,050
# │    │    └─Dropout2d: 3-10                   [1, 50, 1, 10]            --
# ├─Sequential: 1-2                             [1, 40]                   --
# │    └─Linear: 2-5                            [1, 1000]                 501,000
# │    └─ReLU: 2-6                              [1, 1000]                 --
# │    └─Linear: 2-7                            [1, 40]                   40,040
# ===============================================================================================
# Total params: 5,490,978
# Trainable params: 5,490,978
# Non-trainable params: 0
# Total mult-adds (G): 22.41
# ===============================================================================================
# Input size (MB): 0.23
# Forward/backward pass size (MB): 224.12
# Params size (MB): 21.96
# Estimated Total Size (MB): 246.30
# ===============================================================================================

# %%
model_path = (   opt.classifier+
                  "-"+
                  str(length)+
                  "-"+
                  str(channel) )
results_path = (  "results_"+ opt.classifier+
                  "-"+
                  str(length)+
                  "-"+
                  str(channel) )
print(model_path)
print(results_path)
# Out:
# EEGChannelNet-440-128
# results_EEGChannelNet-440-128

# %%
print(opt)
# Out:
# Namespace(results_file='results.pkl', subject=0, time_low=20, time_high=460, eeg_dataset='/media/titan/AI Research1/Data/CVPR2017/eeg_5_95_std.pth', model_type='model10', splits_path='/media/titan/AI Research1/Data/CVPR2017/block_splits_by_image_all.pth', split_num=0, split_name='train', batch_size=16, optim='Adam', learning_rate=0.001, learning_rate_decay_by=0.5, learning_rate_decay_every=10, epochs=100, GPUindex=0, kind='from-scratch', no_cuda=False, classifier='EEGChannelNet')

# %%
channel_idx=None
non_classes=None
if opt.kind=="from-scratch":
    results = net_trainer(
            net,
            loaders,
            opt,
            channel_idx,
            nonclasses,
            None,
            True,
            model_path)
# Out:
# Epoch 1
# Train Batch 100 (every 100 batch): Loss=3.7582; accuracy=0.0325
# Train Batch 200 (every 100 batch): Loss=3.6718; accuracy=0.0287
# Train Batch 300 (every 100 batch): Loss=3.7293; accuracy=0.0273
# Train Batch 400 (every 100 batch): Loss=3.7032; accuracy=0.0278
# Epoch 1 summary: train_loss: 3.7084 | train_acc: 0.0280 | val_loss: 3.6936 | val_acc: 0.0205
# Epoch 2
# Train Batch 100 (every 100 batch): Loss=3.6803; accuracy=0.0231
# Train Batch 200 (every 100 batch): Loss=3.6839; accuracy=0.0259
# Train Batch 300 (every 100 batch): Loss=3.6566; accuracy=0.0256
# Train Batch 400 (every 100 batch): Loss=3.7066; accuracy=0.0245
# Epoch 2 summary: train_loss: 3.6943 | train_acc: 0.0259 | val_loss: 3.6997 | val_acc: 0.0218
# Epoch 3
# Train Batch 100 (every 100 batch): Loss=3.7302; accuracy=0.0287
# Train Batch 200 (every 100 batch): Loss=3.6352; accuracy=0.0272
# Train Batch 300 (every 100 batch): Loss=3.6836; accuracy=0.0294
# Train Batch 400 (every 100 batch): Loss=3.7036; accuracy=0.0302
# Epoch 3 summary: train_loss: 3.6897 | train_acc: 0.0285 | val_loss: 3.7016 | val_acc: 0.0220
# Epoch 4
# Train Batch 100 (every 100 batch): Loss=3.6731; accuracy=0.0250
# Train Batch 200 (every 100 batch): Loss=3.6974; accuracy=0.0287
# Train Batch 300 (every 100 batch): Loss=3.6858; accuracy=0.0296
# Train Batch 400 (every 100 batch): Loss=3.7123; accuracy=0.0294
# Epoch 4 summary: train_loss: 3.6901 | train_acc: 0.0291 | val_loss: 3.7006 | val_acc: 0.0273
# Epoch 5
# Train Batch 100 (every 100 batch): Loss=3.7016; accuracy=0.0281
# Train Batch 200 (every 100 batch): Loss=3.6762; accuracy=0.0275
# Train Batch 300 (every 100 batch): Loss=3.6964; accuracy=0.0254
# Train Batch 400 (every 100 batch): Loss=3.6438; accuracy=0.0256
# Epoch 5 summary: train_loss: 3.6891 | train_acc: 0.0265 | val_loss: 3.7010 | val_acc: 0.0261
# Epoch 6
# Train Batch 100 (every 100 batch): Loss=3.6357; accuracy=0.0256
# Train Batch 200 (every 100 batch): Loss=3.7218; accuracy=0.0287
# Train Batch 300 (every 100 batch): Loss=3.6727; accuracy=0.0285
# Train Batch 400 (every 100 batch): Loss=3.6086; accuracy=0.0291
# Epoch 6 summary: train_loss: 3.6863 | train_acc: 0.0311 | val_loss: 3.7034 | val_acc: 0.0200
# Epoch 7
# Train Batch 100 (every 100 batch): Loss=3.6354; accuracy=0.0269
# Train Batch 200 (every 100 batch): Loss=3.6640; accuracy=0.0287
# Train Batch 300 (every 100 batch): Loss=3.6817; accuracy=0.0310
# Train Batch 400 (every 100 batch): Loss=3.6888; accuracy=0.0302
# Epoch 7 summary: train_loss: 3.6837 | train_acc: 0.0297 | val_loss: 3.6983 | val_acc: 0.0240
# Epoch 8
# Train Batch 100 (every 100 batch): Loss=3.7169; accuracy=0.0331
# Train Batch 200 (every 100 batch): Loss=3.5937; accuracy=0.0303
# Train Batch 300 (every 100 batch): Loss=3.6594; accuracy=0.0306
# Train Batch 400 (every 100 batch): Loss=3.7765; accuracy=0.0298
# Epoch 8 summary: train_loss: 3.6810 | train_acc: 0.0309 | val_loss: 3.7082 | val_acc: 0.0210
# Epoch 9
# Train Batch 100 (every 100 batch): Loss=3.7091; accuracy=0.0344
# Train Batch 200 (every 100 batch): Loss=3.7512; accuracy=0.0306
# Train Batch 300 (every 100 batch): Loss=3.6824; accuracy=0.0285
# Train Batch 400 (every 100 batch): Loss=3.6273; accuracy=0.0292
# Epoch 9 summary: train_loss: 3.6785 | train_acc: 0.0306 | val_loss: 3.7096 | val_acc: 0.0235
# Epoch 10
# Train Batch 100 (every 100 batch): Loss=3.7537; accuracy=0.0225
# Train Batch 200 (every 100 batch): Loss=3.7164; accuracy=0.0241
# Train Batch 300 (every 100 batch): Loss=3.6617; accuracy=0.0273
# Train Batch 400 (every 100 batch): Loss=3.5008; accuracy=0.0281
# Epoch 10 summary: train_loss: 3.6742 | train_acc: 0.0282 | val_loss: 3.7163 | val_acc: 0.0258
# Epoch 11
# Train Batch 100 (every 100 batch): Loss=3.6933; accuracy=0.0362
# Train Batch 200 (every 100 batch): Loss=3.6101; accuracy=0.0337
# Train Batch 300 (every 100 batch): Loss=3.4898; accuracy=0.0340
# Train Batch 400 (every 100 batch): Loss=3.6027; accuracy=0.0344
# Epoch 11 summary: train_loss: 3.6706 | train_acc: 0.0363 | val_loss: 3.7099 | val_acc: 0.0258
# Epoch 12
# Train Batch 100 (every 100 batch): Loss=3.6049; accuracy=0.0319
# Train Batch 200 (every 100 batch): Loss=3.6593; accuracy=0.0337
# Train Batch 300 (every 100 batch): Loss=3.7036; accuracy=0.0335
# Train Batch 400 (every 100 batch): Loss=3.6732; accuracy=0.0352
# Epoch 12 summary: train_loss: 3.6634 | train_acc: 0.0351 | val_loss: 3.7200 | val_acc: 0.0280
# Epoch 13
# Train Batch 100 (every 100 batch): Loss=3.7961; accuracy=0.0494
# Train Batch 200 (every 100 batch): Loss=3.6587; accuracy=0.0444
# Train Batch 300 (every 100 batch): Loss=3.4815; accuracy=0.0442
# Train Batch 400 (every 100 batch): Loss=3.5466; accuracy=0.0423
# Epoch 13 summary: train_loss: 3.6325 | train_acc: 0.0414 | val_loss: 3.6056 | val_acc: 0.0358
# Epoch 14
# Train Batch 100 (every 100 batch): Loss=3.6739; accuracy=0.0456
# Train Batch 200 (every 100 batch): Loss=3.6203; accuracy=0.0456
# Train Batch 300 (every 100 batch): Loss=3.3002; accuracy=0.0481
# Train Batch 400 (every 100 batch): Loss=3.4038; accuracy=0.0509
# Epoch 14 summary: train_loss: 3.4362 | train_acc: 0.0529 | val_loss: 3.4023 | val_acc: 0.0435
# Epoch 15
# Train Batch 100 (every 100 batch): Loss=3.1147; accuracy=0.0662
# Train Batch 200 (every 100 batch): Loss=3.2731; accuracy=0.0700
# Train Batch 300 (every 100 batch): Loss=3.2314; accuracy=0.0775
# Train Batch 400 (every 100 batch): Loss=2.8795; accuracy=0.0784
# Epoch 15 summary: train_loss: 3.1703 | train_acc: 0.0796 | val_loss: 3.0384 | val_acc: 0.0933
# Epoch 16
# Train Batch 100 (every 100 batch): Loss=3.2071; accuracy=0.0987
# Train Batch 200 (every 100 batch): Loss=2.6751; accuracy=0.1056
# Train Batch 300 (every 100 batch): Loss=2.9635; accuracy=0.1040
# Train Batch 400 (every 100 batch): Loss=2.7633; accuracy=0.1013
# Epoch 16 summary: train_loss: 2.9134 | train_acc: 0.1054 | val_loss: 2.8184 | val_acc: 0.0953
# Epoch 17
# Train Batch 100 (every 100 batch): Loss=2.6718; accuracy=0.1381
# Train Batch 200 (every 100 batch): Loss=2.5097; accuracy=0.1416
# Train Batch 300 (every 100 batch): Loss=2.6422; accuracy=0.1402
# Train Batch 400 (every 100 batch): Loss=2.5814; accuracy=0.1466
# Epoch 17 summary: train_loss: 2.6812 | train_acc: 0.1445 | val_loss: 2.6341 | val_acc: 0.1503
# Epoch 18
# Train Batch 100 (every 100 batch): Loss=2.5940; accuracy=0.1700
# Train Batch 200 (every 100 batch): Loss=2.9121; accuracy=0.1609
# Train Batch 300 (every 100 batch): Loss=2.6545; accuracy=0.1656
# Train Batch 400 (every 100 batch): Loss=2.3372; accuracy=0.1636
# Epoch 18 summary: train_loss: 2.5204 | train_acc: 0.1652 | val_loss: 2.4381 | val_acc: 0.1628
# Epoch 19
# Train Batch 100 (every 100 batch): Loss=2.2079; accuracy=0.1775
# Train Batch 200 (every 100 batch): Loss=2.4709; accuracy=0.1816
# Train Batch 300 (every 100 batch): Loss=2.5028; accuracy=0.1860
# Train Batch 400 (every 100 batch): Loss=1.7567; accuracy=0.1898
# Epoch 19 summary: train_loss: 2.3879 | train_acc: 0.1934 | val_loss: 2.4033 | val_acc: 0.1740
# Epoch 20
# Train Batch 100 (every 100 batch): Loss=2.3303; accuracy=0.2156
# Train Batch 200 (every 100 batch): Loss=2.0878; accuracy=0.2131
# Train Batch 300 (every 100 batch): Loss=2.0944; accuracy=0.2152
# Train Batch 400 (every 100 batch): Loss=2.1959; accuracy=0.2142
# Epoch 20 summary: train_loss: 2.2783 | train_acc: 0.2117 | val_loss: 2.1962 | val_acc: 0.2185
# Epoch 21
# Train Batch 100 (every 100 batch): Loss=2.1188; accuracy=0.2356
# Train Batch 200 (every 100 batch): Loss=2.2500; accuracy=0.2356
# Train Batch 300 (every 100 batch): Loss=2.3145; accuracy=0.2338
# Train Batch 400 (every 100 batch): Loss=2.1695; accuracy=0.2316
# Epoch 21 summary: train_loss: 2.1904 | train_acc: 0.2351 | val_loss: 2.1542 | val_acc: 0.2333
# Epoch 22
# Train Batch 100 (every 100 batch): Loss=1.8935; accuracy=0.2506
# Train Batch 200 (every 100 batch): Loss=2.0914; accuracy=0.2484
# Train Batch 300 (every 100 batch): Loss=2.0573; accuracy=0.2471
# Train Batch 400 (every 100 batch): Loss=2.6647; accuracy=0.2425
# Epoch 22 summary: train_loss: 2.1212 | train_acc: 0.2440 | val_loss: 2.1552 | val_acc: 0.2289
# Epoch 23
# Train Batch 100 (every 100 batch): Loss=2.0265; accuracy=0.2575
# Train Batch 200 (every 100 batch): Loss=2.1290; accuracy=0.2512
# Train Batch 300 (every 100 batch): Loss=2.2349; accuracy=0.2565
# Train Batch 400 (every 100 batch): Loss=2.2285; accuracy=0.2562
# Epoch 23 summary: train_loss: 2.0476 | train_acc: 0.2621 | val_loss: 2.0215 | val_acc: 0.2620
# Epoch 24
# Train Batch 100 (every 100 batch): Loss=1.9886; accuracy=0.2819
# Train Batch 200 (every 100 batch): Loss=1.8673; accuracy=0.2828
# Train Batch 300 (every 100 batch): Loss=2.4945; accuracy=0.2837
# Train Batch 400 (every 100 batch): Loss=2.2637; accuracy=0.2827
# Epoch 24 summary: train_loss: 1.9891 | train_acc: 0.2824 | val_loss: 2.0211 | val_acc: 0.2884
# Epoch 25
# Train Batch 100 (every 100 batch): Loss=1.7589; accuracy=0.2931
# Train Batch 200 (every 100 batch): Loss=1.7218; accuracy=0.2972
# Train Batch 300 (every 100 batch): Loss=1.5927; accuracy=0.2938
# Train Batch 100 (every 100 batch): Loss=1.3058; accuracy=0.4013
# Train Batch 200 (every 100 batch): Loss=2.1991; accuracy=0.3994
# Train Batch 300 (every 100 batch): Loss=1.5989; accuracy=0.3994
# Train Batch 400 (every 100 batch): Loss=1.6679; accuracy=0.3991
# Epoch 34 summary: train_loss: 1.5876 | train_acc: 0.3988 | val_loss: 1.9807 | val_acc: 0.3334
# Epoch 35
# Train Batch 100 (every 100 batch): Loss=1.4754; accuracy=0.4181
# Train Batch 200 (every 100 batch): Loss=1.8491; accuracy=0.4175
# Train Batch 300 (every 100 batch): Loss=1.5260; accuracy=0.4144
# Train Batch 400 (every 100 batch): Loss=1.6148; accuracy=0.4114
# Epoch 35 summary: train_loss: 1.5477 | train_acc: 0.4142 | val_loss: 2.1163 | val_acc: 0.3172
# Epoch 36
# Train Batch 100 (every 100 batch): Loss=1.5571; accuracy=0.4462
# Train Batch 200 (every 100 batch): Loss=1.7570; accuracy=0.4234
# Train Batch 300 (every 100 batch): Loss=1.6404; accuracy=0.4223
# Train Batch 400 (every 100 batch): Loss=1.5173; accuracy=0.4169
# Epoch 36 summary: train_loss: 1.5406 | train_acc: 0.4114 | val_loss: 1.9298 | val_acc: 0.3285
# Epoch 37
# Train Batch 100 (every 100 batch): Loss=1.5247; accuracy=0.4350
# Train Batch 200 (every 100 batch): Loss=1.2914; accuracy=0.4328
# Train Batch 300 (every 100 batch): Loss=1.2632; accuracy=0.4402
# Train Batch 400 (every 100 batch): Loss=1.4772; accuracy=0.4394
# Epoch 37 summary: train_loss: 1.4872 | train_acc: 0.4345 | val_loss: 2.0308 | val_acc: 0.3460
# Epoch 38
# Train Batch 100 (every 100 batch): Loss=1.5811; accuracy=0.4737
# Train Batch 200 (every 100 batch): Loss=1.6380; accuracy=0.4566
# Train Batch 300 (every 100 batch): Loss=1.5927; accuracy=0.4454
# Train Batch 400 (every 100 batch): Loss=1.7559; accuracy=0.4433
# Epoch 38 summary: train_loss: 1.4637 | train_acc: 0.4461 | val_loss: 2.0456 | val_acc: 0.3484
# Epoch 39
# Train Batch 100 (every 100 batch): Loss=0.9359; accuracy=0.4837
# Train Batch 200 (every 100 batch): Loss=1.6989; accuracy=0.4659
# Train Batch 300 (every 100 batch): Loss=1.3622; accuracy=0.4631
# Train Batch 400 (every 100 batch): Loss=0.9376; accuracy=0.4630
# Epoch 39 summary: train_loss: 1.4335 | train_acc: 0.4569 | val_loss: 1.9624 | val_acc: 0.3597
# Epoch 40
# Train Batch 100 (every 100 batch): Loss=1.3236; accuracy=0.4750
# Train Batch 200 (every 100 batch): Loss=1.4578; accuracy=0.4741
# Train Batch 300 (every 100 batch): Loss=1.3224; accuracy=0.4696
# Train Batch 400 (every 100 batch): Loss=1.2517; accuracy=0.4641
# Epoch 40 summary: train_loss: 1.4185 | train_acc: 0.4621 | val_loss: 2.0819 | val_acc: 0.3399
# Epoch 41
# Train Batch 100 (every 100 batch): Loss=1.3624; accuracy=0.4956
# Train Batch 200 (every 100 batch): Loss=1.6064; accuracy=0.4884
# Train Batch 300 (every 100 batch): Loss=0.9103; accuracy=0.4790
# Train Batch 400 (every 100 batch): Loss=1.2247; accuracy=0.4747
# Epoch 41 summary: train_loss: 1.3912 | train_acc: 0.4723 | val_loss: 2.0106 | val_acc: 0.3597
# Epoch 42
# Train Batch 100 (every 100 batch): Loss=1.4727; accuracy=0.4781
# Train Batch 200 (every 100 batch): Loss=1.2935; accuracy=0.4850
# Train Batch 300 (every 100 batch): Loss=1.9536; accuracy=0.4744
# Train Batch 400 (every 100 batch): Loss=1.6923; accuracy=0.4725
# Epoch 42 summary: train_loss: 1.3745 | train_acc: 0.4682 | val_loss: 2.1559 | val_acc: 0.3382
# Epoch 43
# Train Batch 100 (every 100 batch): Loss=1.2167; accuracy=0.5131
# Train Batch 200 (every 100 batch): Loss=1.3218; accuracy=0.4969
# Train Batch 300 (every 100 batch): Loss=1.0858; accuracy=0.4948
# Train Batch 400 (every 100 batch): Loss=0.8524; accuracy=0.4950
# Epoch 43 summary: train_loss: 1.3452 | train_acc: 0.4955 | val_loss: 2.1453 | val_acc: 0.3530
# Epoch 44
# Train Batch 100 (every 100 batch): Loss=1.5105; accuracy=0.5200
# Train Batch 200 (every 100 batch): Loss=0.9370; accuracy=0.5178
# Train Batch 300 (every 100 batch): Loss=1.2195; accuracy=0.5088
# Train Batch 400 (every 100 batch): Loss=0.9647; accuracy=0.5077
# Epoch 44 summary: train_loss: 1.3143 | train_acc: 0.5028 | val_loss: 2.0004 | val_acc: 0.3594
# Epoch 45
# Train Batch 100 (every 100 batch): Loss=1.4341; accuracy=0.5256
# Train Batch 200 (every 100 batch): Loss=0.9727; accuracy=0.5122
# Train Batch 300 (every 100 batch): Loss=0.9704; accuracy=0.5185
# Train Batch 400 (every 100 batch): Loss=1.0989; accuracy=0.5139
# Epoch 45 summary: train_loss: 1.2945 | train_acc: 0.5169 | val_loss: 2.0436 | val_acc: 0.3742
# Epoch 46
# Train Batch 100 (every 100 batch): Loss=1.3792; accuracy=0.5294
# Train Batch 200 (every 100 batch): Loss=1.5580; accuracy=0.5356
# Train Batch 300 (every 100 batch): Loss=1.0291; accuracy=0.5302
# Train Batch 400 (every 100 batch): Loss=1.6559; accuracy=0.5233
# Epoch 46 summary: train_loss: 1.2745 | train_acc: 0.5205 | val_loss: 2.0802 | val_acc: 0.3784
# Epoch 47
# Train Batch 100 (every 100 batch): Loss=1.2291; accuracy=0.5512
# Train Batch 200 (every 100 batch): Loss=1.4417; accuracy=0.5475
# Train Batch 300 (every 100 batch): Loss=1.0210; accuracy=0.5379
# Train Batch 400 (every 100 batch): Loss=1.0623; accuracy=0.5359
# Epoch 47 summary: train_loss: 1.2450 | train_acc: 0.5275 | val_loss: 2.1424 | val_acc: 0.3614
# Epoch 48
# Train Batch 100 (every 100 batch): Loss=1.3675; accuracy=0.5500
# Train Batch 200 (every 100 batch): Loss=1.5103; accuracy=0.5356
# Train Batch 300 (every 100 batch): Loss=1.1510; accuracy=0.5335
# Train Batch 400 (every 100 batch): Loss=1.3143; accuracy=0.5353
# Epoch 48 summary: train_loss: 1.2173 | train_acc: 0.5381 | val_loss: 2.1151 | val_acc: 0.3668
# Epoch 49
# Train Batch 100 (every 100 batch): Loss=0.9740; accuracy=0.5556
# Train Batch 200 (every 100 batch): Loss=1.1942; accuracy=0.5475
# Train Batch 300 (every 100 batch): Loss=0.8070; accuracy=0.5517
# Train Batch 400 (every 100 batch): Loss=1.1876; accuracy=0.5466
# Epoch 49 summary: train_loss: 1.1948 | train_acc: 0.5477 | val_loss: 2.1144 | val_acc: 0.3650
# Epoch 50
# Train Batch 100 (every 100 batch): Loss=1.2486; accuracy=0.5531
# Train Batch 200 (every 100 batch): Loss=1.1315; accuracy=0.5625
# Train Batch 300 (every 100 batch): Loss=1.0885; accuracy=0.5606
# Train Batch 400 (every 100 batch): Loss=0.9798; accuracy=0.5564
# Epoch 50 summary: train_loss: 1.1686 | train_acc: 0.5578 | val_loss: 2.1213 | val_acc: 0.3695
# Epoch 51
# Train Batch 100 (every 100 batch): Loss=1.2586; accuracy=0.5669
# Train Batch 200 (every 100 batch): Loss=0.6605; accuracy=0.5687
# Train Batch 300 (every 100 batch): Loss=1.2687; accuracy=0.5700
# Train Batch 400 (every 100 batch): Loss=1.4806; accuracy=0.5670
# Epoch 51 summary: train_loss: 1.1524 | train_acc: 0.5657 | val_loss: 2.2619 | val_acc: 0.3727
# Epoch 52
# Train Batch 100 (every 100 batch): Loss=1.0725; accuracy=0.5637
# Train Batch 200 (every 100 batch): Loss=1.5000; accuracy=0.5744
# Train Batch 300 (every 100 batch): Loss=1.8833; accuracy=0.5677
# Train Batch 400 (every 100 batch): Loss=1.2125; accuracy=0.5747
# Epoch 52 summary: train_loss: 1.1272 | train_acc: 0.5731 | val_loss: 2.2226 | val_acc: 0.3707
# Epoch 53
# Train Batch 100 (every 100 batch): Loss=1.0793; accuracy=0.6006
# Train Batch 200 (every 100 batch): Loss=1.6451; accuracy=0.5997
# Train Batch 300 (every 100 batch): Loss=1.0485; accuracy=0.5892
# Train Batch 400 (every 100 batch): Loss=1.0661; accuracy=0.5897
# Epoch 53 summary: train_loss: 1.1035 | train_acc: 0.5869 | val_loss: 2.3755 | val_acc: 0.3762
# Epoch 54
# Train Batch 100 (every 100 batch): Loss=1.1103; accuracy=0.6025
# Train Batch 200 (every 100 batch): Loss=1.6222; accuracy=0.6022
# Train Batch 300 (every 100 batch): Loss=0.8457; accuracy=0.5987
# Train Batch 400 (every 100 batch): Loss=1.1462; accuracy=0.5923
# Epoch 54 summary: train_loss: 1.0828 | train_acc: 0.5907 | val_loss: 2.4048 | val_acc: 0.3310
# Epoch 55
# Train Batch 100 (every 100 batch): Loss=1.1101; accuracy=0.6050
# Train Batch 200 (every 100 batch): Loss=1.5485; accuracy=0.6034
# Train Batch 300 (every 100 batch): Loss=1.0751; accuracy=0.6044
# Train Batch 400 (every 100 batch): Loss=0.9773; accuracy=0.6062
# Epoch 55 summary: train_loss: 1.0527 | train_acc: 0.6036 | val_loss: 2.3295 | val_acc: 0.3446
# Epoch 56
# Train Batch 100 (every 100 batch): Loss=0.8411; accuracy=0.6569
# Train Batch 200 (every 100 batch): Loss=0.7097; accuracy=0.6372
# Train Batch 300 (every 100 batch): Loss=0.8452; accuracy=0.6238
# Train Batch 400 (every 100 batch): Loss=0.5820; accuracy=0.6225
# Epoch 56 summary: train_loss: 1.0371 | train_acc: 0.6153 | val_loss: 2.5163 | val_acc: 0.3624
# Epoch 57
# Train Batch 100 (every 100 batch): Loss=1.1828; accuracy=0.6375
# Train Batch 200 (every 100 batch): Loss=0.7537; accuracy=0.6312
# Train Batch 300 (every 100 batch): Loss=0.8531; accuracy=0.6296
# Train Batch 400 (every 100 batch): Loss=1.5631; accuracy=0.6253
# Epoch 57 summary: train_loss: 1.0206 | train_acc: 0.6194 | val_loss: 2.2260 | val_acc: 0.3701
# Epoch 58
# Train Batch 100 (every 100 batch): Loss=0.7167; accuracy=0.6356
# Train Batch 200 (every 100 batch): Loss=1.1992; accuracy=0.6350
# Train Batch 300 (every 100 batch): Loss=0.7862; accuracy=0.6242
# Train Batch 400 (every 100 batch): Loss=1.1224; accuracy=0.6220
# Epoch 58 summary: train_loss: 0.9986 | train_acc: 0.6208 | val_loss: 2.4543 | val_acc: 0.3640
# Epoch 59
# Train Batch 100 (every 100 batch): Loss=0.5984; accuracy=0.6569
# Train Batch 200 (every 100 batch): Loss=0.8692; accuracy=0.6306
# Train Batch 300 (every 100 batch): Loss=0.9660; accuracy=0.6335
# Train Batch 400 (every 100 batch): Loss=0.9739; accuracy=0.6336
# Epoch 59 summary: train_loss: 0.9825 | train_acc: 0.6314 | val_loss: 2.5157 | val_acc: 0.3631
# Epoch 60
# Train Batch 100 (every 100 batch): Loss=1.2044; accuracy=0.6531
# Train Batch 200 (every 100 batch): Loss=0.7704; accuracy=0.6528
# Train Batch 300 (every 100 batch): Loss=0.6731; accuracy=0.6448
# Train Batch 400 (every 100 batch): Loss=0.9961; accuracy=0.6414
# Epoch 60 summary: train_loss: 0.9680 | train_acc: 0.6386 | val_loss: 2.3793 | val_acc: 0.3747
# Epoch 61
# Train Batch 100 (every 100 batch): Loss=0.5253; accuracy=0.6594
# Train Batch 200 (every 100 batch): Loss=1.0271; accuracy=0.6544
# Train Batch 300 (every 100 batch): Loss=0.9064; accuracy=0.6519
# Train Batch 400 (every 100 batch): Loss=0.8632; accuracy=0.6484
# Epoch 61 summary: train_loss: 0.9432 | train_acc: 0.6471 | val_loss: 2.5758 | val_acc: 0.3590
# Epoch 62
# Train Batch 100 (every 100 batch): Loss=0.4786; accuracy=0.6606
# Train Batch 200 (every 100 batch): Loss=0.8216; accuracy=0.6625
# Train Batch 300 (every 100 batch): Loss=0.7452; accuracy=0.6575
# Train Batch 400 (every 100 batch): Loss=0.6611; accuracy=0.6547
# Epoch 62 summary: train_loss: 0.9356 | train_acc: 0.6508 | val_loss: 2.3962 | val_acc: 0.3701
# Epoch 63
# Train Batch 100 (every 100 batch): Loss=1.5939; accuracy=0.6731
# Train Batch 200 (every 100 batch): Loss=1.0485; accuracy=0.6659
# Train Batch 300 (every 100 batch): Loss=0.6941; accuracy=0.6671
# Train Batch 400 (every 100 batch): Loss=0.7682; accuracy=0.6625
# Epoch 63 summary: train_loss: 0.9014 | train_acc: 0.6629 | val_loss: 2.6989 | val_acc: 0.3615
# Epoch 64
# Train Batch 100 (every 100 batch): Loss=0.5871; accuracy=0.6669
# Train Batch 200 (every 100 batch): Loss=1.4399; accuracy=0.6691
# Train Batch 300 (every 100 batch): Loss=1.3120; accuracy=0.6652
# Train Batch 400 (every 100 batch): Loss=0.7080; accuracy=0.6628
# Epoch 64 summary: train_loss: 0.8932 | train_acc: 0.6637 | val_loss: 2.6382 | val_acc: 0.3768
# Epoch 65
# Train Batch 100 (every 100 batch): Loss=0.5793; accuracy=0.7138
# Train Batch 200 (every 100 batch): Loss=0.8986; accuracy=0.6975
# Train Batch 300 (every 100 batch): Loss=1.0986; accuracy=0.6896
# Train Batch 400 (every 100 batch): Loss=0.6067; accuracy=0.6814
# Epoch 65 summary: train_loss: 0.8644 | train_acc: 0.6803 | val_loss: 2.5849 | val_acc: 0.3692
# Epoch 66
# Train Batch 100 (every 100 batch): Loss=0.6581; accuracy=0.6894
# Train Batch 200 (every 100 batch): Loss=1.0100; accuracy=0.6941
# Train Batch 300 (every 100 batch): Loss=1.0618; accuracy=0.6921
# Train Batch 400 (every 100 batch): Loss=0.6669; accuracy=0.6875
# Epoch 66 summary: train_loss: 0.8472 | train_acc: 0.6833 | val_loss: 2.8068 | val_acc: 0.3469
# Epoch 67
# Train Batch 100 (every 100 batch): Loss=1.1625; accuracy=0.7250
# Train Batch 200 (every 100 batch): Loss=0.8514; accuracy=0.6956
# Train Batch 300 (every 100 batch): Loss=0.8019; accuracy=0.6908
# Train Batch 400 (every 100 batch): Loss=0.8001; accuracy=0.6944
# Epoch 67 summary: train_loss: 0.8372 | train_acc: 0.6939 | val_loss: 2.5866 | val_acc: 0.3687
# Epoch 68
# Train Batch 100 (every 100 batch): Loss=0.9080; accuracy=0.7144
# Train Batch 200 (every 100 batch): Loss=0.7135; accuracy=0.7150
# Train Batch 300 (every 100 batch): Loss=0.5241; accuracy=0.7090
# Train Batch 400 (every 100 batch): Loss=0.8348; accuracy=0.7059
# Epoch 68 summary: train_loss: 0.8140 | train_acc: 0.7022 | val_loss: 2.8135 | val_acc: 0.3436
# Epoch 69
# Train Batch 100 (every 100 batch): Loss=0.5686; accuracy=0.7163
# Train Batch 200 (every 100 batch): Loss=0.5770; accuracy=0.7216
# Train Batch 300 (every 100 batch): Loss=0.7395; accuracy=0.7140
# Train Batch 400 (every 100 batch): Loss=0.6102; accuracy=0.7130
# Epoch 69 summary: train_loss: 0.7948 | train_acc: 0.7118 | val_loss: 2.7713 | val_acc: 0.3500
# Epoch 70
# Train Batch 100 (every 100 batch): Loss=0.4145; accuracy=0.7269
# Train Batch 200 (every 100 batch): Loss=0.6646; accuracy=0.7178
# Train Batch 300 (every 100 batch): Loss=1.1672; accuracy=0.7181
# Train Batch 400 (every 100 batch): Loss=0.4572; accuracy=0.7189
# Epoch 70 summary: train_loss: 0.7926 | train_acc: 0.7133 | val_loss: 2.9905 | val_acc: 0.3538
# Epoch 71
# Train Batch 100 (every 100 batch): Loss=1.0487; accuracy=0.7275
# Train Batch 200 (every 100 batch): Loss=1.0306; accuracy=0.7153
# Train Batch 300 (every 100 batch): Loss=0.8044; accuracy=0.7108
# Train Batch 400 (every 100 batch): Loss=0.9231; accuracy=0.7122
# Epoch 71 summary: train_loss: 0.7849 | train_acc: 0.7119 | val_loss: 2.7114 | val_acc: 0.3654
# Epoch 72
# Train Batch 100 (every 100 batch): Loss=0.6828; accuracy=0.7400
# Train Batch 200 (every 100 batch): Loss=0.6477; accuracy=0.7353
# Train Batch 300 (every 100 batch): Loss=0.7201; accuracy=0.7352
# Train Batch 400 (every 100 batch): Loss=1.0348; accuracy=0.7291
# Epoch 72 summary: train_loss: 0.7515 | train_acc: 0.7291 | val_loss: 2.8557 | val_acc: 0.3651
# Epoch 73
# Train Batch 100 (every 100 batch): Loss=0.5647; accuracy=0.7506
# Train Batch 200 (every 100 batch): Loss=0.4290; accuracy=0.7422
# Train Batch 300 (every 100 batch): Loss=0.6699; accuracy=0.7342
# Train Batch 400 (every 100 batch): Loss=0.3743; accuracy=0.7361
# Epoch 73 summary: train_loss: 0.7296 | train_acc: 0.7374 | val_loss: 2.8178 | val_acc: 0.3572
# Epoch 74
# Train Batch 100 (every 100 batch): Loss=0.9150; accuracy=0.7756
# Train Batch 200 (every 100 batch): Loss=0.2419; accuracy=0.7547
# Train Batch 300 (every 100 batch): Loss=0.2907; accuracy=0.7510
# Train Batch 400 (every 100 batch): Loss=0.9848; accuracy=0.7444
# Epoch 74 summary: train_loss: 0.7107 | train_acc: 0.7426 | val_loss: 2.8406 | val_acc: 0.3429
# Epoch 75
# Train Batch 100 (every 100 batch): Loss=0.4414; accuracy=0.7475
# Train Batch 200 (every 100 batch): Loss=0.3578; accuracy=0.7584
# Train Batch 300 (every 100 batch): Loss=0.5332; accuracy=0.7504
# Train Batch 400 (every 100 batch): Loss=1.0427; accuracy=0.7467
# Epoch 75 summary: train_loss: 0.7144 | train_acc: 0.7429 | val_loss: 2.6930 | val_acc: 0.3770
# Epoch 76
# Train Batch 100 (every 100 batch): Loss=0.8893; accuracy=0.7619
# Train Batch 200 (every 100 batch): Loss=0.8555; accuracy=0.7500
# Train Batch 300 (every 100 batch): Loss=0.7410; accuracy=0.7579
# Train Batch 400 (every 100 batch): Loss=0.5726; accuracy=0.7558
# Epoch 76 summary: train_loss: 0.7015 | train_acc: 0.7510 | val_loss: 3.0261 | val_acc: 0.3616
# Epoch 77
# Train Batch 100 (every 100 batch): Loss=0.5371; accuracy=0.7706
# Train Batch 200 (every 100 batch): Loss=0.4474; accuracy=0.7569
# Train Batch 300 (every 100 batch): Loss=0.6312; accuracy=0.7592
# Train Batch 400 (every 100 batch): Loss=0.6507; accuracy=0.7612
# Epoch 77 summary: train_loss: 0.6684 | train_acc: 0.7605 | val_loss: 2.9380 | val_acc: 0.3612
# Epoch 78
# Train Batch 100 (every 100 batch): Loss=0.5389; accuracy=0.7569
# Train Batch 200 (every 100 batch): Loss=0.2780; accuracy=0.7578
# Train Batch 300 (every 100 batch): Loss=0.2968; accuracy=0.7627
# Train Batch 400 (every 100 batch): Loss=0.4340; accuracy=0.7641
# Epoch 78 summary: train_loss: 0.6605 | train_acc: 0.7599 | val_loss: 2.9057 | val_acc: 0.3678
# Epoch 79
# Train Batch 100 (every 100 batch): Loss=0.4077; accuracy=0.7862
# Train Batch 200 (every 100 batch): Loss=0.9924; accuracy=0.7772
# Train Batch 300 (every 100 batch): Loss=0.6258; accuracy=0.7727
# Train Batch 400 (every 100 batch): Loss=0.5343; accuracy=0.7692
# Epoch 79 summary: train_loss: 0.6417 | train_acc: 0.7650 | val_loss: 2.8960 | val_acc: 0.3656
# Epoch 80
# Train Batch 100 (every 100 batch): Loss=0.2974; accuracy=0.7912
# Train Batch 200 (every 100 batch): Loss=0.4049; accuracy=0.7822
# Train Batch 300 (every 100 batch): Loss=1.1107; accuracy=0.7865
# Train Batch 400 (every 100 batch): Loss=0.7562; accuracy=0.7802
# Epoch 89 summary: train_loss: 0.5263 | train_acc: 0.8126 | val_loss: 3.4064 | val_acc: 0.3597
# Epoch 90
# Train Batch 100 (every 100 batch): Loss=0.6175; accuracy=0.8294
# Train Batch 200 (every 100 batch): Loss=0.4246; accuracy=0.8287
# Train Batch 300 (every 100 batch): Loss=0.4178; accuracy=0.8210
# Train Batch 400 (every 100 batch): Loss=0.3750; accuracy=0.8192
# Epoch 90 summary: train_loss: 0.5186 | train_acc: 0.8156 | val_loss: 3.5569 | val_acc: 0.3576
# Epoch 91
# Train Batch 100 (every 100 batch): Loss=0.6237; accuracy=0.8156
# Train Batch 200 (every 100 batch): Loss=0.2317; accuracy=0.8253
# Train Batch 300 (every 100 batch): Loss=0.4760; accuracy=0.8204
# Train Batch 400 (every 100 batch): Loss=0.7948; accuracy=0.8216
# Epoch 91 summary: train_loss: 0.5022 | train_acc: 0.8184 | val_loss: 3.2712 | val_acc: 0.3665
# Epoch 92
# Train Batch 100 (every 100 batch): Loss=0.6305; accuracy=0.8363
# Train Batch 200 (every 100 batch): Loss=0.4802; accuracy=0.8219
# Train Batch 300 (every 100 batch): Loss=0.6117; accuracy=0.8244
# Train Batch 400 (every 100 batch): Loss=1.3485; accuracy=0.8250
# Epoch 92 summary: train_loss: 0.5041 | train_acc: 0.8254 | val_loss: 3.4458 | val_acc: 0.3581
# Epoch 93
# Train Batch 100 (every 100 batch): Loss=0.3609; accuracy=0.8331
# Train Batch 200 (every 100 batch): Loss=0.4413; accuracy=0.8341
# Train Batch 300 (every 100 batch): Loss=1.0568; accuracy=0.8329
# Train Batch 400 (every 100 batch): Loss=0.3106; accuracy=0.8333
# Epoch 93 summary: train_loss: 0.4720 | train_acc: 0.8315 | val_loss: 3.2975 | val_acc: 0.3680
# Epoch 94
# Train Batch 100 (every 100 batch): Loss=0.6979; accuracy=0.8494
# Train Batch 200 (every 100 batch): Loss=0.9994; accuracy=0.8525
# Train Batch 300 (every 100 batch): Loss=0.5863; accuracy=0.8450
# Train Batch 400 (every 100 batch): Loss=0.5497; accuracy=0.8406
# Epoch 94 summary: train_loss: 0.4721 | train_acc: 0.8373 | val_loss: 3.5377 | val_acc: 0.3500
# Epoch 95
# Train Batch 100 (every 100 batch): Loss=0.4425; accuracy=0.8269
# Train Batch 200 (every 100 batch): Loss=0.1145; accuracy=0.8309
# Train Batch 300 (every 100 batch): Loss=0.9254; accuracy=0.8325
# Train Batch 400 (every 100 batch): Loss=0.4936; accuracy=0.8270
# Epoch 95 summary: train_loss: 0.4824 | train_acc: 0.8284 | val_loss: 3.5022 | val_acc: 0.3690
# Epoch 96
# Train Batch 100 (every 100 batch): Loss=0.2858; accuracy=0.8462
# Train Batch 200 (every 100 batch): Loss=0.6002; accuracy=0.8378
# Train Batch 300 (every 100 batch): Loss=0.5949; accuracy=0.8360
# Train Batch 400 (every 100 batch): Loss=0.6558; accuracy=0.8364
# Epoch 96 summary: train_loss: 0.4621 | train_acc: 0.8374 | val_loss: 3.3306 | val_acc: 0.3546
# Epoch 97
# Train Batch 100 (every 100 batch): Loss=0.8357; accuracy=0.8562
# Train Batch 200 (every 100 batch): Loss=0.4573; accuracy=0.8425
# Train Batch 300 (every 100 batch): Loss=0.9428; accuracy=0.8408
# Train Batch 400 (every 100 batch): Loss=0.1984; accuracy=0.8403
# Epoch 97 summary: train_loss: 0.4465 | train_acc: 0.8405 | val_loss: 3.5931 | val_acc: 0.3562
# Epoch 98
# Train Batch 100 (every 100 batch): Loss=0.6111; accuracy=0.8475
# Train Batch 200 (every 100 batch): Loss=0.5874; accuracy=0.8459
# Train Batch 300 (every 100 batch): Loss=0.3549; accuracy=0.8435
# Train Batch 400 (every 100 batch): Loss=0.2906; accuracy=0.8413
# Epoch 98 summary: train_loss: 0.4643 | train_acc: 0.8398 | val_loss: 3.6002 | val_acc: 0.3347
# Epoch 99
# Train Batch 100 (every 100 batch): Loss=0.3301; accuracy=0.8469
# Train Batch 200 (every 100 batch): Loss=0.4428; accuracy=0.8487
# Train Batch 300 (every 100 batch): Loss=0.6698; accuracy=0.8479
# Train Batch 400 (every 100 batch): Loss=0.2058; accuracy=0.8447
# Epoch 99 summary: train_loss: 0.4459 | train_acc: 0.8425 | val_loss: 3.5418 | val_acc: 0.3592
# Epoch 100
# Train Batch 100 (every 100 batch): Loss=0.4028; accuracy=0.8450
# Train Batch 200 (every 100 batch): Loss=0.1975; accuracy=0.8522
# Train Batch 300 (every 100 batch): Loss=0.3774; accuracy=0.8563
# Train Batch 400 (every 100 batch): Loss=0.5546; accuracy=0.8536
# Epoch 100 summary: train_loss: 0.4399 | train_acc: 0.8502 | val_loss: 3.6249 | val_acc: 0.3501

# %%
torch.save(results, results_path+'.obj')
# val =accuracy_val
# test = accuracy_test

# print("Validation accuracy: ", val)
# print("Test accuracy: ", test)

# %%
loaded_results = torch.load(results_path+'.obj')
print(loaded_results)
# Out:
# {'train_loss': [3.708382266113557, 3.6943420703152574, 3.689659358028427, 3.690112811973296, 3.6891378145141296, 3.6862910492831924, 3.683740390352456, 3.681005189696469, 3.678459005662236, 3.6742294950178827, 3.6706395345519347, 3.663387747174765, 3.632481514210682, 3.436202349911732, 3.1702836493411697, 2.9133645616860755, 2.6812339547168778, 2.520376566902222, 2.3879092517626814, 2.2782727302796393, 2.1904332901100556, 2.1211712808015357, 2.047587642468602, 1.9891046584849377, 1.947505953082119, 1.8815331791778167, 1.8485457198208115, 1.8093792939760598, 1.7458212586291824, 1.7421414428446667, 1.693274403671663, 1.6521116757249257, 1.6344079771434448, 1.5875827392421094, 1.547657245253942, 1.540619963982019, 1.487154372126223, 1.4637304329010377, 1.4334587815056843, 1.418474506422219, 1.391204894307148, 1.374520314625468, 1.3451852943284444, 1.314282026276531, 1.2945178918331024, 1.2744692485016513, 1.2450198115833313, 1.217334870234072, 1.194819479103548, 1.1685513426740486, 1.1523694746704944, 1.1271502391760608, 1.103547087036462, 1.082794522604789, 1.0527444810991786, 1.0371311400310104, 1.020627125977991, 0.998631067185038, 0.9824604355546844, 0.9680392972556463, 0.9432436091952534, 0.9355714856142021, 0.9013918831226337, 0.8931940001057812, 0.8643980271605602, 0.8472058101590857, 0.8371826425254585, 0.8140398948546873, 0.7947843703759243, 0.7925658916014744, 0.784916820296322, 0.7515257339341095, 0.7296193706462661, 0.7106924633903197, 0.7143991575782079, 0.7015170793995321, 0.6683726380448265, 0.6605240540002962, 0.6417052784418485, 0.6224911542960918, 0.6339277706022961, 0.6186359161772881, 0.6008580312372211, 0.5672103104791248, 0.5637161983139664, 0.5666980493858637, 0.5582915268030512, 0.5476064831467278, 0.5262530045995272, 0.5186090712401882, 0.5021692834285847, 0.5040624223380203, 0.47198974015004186, 0.4721192973684594, 0.4823612259050091, 0.4621330231099004, 0.44652020673914605, 0.4642674348290905, 0.44594904644242733, 0.4398817086076162], 'train_acc': [tensor(0.0280, device='cuda:0'), tensor(0.0259, device='cuda:0'), tensor(0.0285, device='cuda:0'), tensor(0.0291, device='cuda:0'), tensor(0.0265, device='cuda:0'), tensor(0.0311, device='cuda:0'), tensor(0.0297, device='cuda:0'), tensor(0.0309, device='cuda:0'), tensor(0.0306, device='cuda:0'), tensor(0.0282, device='cuda:0'), tensor(0.0363, device='cuda:0'), tensor(0.0351, device='cuda:0'), tensor(0.0414, device='cuda:0'), tensor(0.0529, device='cuda:0'), tensor(0.0796, device='cuda:0'), tensor(0.1054, device='cuda:0'), tensor(0.1445, device='cuda:0'), tensor(0.1652, device='cuda:0'), tensor(0.1934, device='cuda:0'), tensor(0.2117, device='cuda:0'), tensor(0.2351, device='cuda:0'), tensor(0.2440, device='cuda:0'), tensor(0.2621, device='cuda:0'), tensor(0.2824, device='cuda:0'), tensor(0.2926, device='cuda:0'), tensor(0.3064, device='cuda:0'), tensor(0.3178, device='cuda:0'), tensor(0.3353, device='cuda:0'), tensor(0.3487, device='cuda:0'), tensor(0.3478, device='cuda:0'), tensor(0.3695, device='cuda:0'), tensor(0.3826, device='cuda:0'), tensor(0.3818, device='cuda:0'), tensor(0.3988, device='cuda:0'), tensor(0.4142, device='cuda:0'), tensor(0.4114, device='cuda:0'), tensor(0.4345, device='cuda:0'), tensor(0.4461, device='cuda:0'), tensor(0.4569, device='cuda:0'), tensor(0.4621, device='cuda:0'), tensor(0.4723, device='cuda:0'), tensor(0.4682, device='cuda:0'), tensor(0.4955, device='cuda:0'), tensor(0.5028, device='cuda:0'), tensor(0.5169, device='cuda:0'), tensor(0.5205, device='cuda:0'), tensor(0.5275, device='cuda:0'), tensor(0.5381, device='cuda:0'), tensor(0.5477, device='cuda:0'), tensor(0.5578, device='cuda:0'), tensor(0.5657, device='cuda:0'), tensor(0.5731, device='cuda:0'), tensor(0.5869, device='cuda:0'), tensor(0.5907, device='cuda:0'), tensor(0.6036, device='cuda:0'), tensor(0.6153, device='cuda:0'), tensor(0.6194, device='cuda:0'), tensor(0.6208, device='cuda:0'), tensor(0.6314, device='cuda:0'), tensor(0.6386, device='cuda:0'), tensor(0.6471 ...

# %%
train_values = loaded_results['train_loss']
val_values = loaded_results['val_loss']
print(len(train_values))
print(len(val_values))
# Out:
# 100
# 100

# %%
epochs = range(1, 101)
print(len(epochs))
# Plot and label the training and validation loss values
plt.plot(epochs, train_values, label='Training Loss')
plt.plot(epochs, val_values, label='Validation Loss')
 
# Add in a title and axes labels
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
 
# Set the tick locations
plt.xticks(np.arange(0, 101, 10))
 
# Display the plot
plt.legend(loc='best')
plt.show()
# Out:
# 100

# %%
train_acc_values = torch.stack(loaded_results['train_acc']).tolist()
val_acc_values = torch.stack(loaded_results['val_acc']).tolist()
print(len(train_values))
print(len(val_values))
# Out:
# 100
# 100

# %%
epochs = range(1, 101)
print(len(epochs))
# Plot and label the training and validation loss values
plt.plot(epochs, train_acc_values, label='Training Accuracy')
plt.plot(epochs, val_acc_values, label='Validation Accuracy')
 
# Add in a title and axes labels
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
 
# Set the tick locations
plt.xticks(np.arange(0, 101, 10))
 
# Display the plot
plt.legend(loc='best')
plt.show()
# Out:
# 100
