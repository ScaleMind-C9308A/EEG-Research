# %%
import os
import random
import torch
import numpy as np
import pickle as pkl
from analysis import *
import argparse
from sys import platform
import matplotlib

# %%
torch.manual_seed(12)
torch.cuda.manual_seed(12)
np.random.seed(12)
torch.backends.cudnn.deterministics = True
torch.set_num_threads(1)

# %%
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.current_device())


print(torch.cuda.device(0))
print(torch.cuda.get_device_name(0))
# Out:
# True
# 1
# 0
# <torch.cuda.device object at 0x7f3130549f10>
# NVIDIA TITAN V

# %%
# iv: image option
length = 440
channel = 128
min_CNN = 200
n_classes = 40
classes = range(n_classes)

# %%
if platform == "linux" or platform == "linux2":
    torch_models_dir = r"/media/titan/AI Research1/Data/CVPR2017"
elif platform == "win32":
    torch_models_dir = r"D:\Data\CVPR2021-02785\CVPR2021-02785\preprocessed\torch_models"
block_splits_all, block_splits_single, eeg_14_70, eeg_55_95, eeg_5_95, eeg_raw = os.listdir(torch_models_dir)
print(os.listdir(torch_models_dir))
# Out:
# ['block_splits_by_image_all.pth', 'block_splits_by_image_single.pth', 'eeg_14_70_std.pth', 'eeg_55_95_std.pth', 'eeg_5_95_std.pth', 'eeg_signals_raw_with_mean_std.pth']

# %%
eeg_dataset = os.path.join(torch_models_dir, eeg_55_95)
splits_all_path = os.path.join(torch_models_dir, block_splits_all)
splits_single_path = os.path.join(torch_models_dir, block_splits_single)
# splits_path = os.path.join(torch_models_dir, splits_shuffled_path)
print(eeg_dataset,'\n', splits_all_path, '\n', splits_single_path)
# Out:
# /media/titan/AI Research1/Data/CVPR2017/eeg_55_95_std.pth
#  /media/titan/AI Research1/Data/CVPR2017/block_splits_by_image_all.pth
#  /media/titan/AI Research1/Data/CVPR2017/block_splits_by_image_single.pth

# %%
splits_all = torch.load(splits_all_path)
splits_single = torch.load(splits_single_path)

# %%
print(len(splits_all['splits']))
print(len(splits_all['splits'][0]))

print(len(splits_all['splits'][5]['train']))
print(len(splits_all['splits'][5]['val']))
print(len(splits_all['splits'][5]['test']))
print(splits_all['splits'][0]['train'][:40])
print(splits_all['splits'][1]['train'][:40])
print(splits_all['splits'][2]['train'][:10])
print(splits_all['splits'][3]['train'][:10])
# Out:
# 6
# 3
# 7984
# 1996
# 1985
# [0, 3, 4, 5, 6, 8, 9, 10, 11, 12, 13, 15, 16, 17, 18, 19, 21, 22, 23, 24, 25, 27, 29, 33, 35, 36, 37, 38, 39, 42, 43, 44, 45, 46, 47, 48, 51, 52, 54, 55]
# [1, 2, 3, 4, 6, 8, 9, 12, 13, 20, 25, 26, 27, 28, 30, 32, 33, 35, 37, 38, 39, 40, 44, 45, 46, 50, 52, 54, 56, 58, 59, 60, 62, 65, 68, 72, 73, 74, 76, 81]
# [2, 3, 4, 5, 6, 7, 8, 10, 11, 13]
# [1, 2, 4, 7, 9, 10, 12, 13, 14, 15]

# %%
# print(splits_single)
print(len(splits_single['splits'][0]['train']))
print(len(splits_single['splits'][0]['val']))
print(len(splits_single['splits'][0]['test']))
# Out:
# 669
# 167
# 164

# %%
eeg_loaded = torch.load(eeg_dataset)

# %%
print(len(eeg_loaded))
print(eeg_loaded.keys())
dataset, labels, images = [eeg_loaded[k] for k in eeg_loaded.keys()]
print(len(labels))
print(len(images))
print(len(dataset))

print(labels)
print(images[0])
print(dataset[0]['eeg'].shape)
print(dataset[0])
# Out:
# 3
# dict_keys(['dataset', 'labels', 'images'])
# 40
# 1996
# 11965
# ['n02389026', 'n03888257', 'n03584829', 'n02607072', 'n03297495', 'n03063599', 'n03792782', 'n04086273', 'n02510455', 'n11939491', 'n02951358', 'n02281787', 'n02106662', 'n04120489', 'n03590841', 'n02992529', 'n03445777', 'n03180011', 'n02906734', 'n07873807', 'n03773504', 'n02492035', 'n03982430', 'n03709823', 'n03100240', 'n03376595', 'n03877472', 'n03775071', 'n03272010', 'n04069434', 'n03452741', 'n03792972', 'n07753592', 'n13054560', 'n03197337', 'n02504458', 'n02690373', 'n03272562', 'n04044716', 'n02124075']
# n02951358_31190
# torch.Size([128, 500])
# {'eeg': tensor([[-2.9181e-02, -2.9862e-01, -5.1430e-01,  ..., -8.4631e-01,
#          -4.8041e-01, -2.8394e-02],
#         [-2.4111e-02, -1.6960e-01, -2.8707e-01,  ..., -5.6212e-01,
#          -3.2735e-01, -3.5872e-02],
#         [ 4.7802e-02,  3.7646e-01,  6.4149e-01,  ...,  4.3011e-01,
#           2.4678e-01,  4.1414e-02],
#         ...,
#         [ 2.1368e-02,  1.2907e-01,  1.9428e-01,  ...,  7.4598e-01,
#           4.1789e-01, -9.6936e-03],
#         [ 9.9196e-04, -1.1907e-02, -2.2160e-02,  ...,  2.7170e-02,
#           1.5099e-02, -3.4801e-04],
#         [ 2.7840e-03, -3.7217e-02, -7.2385e-02,  ...,  1.1830e-01,
#           6.4887e-02, -6.0881e-03]]), 'image': 0, 'label': 10, 'subject': 4}

# %%
opt = {
    # Dataset options
#     "iv": "image",
#     "offset": None,
    "results_file": "results.pkl",
    "subject": 0,
    "time_low": 20,
    "time_high": 460,
#     "run": "none",
    "eeg_dataset": eeg_dataset,
    "model_type": "model10",
    "splits_path": splits_all_path,
    "split_num": 0,
    "split_name": "train",
#     "fold": 5,
    #Training options
    "batch_size": 16,
    "optim": "Adam",
    "learning_rate": 0.001,
    "weight_decay": 0.001,
    "learning_rate_decay_by": 0.5,
    "learning_rate_decay_every": 10,
    "epochs": 100,
    "GPUindex": 0,
    "kind":"from-scratch",
    #Backend options
    "no_cuda": False,
    "classifier": None
}
opt = argparse.Namespace(**opt)
print(opt.time_low)
# Out:
# 20

# %%
# %load_ext autoreload
# %autoreload 2
from torch.utils.data import DataLoader
# from data_loader import EEGDataset, Splitter, SplitterWithData
from data_loader_CVPR2017 import EEGDataset, Splitter
from EEG_Encoder.LSTM import classifier_LSTM
from EEG_Encoder.CNN import classifier_CNN
from EEG_Encoder.EEGNet import classifier_EEGNet
from EEG_Encoder.SyncNet import classifier_SyncNet
from EEG_Encoder.EEGChannelNet import classifier_EEGChannelNet
from EEG_Encoder.net_generator import Classifier
from EEG_Encoder.net_trainer import net_trainer
from matplotlib import pyplot as plt
from p_values import *
from torchinfo import summary

# %%
def load_dataset(
#              offset,
             eeg_dataset,
             splits_path,
             split_num, # (0-5) - 6 fold cross validation
             split_name,
#              total, 
#              classes,
#              classifier,
             batch_size,
#              GPUindex,
#              length, # 500
#              channel, # 128
#              min_CNN,
             opt,
             kind="from-scratch"):        
    # Load dataset
    dataset = EEGDataset(opt, eeg_dataset)
    print("DONE: LOAD DATASET")
#     # Create loaders for LSTM/MLP/CNN/SCNN/EEGNet/SyncNet/EEGChannelNet
#     if kind=="from-scratch":
#         relabel = False
#     if kind=="incremental":
#         relabel = False
#     if kind=="no-model-file":
#         relabel = True
    splitter = {split: Splitter(dataset,
                    splits_path,
                    split_num,
                    split_name = split) for split in ["train", "val", "test"]}
    loaders = {split: DataLoader(
                        splitter[split],
                        batch_size = batch_size,
                        drop_last = False,
                        shuffle = True)
                    for split in ["train", "val", "test"]}
    channel_idx = None    
    print("DONE: Create loaders for model")            
    return dataset, loaders, splitter

# %%
# Options
opt.classifier = "EEGChannelNet"
opt.batch_size = 16
# opt.kind = "from-scratch"
# opt.run = "imagenet40-1000"
# opt.fold = 5

# %%
dataset, loaders, splitter = load_dataset(
#              offset,
             opt.eeg_dataset,
             opt.splits_path,
             opt.split_num, # (0-5) - 6 fold cross validation
             opt.split_name,
#              total, 
#              classes,
#              classifier,
             opt.batch_size,
#              GPUindex,
#              length, # 500
#              channel, # 128
#              min_CNN,
             opt,
             opt.kind)
# Out:
# DONE: LOAD DATASET
# DONE: Create loaders for model

# %%
# loaders: divide the splits data in each fold with batch_size
# Each fold has {train: 8000 idx, val: 2000 idx, test: 2000 idx}
# Each loader batch has {train: 2000 idx, val: 250 idx, test: 250 idx}
print(type(dataset))
print(type(loaders))
print(len(loaders), [len(loaders[name]) for name in ["train", "val", "test"] ])
for i, (input, target) in enumerate(loaders["train"]):
    if i<20:
        print(f"{i+1}: Target size: {target.size()}; input size: {input.size()}")
for i in range(0, 40):
    eeg, label_val = splitter["val"][i]
    eeg, label_train = splitter["train"][i]
    print(f"{i+1}: Label val: {label_val}; label train: {label_train}")
# Out:
# <class 'data_loader_CVPR2017.EEGDataset'>
# <class 'dict'>
# 3 [498, 125, 125]
# 1: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 2: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 3: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 4: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 5: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 6: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 7: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 8: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 9: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 10: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 11: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 12: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 13: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 14: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 15: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 16: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 17: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 18: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 19: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 20: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 1: Label val: 37; label train: 10
# 2: Label val: 38; label train: 10
# 3: Label val: 11; label train: 30
# 4: Label val: 10; label train: 25
# 5: Label val: 7; label train: 18
# 6: Label val: 35; label train: 3
# 7: Label val: 13; label train: 8
# 8: Label val: 2; label train: 11
# 9: Label val: 14; label train: 18
# 10: Label val: 2; label train: 28
# 11: Label val: 33; label train: 38
# 12: Label val: 26; label train: 20
# 13: Label val: 34; label train: 3
# 14: Label val: 18; label train: 28
# 15: Label val: 11; label train: 23
# 16: Label val: 32; label train: 0
# 17: Label val: 6; label train: 34
# 18: Label val: 22; label train: 20
# 19: Label val: 24; label train: 23
# 20: Label val: 24; label train: 39
# 21: Label val: 29; label train: 0
# 22: Label val: 3; label train: 34
# 23: Label val: 25; label train: 21
# 24: Label val: 11; label train: 39
# 25: Label val: 22; label train: 6
# 26: Label val: 36; label train: 26
# 27: Label val: 30; label train: 20
# 28: Label val: 32; label train: 1
# 29: Label val: 22; label train: 27
# 30: Label val: 39; label train: 37
# 31: Label val: 23; label train: 19
# 32: Label val: 4; label train: 9
# 33: Label val: 10; label train: 12
# 34: Label val: 3; label train: 18
# 35: Label val: 24; label train: 25
# 36: Label val: 27; label train: 27
# 37: Label val: 20; label train: 34
# 38: Label val: 1; label train: 35
# 39: Label val: 38; label train: 8
# 40: Label val: 15; label train: 29

# %%
net, nonclasses = Classifier(
                 n_classes,
                 classes,
                 opt.classifier,
                 opt.GPUindex,
                 length,
                 channel,
                 min_CNN,
                 opt.kind)
# print(len(nonclasses))
summary(net, input_size =(1,128, 440))
# Out:
# [W NNPACK.cpp:53] Could not initialize NNPACK! Reason: Unsupported hardware.
# DONE: CREATE TORCH CLASSIFIER
# classifier_EEGChannelNet(
#   (encoder): FeaturesExtractor(
#     (temporal_block): TemporalBlock(
#       (layers): ModuleList(
#         (0): ConvLayer2D(
#           (norm): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(1, 10, kernel_size=(1, 33), stride=(1, 2), padding=(0, 16))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#         (1): ConvLayer2D(
#           (norm): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(1, 10, kernel_size=(1, 33), stride=(1, 2), padding=(0, 32), dilation=(1, 2))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#         (2): ConvLayer2D(
#           (norm): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(1, 10, kernel_size=(1, 33), stride=(1, 2), padding=(0, 64), dilation=(1, 4))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#         (3): ConvLayer2D(
#           (norm): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(1, 10, kernel_size=(1, 33), stride=(1, 2), padding=(0, 128), dilation=(1, 8))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#       )
#     )
#     (spatial_block): SpatialBlock(
#       (layers): ModuleList(
#         (0): ConvLayer2D(
#           (norm): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(40, 50, kernel_size=(128, 1), stride=(2, 1), padding=(63, 0))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#         (1): ConvLayer2D(
#           (norm): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(40, 50, kernel_size=(64, 1), stride=(2, 1), padding=(31, 0))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#         (2): ConvLayer2D(
#           (norm): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(40, 50, kernel_size=(42, 1), stride=(2, 1), padding=(20, 0))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#         (3): ConvLayer2D(
#           (norm): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(40, 50, kernel_size=(32, 1), stride=(2, 1), padding=(15, 0))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#       )
#     )
#     (res_blocks): ModuleList(
#       (0): Sequential(
#         (0): ResidualBlock(
#           (conv1): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvLayer2D(
#           (norm): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(200, 200, kernel_size=(3, 3), stride=(2, 2))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#       )
#       (1): Sequential(
#         (0): ResidualBlock(
#           (conv1): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvLayer2D(
#           (norm): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(200, 200, kernel_size=(3, 3), stride=(2, 2))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#       )
#       (2): Sequential(
#         (0): ResidualBlock(
#           (conv1): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvLayer2D(
#           (norm): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(200, 200, kernel_size=(3, 3), stride=(2, 2))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#       )
#       (3): Sequential(
#         (0): ResidualBlock(
#           (conv1): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvLayer2D(
#           (norm): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(200, 200, kernel_size=(3, 3), stride=(2, 2))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#       )
#     )
#     (final_conv): ConvLayer2D(
#       (norm): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(200, 50, kernel_size=(3, 3), stride=(1, 1))
#       (drop): Dropout2d(p=0.2, inplace=False)
#     )
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=500, out_features=1000, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=1000, out_features=40, bias=True)
#   )
# )
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# classifier_EEGChannelNet                      [1, 40]                   --
# ├─FeaturesExtractor: 1-1                      [1, 50, 1, 10]            --
# │    └─TemporalBlock: 2-1                     [1, 40, 128, 220]         --
# │    │    └─ModuleList: 3-1                   --                        1,368
# │    └─SpatialBlock: 2-2                      [1, 200, 64, 220]         --
# │    │    └─ModuleList: 3-2                   --                        532,520
# │    └─ModuleList: 2-3                        --                        --
# │    │    └─Sequential: 3-3                   [1, 200, 31, 109]         1,081,400
# │    │    └─Sequential: 3-4                   [1, 200, 15, 54]          1,081,400
# │    │    └─Sequential: 3-5                   [1, 200, 7, 26]           1,081,400
# │    │    └─Sequential: 3-6                   [1, 200, 3, 12]           1,081,400
# │    └─ConvLayer2D: 2-4                       [1, 50, 1, 10]            --
# │    │    └─BatchNorm2d: 3-7                  [1, 200, 3, 12]           400
# │    │    └─ReLU: 3-8                         [1, 200, 3, 12]           --
# │    │    └─Conv2d: 3-9                       [1, 50, 1, 10]            90,050
# │    │    └─Dropout2d: 3-10                   [1, 50, 1, 10]            --
# ├─Sequential: 1-2                             [1, 40]                   --
# │    └─Linear: 2-5                            [1, 1000]                 501,000
# │    └─ReLU: 2-6                              [1, 1000]                 --
# │    └─Linear: 2-7                            [1, 40]                   40,040
# ===============================================================================================
# Total params: 5,490,978
# Trainable params: 5,490,978
# Non-trainable params: 0
# Total mult-adds (G): 22.41
# ===============================================================================================
# Input size (MB): 0.23
# Forward/backward pass size (MB): 224.12
# Params size (MB): 21.96
# Estimated Total Size (MB): 246.30
# ===============================================================================================

# %%
model_path = (   opt.classifier+
                  "-"+
                  str(length)+
                  "-"+
                  str(channel) + "_55_95" +"_test_1" )
results_path = (  "results_"+ opt.classifier+
                  "-"+
                  str(length)+
                  "-"+
                  str(channel)+ "_55_95" +"_test_1"  )
print(model_path)
print(results_path)
# Out:
# EEGChannelNet-440-128_55_95_test_1
# results_EEGChannelNet-440-128_55_95_test_1

# %%
print(opt)
# Out:
# Namespace(results_file='results.pkl', subject=0, time_low=20, time_high=460, eeg_dataset='/media/titan/AI Research1/Data/CVPR2017/eeg_55_95_std.pth', model_type='model10', splits_path='/media/titan/AI Research1/Data/CVPR2017/block_splits_by_image_all.pth', split_num=0, split_name='train', batch_size=16, optim='Adam', learning_rate=0.001, weight_decay=0.001, learning_rate_decay_by=0.5, learning_rate_decay_every=10, epochs=100, GPUindex=0, kind='from-scratch', no_cuda=False, classifier='EEGChannelNet')

# %%
channel_idx=None
non_classes=None
if opt.kind=="from-scratch":
    results = net_trainer(
            net,
            loaders,
            opt,
            channel_idx,
            nonclasses,
            None,
            True,
            model_path)
# Out:
# Epoch 1
# Train Batch 100 (every 100 batch): Loss=3.7180; accuracy=0.0294
# Train Batch 200 (every 100 batch): Loss=3.6966; accuracy=0.0275
# Train Batch 300 (every 100 batch): Loss=3.7598; accuracy=0.0273
# Train Batch 400 (every 100 batch): Loss=3.7002; accuracy=0.0264
# Epoch 1 summary: train_loss: 3.7063 | train_acc: 0.0275 | val_loss: 3.6980 | val_acc: 0.0183
# Epoch 2
# Train Batch 100 (every 100 batch): Loss=3.6919; accuracy=0.0287
# Train Batch 200 (every 100 batch): Loss=3.6821; accuracy=0.0297
# Train Batch 300 (every 100 batch): Loss=3.7057; accuracy=0.0275
# Train Batch 400 (every 100 batch): Loss=3.7037; accuracy=0.0259
# Epoch 2 summary: train_loss: 3.6957 | train_acc: 0.0246 | val_loss: 3.6974 | val_acc: 0.0213
# Epoch 3
# Train Batch 400 (every 100 batch): Loss=3.7077; accuracy=0.0281
# Epoch 3 summary: train_loss: 3.6924 | train_acc: 0.0282 | val_loss: 3.6967 | val_acc: 0.0210
# Epoch 4
# Train Batch 100 (every 100 batch): Loss=3.6868; accuracy=0.0269
# Train Batch 200 (every 100 batch): Loss=3.7108; accuracy=0.0300
# Train Batch 300 (every 100 batch): Loss=3.6873; accuracy=0.0300
# Train Batch 400 (every 100 batch): Loss=3.6943; accuracy=0.0287
# Epoch 4 summary: train_loss: 3.6887 | train_acc: 0.0294 | val_loss: 3.7076 | val_acc: 0.0160
# Epoch 5
# Train Batch 100 (every 100 batch): Loss=3.7325; accuracy=0.0281
# Train Batch 200 (every 100 batch): Loss=3.6696; accuracy=0.0237
# Train Batch 300 (every 100 batch): Loss=3.6994; accuracy=0.0231
# Train Batch 400 (every 100 batch): Loss=3.6638; accuracy=0.0247
# Epoch 5 summary: train_loss: 3.6901 | train_acc: 0.0255 | val_loss: 3.7024 | val_acc: 0.0143
# Epoch 6
# Train Batch 100 (every 100 batch): Loss=3.6770; accuracy=0.0256
# Train Batch 200 (every 100 batch): Loss=3.6882; accuracy=0.0269
# Train Batch 300 (every 100 batch): Loss=3.7149; accuracy=0.0254
# Train Batch 400 (every 100 batch): Loss=3.6404; accuracy=0.0264
# Epoch 6 summary: train_loss: 3.6868 | train_acc: 0.0275 | val_loss: 3.7067 | val_acc: 0.0180
# Epoch 7
# Train Batch 100 (every 100 batch): Loss=3.6679; accuracy=0.0256
# Train Batch 200 (every 100 batch): Loss=3.6923; accuracy=0.0281
# Train Batch 300 (every 100 batch): Loss=3.6627; accuracy=0.0290
# Train Batch 400 (every 100 batch): Loss=3.6828; accuracy=0.0298
# Epoch 7 summary: train_loss: 3.6863 | train_acc: 0.0297 | val_loss: 3.7086 | val_acc: 0.0180
# Epoch 8
# Train Batch 100 (every 100 batch): Loss=3.6810; accuracy=0.0356
# Train Batch 200 (every 100 batch): Loss=3.6592; accuracy=0.0319
# Train Batch 300 (every 100 batch): Loss=3.6576; accuracy=0.0302
# Train Batch 400 (every 100 batch): Loss=3.6884; accuracy=0.0292
# Epoch 8 summary: train_loss: 3.6851 | train_acc: 0.0292 | val_loss: 3.7015 | val_acc: 0.0215
# Epoch 9
# Train Batch 100 (every 100 batch): Loss=3.6687; accuracy=0.0319
# Train Batch 200 (every 100 batch): Loss=3.6805; accuracy=0.0322
# Train Batch 300 (every 100 batch): Loss=3.6940; accuracy=0.0315
# Train Batch 400 (every 100 batch): Loss=3.6501; accuracy=0.0305
# Epoch 9 summary: train_loss: 3.6846 | train_acc: 0.0307 | val_loss: 3.7030 | val_acc: 0.0250
# Epoch 10
# Train Batch 100 (every 100 batch): Loss=3.7421; accuracy=0.0312
# Train Batch 200 (every 100 batch): Loss=3.5357; accuracy=0.0316
# Train Batch 300 (every 100 batch): Loss=3.7032; accuracy=0.0350
# Train Batch 400 (every 100 batch): Loss=3.7401; accuracy=0.0352
# Epoch 10 summary: train_loss: 3.6547 | train_acc: 0.0358 | val_loss: 3.6627 | val_acc: 0.0305
# Epoch 11
# Train Batch 100 (every 100 batch): Loss=3.5864; accuracy=0.0344
# Train Batch 200 (every 100 batch): Loss=3.8119; accuracy=0.0328
# Train Batch 300 (every 100 batch): Loss=3.6629; accuracy=0.0315
# Train Batch 400 (every 100 batch): Loss=3.6324; accuracy=0.0339
# Epoch 11 summary: train_loss: 3.6220 | train_acc: 0.0359 | val_loss: 3.6151 | val_acc: 0.0325
# Epoch 12
# Train Batch 100 (every 100 batch): Loss=3.5662; accuracy=0.0412
# Train Batch 200 (every 100 batch): Loss=3.5883; accuracy=0.0487
# Train Batch 300 (every 100 batch): Loss=3.3634; accuracy=0.0525
# Train Batch 400 (every 100 batch): Loss=3.3133; accuracy=0.0564
# Epoch 12 summary: train_loss: 3.3860 | train_acc: 0.0570 | val_loss: 3.2625 | val_acc: 0.0623
# Epoch 13
# Train Batch 100 (every 100 batch): Loss=3.1072; accuracy=0.0869
# Train Batch 200 (every 100 batch): Loss=3.1056; accuracy=0.0847
# Train Batch 300 (every 100 batch): Loss=3.1067; accuracy=0.0856
# Train Batch 400 (every 100 batch): Loss=2.8406; accuracy=0.0889
# Epoch 13 summary: train_loss: 3.0436 | train_acc: 0.0925 | val_loss: 2.8449 | val_acc: 0.1004
# Epoch 14
# Train Batch 100 (every 100 batch): Loss=2.6049; accuracy=0.1100
# Train Batch 200 (every 100 batch): Loss=2.6026; accuracy=0.1156
# Train Batch 300 (every 100 batch): Loss=2.6972; accuracy=0.1185
# Train Batch 400 (every 100 batch): Loss=2.5793; accuracy=0.1175
# Epoch 14 summary: train_loss: 2.7728 | train_acc: 0.1193 | val_loss: 2.6066 | val_acc: 0.1363
# Epoch 15
# Train Batch 100 (every 100 batch): Loss=2.7020; accuracy=0.1350
# Train Batch 200 (every 100 batch): Loss=2.4811; accuracy=0.1491
# Train Batch 300 (every 100 batch): Loss=1.9839; accuracy=0.1569
# Train Batch 400 (every 100 batch): Loss=2.6859; accuracy=0.1630
# Epoch 15 summary: train_loss: 2.5423 | train_acc: 0.1639 | val_loss: 2.3552 | val_acc: 0.1915
# Epoch 16
# Train Batch 100 (every 100 batch): Loss=2.5294; accuracy=0.1812
# Train Batch 200 (every 100 batch): Loss=1.9416; accuracy=0.1753
# Train Batch 300 (every 100 batch): Loss=2.2315; accuracy=0.1794
# Train Batch 400 (every 100 batch): Loss=2.3168; accuracy=0.1880
# Epoch 16 summary: train_loss: 2.3678 | train_acc: 0.1870 | val_loss: 2.2694 | val_acc: 0.1898
# Epoch 17
# Train Batch 100 (every 100 batch): Loss=2.2605; accuracy=0.2119
# Train Batch 200 (every 100 batch): Loss=2.6811; accuracy=0.2128
# Train Batch 300 (every 100 batch): Loss=2.0627; accuracy=0.2123
# Train Batch 400 (every 100 batch): Loss=2.3885; accuracy=0.2130
# Epoch 17 summary: train_loss: 2.2239 | train_acc: 0.2123 | val_loss: 2.1882 | val_acc: 0.2214
# Epoch 18
# Train Batch 100 (every 100 batch): Loss=2.9715; accuracy=0.2338
# Train Batch 200 (every 100 batch): Loss=2.1179; accuracy=0.2250
# Train Batch 300 (every 100 batch): Loss=2.2929; accuracy=0.2325
# Train Batch 400 (every 100 batch): Loss=2.2968; accuracy=0.2303
# Epoch 18 summary: train_loss: 2.1343 | train_acc: 0.2359 | val_loss: 2.1441 | val_acc: 0.2464
# Epoch 19
# Train Batch 100 (every 100 batch): Loss=2.0111; accuracy=0.2550
# Train Batch 200 (every 100 batch): Loss=1.8831; accuracy=0.2587
# Train Batch 300 (every 100 batch): Loss=2.0305; accuracy=0.2531
# Train Batch 400 (every 100 batch): Loss=1.7089; accuracy=0.2525
# Epoch 19 summary: train_loss: 2.0470 | train_acc: 0.2541 | val_loss: 2.0621 | val_acc: 0.2526
# Epoch 20
# Train Batch 100 (every 100 batch): Loss=1.8760; accuracy=0.2819
# Train Batch 200 (every 100 batch): Loss=1.9010; accuracy=0.2694
# Train Batch 300 (every 100 batch): Loss=1.6660; accuracy=0.2710
# Train Batch 400 (every 100 batch): Loss=2.0939; accuracy=0.2747
# Epoch 20 summary: train_loss: 1.9682 | train_acc: 0.2729 | val_loss: 1.9215 | val_acc: 0.2964
# Epoch 21
# Train Batch 100 (every 100 batch): Loss=1.9126; accuracy=0.2887
# Train Batch 200 (every 100 batch): Loss=1.7963; accuracy=0.2937
# Train Batch 300 (every 100 batch): Loss=1.8325; accuracy=0.2862
# Train Batch 400 (every 100 batch): Loss=1.9933; accuracy=0.2905
# Epoch 21 summary: train_loss: 1.9099 | train_acc: 0.2937 | val_loss: 1.9057 | val_acc: 0.2985
# Epoch 22
# Train Batch 100 (every 100 batch): Loss=1.6516; accuracy=0.3100
# Train Batch 200 (every 100 batch): Loss=1.6336; accuracy=0.3094
# Train Batch 300 (every 100 batch): Loss=1.8396; accuracy=0.3071
# Train Batch 400 (every 100 batch): Loss=1.6330; accuracy=0.3056
# Epoch 22 summary: train_loss: 1.8515 | train_acc: 0.3104 | val_loss: 1.8521 | val_acc: 0.3017
# Epoch 23
# Train Batch 100 (every 100 batch): Loss=2.1812; accuracy=0.3256
# Train Batch 200 (every 100 batch): Loss=1.9376; accuracy=0.3237
# Train Batch 300 (every 100 batch): Loss=1.7170; accuracy=0.3227
# Train Batch 400 (every 100 batch): Loss=1.7313; accuracy=0.3217
# Epoch 23 summary: train_loss: 1.8010 | train_acc: 0.3226 | val_loss: 1.8783 | val_acc: 0.3157
# Epoch 24
# Train Batch 100 (every 100 batch): Loss=1.7834; accuracy=0.3431
# Train Batch 200 (every 100 batch): Loss=1.2531; accuracy=0.3250
# Train Batch 300 (every 100 batch): Loss=1.8090; accuracy=0.3252
# Train Batch 400 (every 100 batch): Loss=2.3103; accuracy=0.3287
# Epoch 24 summary: train_loss: 1.7549 | train_acc: 0.3309 | val_loss: 1.8453 | val_acc: 0.3431
# Epoch 25
# Train Batch 100 (every 100 batch): Loss=1.5793; accuracy=0.3344
# Train Batch 200 (every 100 batch): Loss=1.5486; accuracy=0.3516
# Train Batch 300 (every 100 batch): Loss=1.6837; accuracy=0.3527
# Train Batch 400 (every 100 batch): Loss=2.1690; accuracy=0.3478
# Epoch 25 summary: train_loss: 1.7084 | train_acc: 0.3478 | val_loss: 1.9066 | val_acc: 0.3159
# Epoch 26
# Train Batch 100 (every 100 batch): Loss=1.8063; accuracy=0.3625
# Train Batch 200 (every 100 batch): Loss=1.7959; accuracy=0.3656
# Train Batch 300 (every 100 batch): Loss=1.7654; accuracy=0.3675
# Train Batch 400 (every 100 batch): Loss=1.9018; accuracy=0.3597
# Epoch 26 summary: train_loss: 1.6755 | train_acc: 0.3588 | val_loss: 1.7875 | val_acc: 0.3186
# Epoch 27
# Train Batch 100 (every 100 batch): Loss=1.6576; accuracy=0.3631
# Train Batch 200 (every 100 batch): Loss=1.3850; accuracy=0.3659
# Train Batch 300 (every 100 batch): Loss=1.5696; accuracy=0.3658
# Train Batch 400 (every 100 batch): Loss=1.2473; accuracy=0.3670
# Epoch 27 summary: train_loss: 1.6347 | train_acc: 0.3696 | val_loss: 1.7944 | val_acc: 0.3616
# Epoch 28
# Train Batch 100 (every 100 batch): Loss=1.5215; accuracy=0.3844
# Train Batch 200 (every 100 batch): Loss=1.6791; accuracy=0.3872
# Train Batch 300 (every 100 batch): Loss=2.0331; accuracy=0.3863
# Train Batch 400 (every 100 batch): Loss=1.9099; accuracy=0.3837
# Epoch 28 summary: train_loss: 1.6043 | train_acc: 0.3808 | val_loss: 1.7818 | val_acc: 0.3485
# Epoch 29
# Train Batch 100 (every 100 batch): Loss=1.6874; accuracy=0.3844
# Train Batch 200 (every 100 batch): Loss=1.0961; accuracy=0.3922
# Train Batch 300 (every 100 batch): Loss=1.5260; accuracy=0.3863
# Train Batch 400 (every 100 batch): Loss=1.5993; accuracy=0.3858
# Epoch 29 summary: train_loss: 1.5663 | train_acc: 0.3861 | val_loss: 1.6856 | val_acc: 0.3659
# Epoch 30
# Train Batch 100 (every 100 batch): Loss=1.4989; accuracy=0.4025
# Train Batch 200 (every 100 batch): Loss=1.3545; accuracy=0.4044
# Train Batch 300 (every 100 batch): Loss=1.4668; accuracy=0.3923
# Train Batch 400 (every 100 batch): Loss=1.7525; accuracy=0.3986
# Epoch 30 summary: train_loss: 1.5360 | train_acc: 0.3992 | val_loss: 1.7273 | val_acc: 0.3651
# Epoch 31
# Train Batch 100 (every 100 batch): Loss=1.4707; accuracy=0.4269
# Train Batch 200 (every 100 batch): Loss=2.0253; accuracy=0.4184
# Train Batch 300 (every 100 batch): Loss=1.7011; accuracy=0.4148
# Train Batch 400 (every 100 batch): Loss=2.1657; accuracy=0.4109
# Epoch 31 summary: train_loss: 1.5042 | train_acc: 0.4101 | val_loss: 1.7681 | val_acc: 0.3684
# Epoch 32
# Train Batch 100 (every 100 batch): Loss=1.5652; accuracy=0.4075
# Train Batch 200 (every 100 batch): Loss=1.4913; accuracy=0.4172
# Train Batch 300 (every 100 batch): Loss=1.6150; accuracy=0.4188
# Train Batch 400 (every 100 batch): Loss=1.8141; accuracy=0.4219
# Epoch 32 summary: train_loss: 1.4841 | train_acc: 0.4223 | val_loss: 1.6732 | val_acc: 0.3857
# Epoch 33
# Train Batch 100 (every 100 batch): Loss=0.9921; accuracy=0.4281
# Train Batch 200 (every 100 batch): Loss=1.4898; accuracy=0.4344
# Train Batch 300 (every 100 batch): Loss=1.2598; accuracy=0.4335
# Train Batch 400 (every 100 batch): Loss=1.8430; accuracy=0.4352
# Epoch 33 summary: train_loss: 1.4578 | train_acc: 0.4343 | val_loss: 1.6790 | val_acc: 0.4084
# Epoch 34
# Train Batch 100 (every 100 batch): Loss=1.2919; accuracy=0.4606
# Train Batch 200 (every 100 batch): Loss=1.9559; accuracy=0.4419
# Train Batch 300 (every 100 batch): Loss=1.4288; accuracy=0.4431
# Train Batch 400 (every 100 batch): Loss=1.3270; accuracy=0.4466
# Epoch 34 summary: train_loss: 1.4337 | train_acc: 0.4440 | val_loss: 1.6956 | val_acc: 0.3957
# Epoch 35
# Train Batch 100 (every 100 batch): Loss=1.4552; accuracy=0.4444
# Train Batch 200 (every 100 batch): Loss=1.8110; accuracy=0.4581
# Train Batch 300 (every 100 batch): Loss=1.5457; accuracy=0.4488
# Train Batch 400 (every 100 batch): Loss=1.1085; accuracy=0.4497
# Epoch 35 summary: train_loss: 1.4131 | train_acc: 0.4508 | val_loss: 1.7067 | val_acc: 0.4285
# Epoch 36
# Train Batch 100 (every 100 batch): Loss=1.3373; accuracy=0.4737
# Train Batch 200 (every 100 batch): Loss=1.3803; accuracy=0.4772
# Train Batch 300 (every 100 batch): Loss=1.2025; accuracy=0.4742
# Train Batch 400 (every 100 batch): Loss=1.3046; accuracy=0.4688
# Epoch 36 summary: train_loss: 1.3747 | train_acc: 0.4646 | val_loss: 1.6929 | val_acc: 0.4103
# Epoch 37
# Train Batch 100 (every 100 batch): Loss=1.5331; accuracy=0.4694
# Train Batch 200 (every 100 batch): Loss=1.2588; accuracy=0.4634
# Train Batch 300 (every 100 batch): Loss=1.1635; accuracy=0.4654
# Train Batch 400 (every 100 batch): Loss=1.3886; accuracy=0.4648
# Epoch 37 summary: train_loss: 1.3633 | train_acc: 0.4624 | val_loss: 1.6209 | val_acc: 0.4290
# Epoch 38
# Train Batch 100 (every 100 batch): Loss=1.7139; accuracy=0.4869
# Train Batch 200 (every 100 batch): Loss=1.4541; accuracy=0.4909
# Train Batch 300 (every 100 batch): Loss=1.2753; accuracy=0.4825
# Train Batch 400 (every 100 batch): Loss=1.1887; accuracy=0.4772
# Epoch 38 summary: train_loss: 1.3267 | train_acc: 0.4758 | val_loss: 1.6247 | val_acc: 0.4149
# Epoch 39
# Train Batch 100 (every 100 batch): Loss=0.9897; accuracy=0.4919
# Train Batch 200 (every 100 batch): Loss=1.1901; accuracy=0.4925
# Train Batch 300 (every 100 batch): Loss=1.6708; accuracy=0.4852
# Train Batch 400 (every 100 batch): Loss=1.1678; accuracy=0.4909
# Epoch 39 summary: train_loss: 1.3103 | train_acc: 0.4854 | val_loss: 1.6832 | val_acc: 0.4169
# Epoch 40
# Train Batch 100 (every 100 batch): Loss=1.0602; accuracy=0.5219
# Train Batch 200 (every 100 batch): Loss=1.5042; accuracy=0.4994
# Train Batch 300 (every 100 batch): Loss=0.9944; accuracy=0.4992
# Train Batch 400 (every 100 batch): Loss=1.5526; accuracy=0.4947
# Epoch 40 summary: train_loss: 1.3106 | train_acc: 0.4919 | val_loss: 1.6651 | val_acc: 0.4246
# Epoch 41
# Train Batch 100 (every 100 batch): Loss=1.1718; accuracy=0.5069
# Train Batch 200 (every 100 batch): Loss=1.4700; accuracy=0.5106
# Train Batch 300 (every 100 batch): Loss=0.8246; accuracy=0.5044
# Train Batch 400 (every 100 batch): Loss=0.9565; accuracy=0.5014
# Epoch 41 summary: train_loss: 1.2698 | train_acc: 0.5034 | val_loss: 1.7739 | val_acc: 0.4089
# Epoch 42
# Train Batch 100 (every 100 batch): Loss=1.1987; accuracy=0.5081
# Train Batch 200 (every 100 batch): Loss=1.6168; accuracy=0.5075
# Train Batch 300 (every 100 batch): Loss=1.3809; accuracy=0.5002
# Train Batch 400 (every 100 batch): Loss=1.0643; accuracy=0.4984
# Epoch 42 summary: train_loss: 1.2681 | train_acc: 0.4983 | val_loss: 1.6549 | val_acc: 0.4522
# Epoch 43
# Train Batch 100 (every 100 batch): Loss=1.3727; accuracy=0.5188
# Train Batch 200 (every 100 batch): Loss=0.9574; accuracy=0.5188
# Train Batch 300 (every 100 batch): Loss=1.3163; accuracy=0.5146
# Train Batch 400 (every 100 batch): Loss=1.1571; accuracy=0.5122
# Epoch 43 summary: train_loss: 1.2453 | train_acc: 0.5116 | val_loss: 1.7467 | val_acc: 0.4220
# Epoch 44
# Train Batch 100 (every 100 batch): Loss=1.2892; accuracy=0.5231
# Train Batch 200 (every 100 batch): Loss=0.7374; accuracy=0.5184
# Train Batch 300 (every 100 batch): Loss=0.9896; accuracy=0.5165
# Train Batch 400 (every 100 batch): Loss=0.8826; accuracy=0.5141
# Epoch 44 summary: train_loss: 1.2308 | train_acc: 0.5114 | val_loss: 1.6514 | val_acc: 0.4510
# Epoch 45
# Train Batch 100 (every 100 batch): Loss=1.7282; accuracy=0.5256
# Train Batch 200 (every 100 batch): Loss=1.3952; accuracy=0.5297
# Train Batch 300 (every 100 batch): Loss=1.4219; accuracy=0.5281
# Train Batch 400 (every 100 batch): Loss=1.0493; accuracy=0.5280
# Epoch 45 summary: train_loss: 1.1901 | train_acc: 0.5292 | val_loss: 1.6824 | val_acc: 0.4323
# Epoch 46
# Train Batch 100 (every 100 batch): Loss=1.0578; accuracy=0.5556
# Train Batch 200 (every 100 batch): Loss=1.1084; accuracy=0.5481
# Train Batch 300 (every 100 batch): Loss=1.7008; accuracy=0.5477
# Train Batch 400 (every 100 batch): Loss=0.9725; accuracy=0.5412
# Epoch 46 summary: train_loss: 1.1703 | train_acc: 0.5418 | val_loss: 1.7788 | val_acc: 0.4474
# Epoch 47
# Train Batch 100 (every 100 batch): Loss=1.5815; accuracy=0.5600
# Train Batch 200 (every 100 batch): Loss=1.2283; accuracy=0.5481
# Train Batch 300 (every 100 batch): Loss=0.7742; accuracy=0.5477
# Train Batch 400 (every 100 batch): Loss=1.1248; accuracy=0.5436
# Epoch 47 summary: train_loss: 1.1733 | train_acc: 0.5389 | val_loss: 1.8066 | val_acc: 0.4314
# Epoch 48
# Train Batch 100 (every 100 batch): Loss=1.4166; accuracy=0.5606
# Train Batch 200 (every 100 batch): Loss=0.8864; accuracy=0.5591
# Train Batch 300 (every 100 batch): Loss=1.3581; accuracy=0.5523
# Train Batch 400 (every 100 batch): Loss=1.1381; accuracy=0.5444
# Epoch 48 summary: train_loss: 1.1502 | train_acc: 0.5449 | val_loss: 1.6903 | val_acc: 0.4477
# Epoch 49
# Train Batch 100 (every 100 batch): Loss=1.0411; accuracy=0.5425
# Train Batch 200 (every 100 batch): Loss=1.1843; accuracy=0.5419
# Train Batch 300 (every 100 batch): Loss=1.2096; accuracy=0.5500
# Train Batch 400 (every 100 batch): Loss=1.3762; accuracy=0.5442
# Epoch 49 summary: train_loss: 1.1534 | train_acc: 0.5447 | val_loss: 1.7141 | val_acc: 0.4552
# Epoch 50
# Train Batch 100 (every 100 batch): Loss=1.3714; accuracy=0.5838
# Train Batch 200 (every 100 batch): Loss=1.0814; accuracy=0.5694
# Train Batch 300 (every 100 batch): Loss=1.3975; accuracy=0.5623
# Train Batch 400 (every 100 batch): Loss=0.8457; accuracy=0.5631
# Epoch 50 summary: train_loss: 1.1148 | train_acc: 0.5612 | val_loss: 1.7961 | val_acc: 0.4370
# Epoch 51
# Train Batch 100 (every 100 batch): Loss=0.9682; accuracy=0.5687
# Train Batch 200 (every 100 batch): Loss=0.7985; accuracy=0.5600
# Train Batch 300 (every 100 batch): Loss=0.9774; accuracy=0.5650
# Train Batch 400 (every 100 batch): Loss=1.2459; accuracy=0.5612
# Epoch 51 summary: train_loss: 1.0937 | train_acc: 0.5636 | val_loss: 1.6231 | val_acc: 0.4561
# Epoch 52
# Train Batch 100 (every 100 batch): Loss=1.2227; accuracy=0.5981
# Train Batch 200 (every 100 batch): Loss=1.1744; accuracy=0.5869
# Train Batch 300 (every 100 batch): Loss=1.1560; accuracy=0.5817
# Train Batch 400 (every 100 batch): Loss=1.7646; accuracy=0.5795
# Train Batch 300 (every 100 batch): Loss=1.1098; accuracy=0.5838
# Train Batch 400 (every 100 batch): Loss=0.7898; accuracy=0.5847
# Epoch 53 summary: train_loss: 1.0667 | train_acc: 0.5764 | val_loss: 1.7173 | val_acc: 0.4485
# Epoch 54
# Train Batch 100 (every 100 batch): Loss=1.3207; accuracy=0.6031
# Train Batch 200 (every 100 batch): Loss=1.1874; accuracy=0.6009
# Train Batch 300 (every 100 batch): Loss=0.8432; accuracy=0.6017
# Train Batch 400 (every 100 batch): Loss=1.1518; accuracy=0.5961
# Epoch 54 summary: train_loss: 1.0307 | train_acc: 0.5982 | val_loss: 1.7916 | val_acc: 0.4728
# Epoch 55
# Train Batch 100 (every 100 batch): Loss=1.2517; accuracy=0.5987
# Train Batch 200 (every 100 batch): Loss=0.7903; accuracy=0.6069
# Train Batch 300 (every 100 batch): Loss=1.1780; accuracy=0.5969
# Train Batch 400 (every 100 batch): Loss=0.7043; accuracy=0.5987
# Epoch 55 summary: train_loss: 1.0365 | train_acc: 0.5996 | val_loss: 1.7122 | val_acc: 0.4609
# Epoch 56
# Train Batch 100 (every 100 batch): Loss=0.7749; accuracy=0.6331
# Train Batch 200 (every 100 batch): Loss=1.4632; accuracy=0.6128
# Train Batch 300 (every 100 batch): Loss=0.9981; accuracy=0.6100
# Train Batch 400 (every 100 batch): Loss=0.9738; accuracy=0.6087
# Epoch 56 summary: train_loss: 1.0140 | train_acc: 0.6047 | val_loss: 1.6749 | val_acc: 0.4695
# Epoch 57
# Train Batch 100 (every 100 batch): Loss=0.9001; accuracy=0.6344
# Train Batch 200 (every 100 batch): Loss=1.3342; accuracy=0.6297
# Train Batch 300 (every 100 batch): Loss=0.9190; accuracy=0.6242
# Train Batch 400 (every 100 batch): Loss=1.0468; accuracy=0.6141
# Epoch 57 summary: train_loss: 0.9966 | train_acc: 0.6075 | val_loss: 1.8365 | val_acc: 0.4531
# Epoch 58
# Train Batch 100 (every 100 batch): Loss=1.0231; accuracy=0.6244
# Train Batch 200 (every 100 batch): Loss=0.8827; accuracy=0.6212
# Train Batch 300 (every 100 batch): Loss=0.8384; accuracy=0.6190
# Train Batch 400 (every 100 batch): Loss=1.3014; accuracy=0.6191
# Epoch 58 summary: train_loss: 0.9764 | train_acc: 0.6200 | val_loss: 1.8692 | val_acc: 0.4512
# Epoch 59
# Train Batch 100 (every 100 batch): Loss=0.5928; accuracy=0.6231
# Train Batch 200 (every 100 batch): Loss=0.7044; accuracy=0.6203
# Train Batch 300 (every 100 batch): Loss=0.9955; accuracy=0.6177
# Train Batch 400 (every 100 batch): Loss=0.8225; accuracy=0.6195
# Epoch 59 summary: train_loss: 0.9658 | train_acc: 0.6201 | val_loss: 1.8788 | val_acc: 0.4579
# Epoch 60
# Train Batch 100 (every 100 batch): Loss=1.0294; accuracy=0.6187
# Train Batch 200 (every 100 batch): Loss=0.9279; accuracy=0.6303
# Train Batch 300 (every 100 batch): Loss=0.7722; accuracy=0.6306
# Train Batch 400 (every 100 batch): Loss=0.6130; accuracy=0.6292
# Epoch 60 summary: train_loss: 0.9441 | train_acc: 0.6308 | val_loss: 1.7714 | val_acc: 0.4978
# Epoch 61
# Train Batch 100 (every 100 batch): Loss=0.4647; accuracy=0.6494
# Train Batch 200 (every 100 batch): Loss=1.0559; accuracy=0.6453
# Train Batch 300 (every 100 batch): Loss=0.7333; accuracy=0.6446
# Train Batch 400 (every 100 batch): Loss=0.8854; accuracy=0.6392
# Epoch 61 summary: train_loss: 0.9446 | train_acc: 0.6359 | val_loss: 1.8190 | val_acc: 0.4672
# Epoch 62
# Train Batch 100 (every 100 batch): Loss=1.1689; accuracy=0.6644
# Train Batch 200 (every 100 batch): Loss=0.9300; accuracy=0.6641
# Train Batch 300 (every 100 batch): Loss=0.8221; accuracy=0.6575
# Train Batch 400 (every 100 batch): Loss=0.4433; accuracy=0.6503
# Epoch 62 summary: train_loss: 0.9120 | train_acc: 0.6482 | val_loss: 1.8496 | val_acc: 0.4818
# Epoch 63
# Train Batch 100 (every 100 batch): Loss=1.1977; accuracy=0.6531
# Train Batch 200 (every 100 batch): Loss=0.7650; accuracy=0.6562
# Train Batch 300 (every 100 batch): Loss=0.8173; accuracy=0.6623
# Train Batch 400 (every 100 batch): Loss=0.6504; accuracy=0.6598
# Epoch 63 summary: train_loss: 0.8925 | train_acc: 0.6546 | val_loss: 1.7346 | val_acc: 0.4656
# Epoch 64
# Train Batch 100 (every 100 batch): Loss=0.9257; accuracy=0.6438
# Train Batch 200 (every 100 batch): Loss=1.1045; accuracy=0.6481
# Train Batch 300 (every 100 batch): Loss=0.8377; accuracy=0.6513
# Train Batch 400 (every 100 batch): Loss=1.0279; accuracy=0.6494
# Epoch 64 summary: train_loss: 0.9037 | train_acc: 0.6473 | val_loss: 1.8540 | val_acc: 0.4665
# Epoch 65
# Train Batch 100 (every 100 batch): Loss=0.8705; accuracy=0.6725
# Train Batch 200 (every 100 batch): Loss=1.0263; accuracy=0.6675
# Train Batch 300 (every 100 batch): Loss=1.0055; accuracy=0.6681
# Train Batch 400 (every 100 batch): Loss=0.6993; accuracy=0.6656
# Epoch 65 summary: train_loss: 0.8740 | train_acc: 0.6620 | val_loss: 1.8949 | val_acc: 0.4783
# Epoch 66
# Train Batch 100 (every 100 batch): Loss=0.6070; accuracy=0.6687
# Train Batch 200 (every 100 batch): Loss=0.8653; accuracy=0.6741
# Train Batch 300 (every 100 batch): Loss=0.8483; accuracy=0.6662
# Train Batch 400 (every 100 batch): Loss=0.8734; accuracy=0.6636
# Epoch 66 summary: train_loss: 0.8577 | train_acc: 0.6651 | val_loss: 1.8762 | val_acc: 0.4672
# Epoch 67
# Train Batch 100 (every 100 batch): Loss=1.1224; accuracy=0.6887
# Train Batch 200 (every 100 batch): Loss=0.6171; accuracy=0.6859
# Train Batch 300 (every 100 batch): Loss=0.9453; accuracy=0.6788
# Train Batch 400 (every 100 batch): Loss=1.1451; accuracy=0.6762
# Epoch 67 summary: train_loss: 0.8443 | train_acc: 0.6784 | val_loss: 1.8494 | val_acc: 0.4665
# Epoch 68
# Train Batch 100 (every 100 batch): Loss=0.7148; accuracy=0.6950
# Train Batch 200 (every 100 batch): Loss=1.0657; accuracy=0.6828
# Train Batch 300 (every 100 batch): Loss=1.2543; accuracy=0.6792
# Train Batch 400 (every 100 batch): Loss=1.0384; accuracy=0.6734
# Epoch 68 summary: train_loss: 0.8350 | train_acc: 0.6715 | val_loss: 1.8420 | val_acc: 0.4846
# Epoch 69
# Train Batch 100 (every 100 batch): Loss=0.7413; accuracy=0.6981
# Train Batch 200 (every 100 batch): Loss=0.7900; accuracy=0.6987
# Train Batch 300 (every 100 batch): Loss=0.6355; accuracy=0.7023
# Train Batch 400 (every 100 batch): Loss=0.4355; accuracy=0.6952
# Epoch 69 summary: train_loss: 0.7948 | train_acc: 0.6937 | val_loss: 1.9156 | val_acc: 0.4901
# Epoch 70
# Train Batch 100 (every 100 batch): Loss=0.6699; accuracy=0.7025
# Train Batch 200 (every 100 batch): Loss=0.5728; accuracy=0.7034
# Train Batch 300 (every 100 batch): Loss=0.7471; accuracy=0.7002
# Train Batch 400 (every 100 batch): Loss=0.8794; accuracy=0.7002
# Epoch 70 summary: train_loss: 0.7861 | train_acc: 0.6970 | val_loss: 2.0890 | val_acc: 0.4785
# Epoch 71
# Train Batch 100 (every 100 batch): Loss=0.8059; accuracy=0.7231
# Train Batch 200 (every 100 batch): Loss=0.5502; accuracy=0.7066
# Train Batch 300 (every 100 batch): Loss=0.5739; accuracy=0.7013
# Train Batch 400 (every 100 batch): Loss=0.7651; accuracy=0.7012
# Epoch 71 summary: train_loss: 0.7981 | train_acc: 0.6934 | val_loss: 1.9516 | val_acc: 0.4757
# Epoch 72
# Train Batch 100 (every 100 batch): Loss=1.1145; accuracy=0.7325
# Train Batch 200 (every 100 batch): Loss=0.5888; accuracy=0.7141
# Train Batch 300 (every 100 batch): Loss=0.7556; accuracy=0.7115
# Train Batch 400 (every 100 batch): Loss=1.0166; accuracy=0.7139
# Epoch 72 summary: train_loss: 0.7604 | train_acc: 0.7107 | val_loss: 1.9822 | val_acc: 0.4645
# Epoch 73
# Train Batch 100 (every 100 batch): Loss=0.4080; accuracy=0.7231
# Train Batch 200 (every 100 batch): Loss=1.0916; accuracy=0.7250
# Train Batch 300 (every 100 batch): Loss=1.0008; accuracy=0.7204
# Train Batch 400 (every 100 batch): Loss=0.5940; accuracy=0.7166
# Epoch 73 summary: train_loss: 0.7444 | train_acc: 0.7142 | val_loss: 2.0319 | val_acc: 0.4723
# Epoch 74
# Train Batch 100 (every 100 batch): Loss=0.6930; accuracy=0.7106
# Train Batch 200 (every 100 batch): Loss=0.7274; accuracy=0.7253
# Train Batch 300 (every 100 batch): Loss=0.3367; accuracy=0.7244
# Train Batch 400 (every 100 batch): Loss=1.0040; accuracy=0.7236
# Epoch 74 summary: train_loss: 0.7445 | train_acc: 0.7186 | val_loss: 2.0601 | val_acc: 0.4675
# Epoch 75
# Train Batch 100 (every 100 batch): Loss=0.4753; accuracy=0.7156
# Train Batch 200 (every 100 batch): Loss=0.5219; accuracy=0.7138
# Train Batch 300 (every 100 batch): Loss=0.7031; accuracy=0.7246
# Train Batch 400 (every 100 batch): Loss=0.7754; accuracy=0.7214
# Epoch 75 summary: train_loss: 0.7410 | train_acc: 0.7219 | val_loss: 2.1319 | val_acc: 0.4755
# Epoch 76
# Train Batch 100 (every 100 batch): Loss=0.5069; accuracy=0.7475
# Train Batch 200 (every 100 batch): Loss=0.7204; accuracy=0.7334
# Train Batch 300 (every 100 batch): Loss=0.9849; accuracy=0.7327
# Train Batch 400 (every 100 batch): Loss=0.5352; accuracy=0.7283
# Epoch 76 summary: train_loss: 0.7206 | train_acc: 0.7273 | val_loss: 1.9431 | val_acc: 0.4758
# Epoch 77
# Train Batch 100 (every 100 batch): Loss=0.9161; accuracy=0.7481
# Train Batch 200 (every 100 batch): Loss=0.6960; accuracy=0.7306
# Train Batch 300 (every 100 batch): Loss=0.6483; accuracy=0.7310
# Train Batch 400 (every 100 batch): Loss=0.6096; accuracy=0.7333
# Epoch 77 summary: train_loss: 0.6993 | train_acc: 0.7319 | val_loss: 2.0345 | val_acc: 0.5056
# Epoch 78
# Train Batch 100 (every 100 batch): Loss=0.6541; accuracy=0.7494
# Train Batch 200 (every 100 batch): Loss=0.5009; accuracy=0.7409
# Train Batch 300 (every 100 batch): Loss=0.6343; accuracy=0.7356
# Train Batch 400 (every 100 batch): Loss=0.4970; accuracy=0.7331
# Epoch 78 summary: train_loss: 0.7116 | train_acc: 0.7293 | val_loss: 1.9460 | val_acc: 0.5066
# Epoch 79
# Train Batch 100 (every 100 batch): Loss=0.3774; accuracy=0.7625
# Train Batch 200 (every 100 batch): Loss=0.5411; accuracy=0.7578
# Train Batch 300 (every 100 batch): Loss=0.6492; accuracy=0.7556
# Train Batch 400 (every 100 batch): Loss=1.0065; accuracy=0.7533
# Epoch 79 summary: train_loss: 0.6640 | train_acc: 0.7498 | val_loss: 2.1062 | val_acc: 0.4857
# Epoch 80
# Train Batch 100 (every 100 batch): Loss=0.4172; accuracy=0.7600
# Train Batch 200 (every 100 batch): Loss=0.5865; accuracy=0.7631
# Train Batch 300 (every 100 batch): Loss=0.9755; accuracy=0.7625
# Train Batch 400 (every 100 batch): Loss=0.6731; accuracy=0.7627
# Epoch 80 summary: train_loss: 0.6391 | train_acc: 0.7563 | val_loss: 2.1529 | val_acc: 0.4930
# Epoch 81
# Train Batch 100 (every 100 batch): Loss=0.4534; accuracy=0.7531
# Train Batch 200 (every 100 batch): Loss=0.8324; accuracy=0.7562
# Train Batch 300 (every 100 batch): Loss=0.5202; accuracy=0.7515
# Train Batch 400 (every 100 batch): Loss=0.4698; accuracy=0.7545
# Epoch 81 summary: train_loss: 0.6415 | train_acc: 0.7579 | val_loss: 2.2123 | val_acc: 0.4804
# Epoch 82
# Train Batch 100 (every 100 batch): Loss=0.3392; accuracy=0.7600
# Train Batch 200 (every 100 batch): Loss=0.5745; accuracy=0.7609
# Train Batch 300 (every 100 batch): Loss=0.6458; accuracy=0.7619
# Train Batch 400 (every 100 batch): Loss=0.9908; accuracy=0.7608
# Epoch 82 summary: train_loss: 0.6658 | train_acc: 0.7545 | val_loss: 2.0980 | val_acc: 0.4711
# Epoch 83
# Train Batch 100 (every 100 batch): Loss=0.3639; accuracy=0.7825
# Train Batch 200 (every 100 batch): Loss=0.4462; accuracy=0.7822
# Train Batch 300 (every 100 batch): Loss=0.1826; accuracy=0.7808
# Train Batch 400 (every 100 batch): Loss=0.6895; accuracy=0.7734
# Epoch 83 summary: train_loss: 0.6252 | train_acc: 0.7685 | val_loss: 2.1544 | val_acc: 0.4626
# Epoch 84
# Train Batch 100 (every 100 batch): Loss=0.5011; accuracy=0.7731
# Train Batch 200 (every 100 batch): Loss=0.6432; accuracy=0.7809
# Train Batch 300 (every 100 batch): Loss=0.6464; accuracy=0.7790
# Train Batch 400 (every 100 batch): Loss=0.3686; accuracy=0.7761
# Epoch 84 summary: train_loss: 0.6011 | train_acc: 0.7726 | val_loss: 2.1831 | val_acc: 0.5027
# Epoch 85
# Train Batch 100 (every 100 batch): Loss=0.5028; accuracy=0.7869
# Train Batch 200 (every 100 batch): Loss=0.3190; accuracy=0.7859
# Train Batch 300 (every 100 batch): Loss=0.6143; accuracy=0.7833
# Train Batch 400 (every 100 batch): Loss=0.2690; accuracy=0.7764
# Epoch 85 summary: train_loss: 0.6017 | train_acc: 0.7748 | val_loss: 2.2408 | val_acc: 0.4718
# Epoch 86
# Train Batch 100 (every 100 batch): Loss=0.6286; accuracy=0.7644
# Train Batch 200 (every 100 batch): Loss=1.1154; accuracy=0.7763
# Train Batch 300 (every 100 batch): Loss=0.3284; accuracy=0.7721
# Train Batch 400 (every 100 batch): Loss=0.3496; accuracy=0.7747
# Epoch 86 summary: train_loss: 0.6128 | train_acc: 0.7721 | val_loss: 2.2618 | val_acc: 0.4687
# Epoch 87
# Train Batch 100 (every 100 batch): Loss=0.4216; accuracy=0.7812
# Train Batch 200 (every 100 batch): Loss=0.3610; accuracy=0.7816
# Train Batch 300 (every 100 batch): Loss=0.5916; accuracy=0.7831
# Train Batch 400 (every 100 batch): Loss=0.4602; accuracy=0.7833
# Epoch 87 summary: train_loss: 0.5844 | train_acc: 0.7828 | val_loss: 2.3044 | val_acc: 0.4832
# Epoch 88
# Train Batch 100 (every 100 batch): Loss=0.6204; accuracy=0.8050
# Train Batch 200 (every 100 batch): Loss=0.9079; accuracy=0.8000
# Train Batch 300 (every 100 batch): Loss=0.5497; accuracy=0.7969
# Train Batch 400 (every 100 batch): Loss=0.2750; accuracy=0.7939
# Epoch 88 summary: train_loss: 0.5598 | train_acc: 0.7935 | val_loss: 2.4227 | val_acc: 0.4697
# Epoch 89
# Train Batch 100 (every 100 batch): Loss=0.3632; accuracy=0.7956
# Train Batch 200 (every 100 batch): Loss=0.5323; accuracy=0.7866
# Train Batch 300 (every 100 batch): Loss=0.7135; accuracy=0.7844
# Train Batch 400 (every 100 batch): Loss=0.5422; accuracy=0.7875
# Epoch 89 summary: train_loss: 0.5803 | train_acc: 0.7866 | val_loss: 2.2289 | val_acc: 0.4893
# Epoch 90
# Train Batch 100 (every 100 batch): Loss=0.4731; accuracy=0.8106
# Train Batch 200 (every 100 batch): Loss=0.2096; accuracy=0.8166
# Train Batch 300 (every 100 batch): Loss=0.3966; accuracy=0.8113
# Train Batch 400 (every 100 batch): Loss=0.3620; accuracy=0.8081
# Epoch 90 summary: train_loss: 0.5327 | train_acc: 0.8048 | val_loss: 2.5121 | val_acc: 0.4961
# Epoch 91
# Train Batch 100 (every 100 batch): Loss=0.6843; accuracy=0.8069
# Train Batch 200 (every 100 batch): Loss=0.4076; accuracy=0.8037
# Train Batch 300 (every 100 batch): Loss=0.6878; accuracy=0.8067
# Train Batch 400 (every 100 batch): Loss=0.4617; accuracy=0.8022
# Epoch 91 summary: train_loss: 0.5312 | train_acc: 0.8026 | val_loss: 2.4479 | val_acc: 0.4792
# Epoch 92
# Train Batch 100 (every 100 batch): Loss=0.3420; accuracy=0.8350
# Train Batch 200 (every 100 batch): Loss=0.6211; accuracy=0.8300
# Train Batch 300 (every 100 batch): Loss=0.2422; accuracy=0.8167
# Train Batch 400 (every 100 batch): Loss=1.0870; accuracy=0.8131
# Epoch 92 summary: train_loss: 0.5227 | train_acc: 0.8101 | val_loss: 2.3728 | val_acc: 0.4733
# Epoch 93
# Train Batch 100 (every 100 batch): Loss=0.2803; accuracy=0.8062
# Train Batch 200 (every 100 batch): Loss=0.3322; accuracy=0.8078
# Train Batch 300 (every 100 batch): Loss=0.5889; accuracy=0.8023
# Train Batch 400 (every 100 batch): Loss=0.6817; accuracy=0.8002
# Epoch 93 summary: train_loss: 0.5500 | train_acc: 0.7986 | val_loss: 2.2328 | val_acc: 0.4793
# Epoch 94
# Train Batch 100 (every 100 batch): Loss=0.5322; accuracy=0.8325
# Train Batch 200 (every 100 batch): Loss=0.9960; accuracy=0.8262
# Train Batch 300 (every 100 batch): Loss=0.6351; accuracy=0.8271
# Train Batch 400 (every 100 batch): Loss=0.5958; accuracy=0.8244
# Epoch 94 summary: train_loss: 0.5022 | train_acc: 0.8218 | val_loss: 2.6764 | val_acc: 0.4644
# Epoch 95
# Train Batch 100 (every 100 batch): Loss=0.3834; accuracy=0.8462
# Train Batch 200 (every 100 batch): Loss=0.3764; accuracy=0.8297
# Train Batch 300 (every 100 batch): Loss=0.7462; accuracy=0.8250
# Train Batch 400 (every 100 batch): Loss=0.9852; accuracy=0.8219
# Epoch 95 summary: train_loss: 0.4878 | train_acc: 0.8203 | val_loss: 2.5381 | val_acc: 0.4754
# Epoch 96
# Train Batch 100 (every 100 batch): Loss=0.7339; accuracy=0.8375
# Train Batch 200 (every 100 batch): Loss=0.6288; accuracy=0.8303
# Train Batch 300 (every 100 batch): Loss=0.5619; accuracy=0.8271
# Train Batch 400 (every 100 batch): Loss=0.4088; accuracy=0.8269
# Epoch 96 summary: train_loss: 0.4900 | train_acc: 0.8251 | val_loss: 2.5774 | val_acc: 0.4621
# Epoch 97
# Train Batch 100 (every 100 batch): Loss=0.5165; accuracy=0.8275
# Train Batch 200 (every 100 batch): Loss=0.5474; accuracy=0.8300
# Train Batch 300 (every 100 batch): Loss=0.6026; accuracy=0.8254
# Train Batch 400 (every 100 batch): Loss=0.3988; accuracy=0.8216
# Epoch 97 summary: train_loss: 0.4859 | train_acc: 0.8195 | val_loss: 2.3176 | val_acc: 0.4895
# Epoch 98
# Train Batch 100 (every 100 batch): Loss=0.7928; accuracy=0.8306
# Train Batch 200 (every 100 batch): Loss=0.5094; accuracy=0.8309
# Train Batch 300 (every 100 batch): Loss=0.3942; accuracy=0.8290
# Train Batch 400 (every 100 batch): Loss=0.3239; accuracy=0.8287
# Epoch 98 summary: train_loss: 0.4793 | train_acc: 0.8267 | val_loss: 2.3590 | val_acc: 0.4814
# Epoch 99
# Train Batch 100 (every 100 batch): Loss=0.4448; accuracy=0.8487
# Train Batch 200 (every 100 batch): Loss=0.5012; accuracy=0.8338
# Train Batch 300 (every 100 batch): Loss=0.2960; accuracy=0.8306
# Train Batch 400 (every 100 batch): Loss=0.2893; accuracy=0.8298
# Epoch 99 summary: train_loss: 0.4707 | train_acc: 0.8308 | val_loss: 2.7191 | val_acc: 0.4838
# Epoch 100
# Train Batch 100 (every 100 batch): Loss=0.0903; accuracy=0.8475
# Train Batch 200 (every 100 batch): Loss=0.3767; accuracy=0.8400
# Train Batch 300 (every 100 batch): Loss=0.6347; accuracy=0.8419
# Train Batch 400 (every 100 batch): Loss=0.3955; accuracy=0.8380
# Epoch 100 summary: train_loss: 0.4631 | train_acc: 0.8363 | val_loss: 2.7163 | val_acc: 0.4862

# %%
torch.save(results, results_path+'.obj')
# val =accuracy_val
# test = accuracy_test

# print("Validation accuracy: ", val)
# print("Test accuracy: ", test)

# %%
loaded_results = torch.load(results_path+'.obj')
print(loaded_results)
# Out:
# {'train_loss': [3.7062951201894676, 3.6957226690039575, 3.692442771900131, 3.688679197227141, 3.6901031560208426, 3.6868012296148094, 3.6863420038338166, 3.685051639396024, 3.68464969248178, 3.654688634068133, 3.622031214246788, 3.386039490680618, 3.0435622437412, 2.772773202643337, 2.5422601908086295, 2.3677799737597085, 2.223864011975177, 2.1342549443723686, 2.0470342482907706, 1.9681759739975373, 1.909850572247103, 1.851546166412323, 1.8009871653763645, 1.754862826751418, 1.7084006032790524, 1.6755295168443856, 1.6346564891347923, 1.604327524282846, 1.5663355501540694, 1.5359704736246163, 1.5041765687934845, 1.4841138446426774, 1.457804185199929, 1.4337067173187992, 1.413131878797309, 1.374702016512553, 1.3633206744031254, 1.3266901525867034, 1.3103453251252692, 1.3106042541653278, 1.2697581123396096, 1.2680705913817547, 1.2453404746381154, 1.230835597917258, 1.1900513355870803, 1.1702531100396651, 1.1732941196864868, 1.1501736514060852, 1.1533906365254796, 1.1147573151023513, 1.0937403484161599, 1.07887732126866, 1.0666595609432243, 1.0306576762692516, 1.0365098690890884, 1.0139515180903744, 0.9966128075338272, 0.9763646685335052, 0.9657601778765759, 0.944124822216819, 0.9446177023002901, 0.9119865389832531, 0.8924860862124876, 0.9036651029285178, 0.874015490483328, 0.8576968283538359, 0.844288067046897, 0.8350325411701777, 0.794848815863391, 0.7860883847776666, 0.7980929526638794, 0.7603906638411633, 0.7443643044455942, 0.7445162310897107, 0.7410055596426309, 0.7205858949018291, 0.6992995411337141, 0.7115991498272581, 0.6639642596663721, 0.6390685696439092, 0.6414705429779717, 0.6658053985800609, 0.6251665620978577, 0.601144600869063, 0.6017056046180935, 0.6127557538180466, 0.5843759344135183, 0.5597637752632061, 0.5802531643624765, 0.5326813359008017, 0.5311980063028364, 0.5226877795524866, 0.549994566489056, 0.5021727113090605, 0.487778445877823, 0.49003859984886694, 0.4858913137596175, 0.47934665005788746, 0.4706798298396619, 0.4630581087481425], 'train_acc': [tensor(0.0275, device='cuda:0'), tensor(0.0246, device='cuda:0'), tensor(0.0282, device='cuda:0'), tensor(0.0294, device='cuda:0'), tensor(0.0255, device='cuda:0'), tensor(0.0275, device='cuda:0'), tensor(0.0297, device='cuda:0'), tensor(0.0292, device='cuda:0'), tensor(0.0307, device='cuda:0'), tensor(0.0358, device='cuda:0'), tensor(0.0359, device='cuda:0'), tensor(0.0570, device='cuda:0'), tensor(0.0925, device='cuda:0'), tensor(0.1193, device='cuda:0'), tensor(0.1639, device='cuda:0'), tensor(0.1870, device='cuda:0'), tensor(0.2123, device='cuda:0'), tensor(0.2359, device='cuda:0'), tensor(0.2541, device='cuda:0'), tensor(0.2729, device='cuda:0'), tensor(0.2937, device='cuda:0'), tensor(0.3104, device='cuda:0'), tensor(0.3226, device='cuda:0'), tensor(0.3309, device='cuda:0'), tensor(0.3478, device='cuda:0'), tensor(0.3588, device='cuda:0'), tensor(0.3696, device='cuda:0'), tensor(0.3808, device='cuda:0'), tensor(0.3861, device='cuda:0'), tensor(0.3992, device='cuda:0'), tensor(0.4101, device='cuda:0'), tensor(0.4223, device='cuda:0'), tensor(0.4343, device='cuda:0'), tensor(0.4440, device='cuda:0'), tensor(0.4508, device='cuda:0'), tensor(0.4646, device='cuda:0'), tensor(0.4624, device='cuda:0'), tensor(0.4758, device='cuda:0'), tensor(0.4854, device='cuda:0'), tensor(0.4919, device='cuda:0'), tensor(0.5034, device='cuda:0'), tensor(0.4983, device='cuda:0'), tensor(0.5116, device='cuda:0'), tensor(0.5114, device='cuda:0'), tensor(0.5292, device='cuda:0'), tensor(0.5418, device='cuda:0'), tensor(0.5389, device='cuda:0'), tensor(0.5449, device='cuda:0'), tensor(0.5447, device='cuda:0'), tensor(0.5612, device='cuda:0'), tensor(0.5636, device='cuda:0'), tensor(0.5817, device='cuda:0'), tensor(0.5764, device='cuda:0'), tensor(0.5982, device='cuda:0'), tensor(0.5996, device='cuda:0'), tensor(0.6047, device='cuda:0'), tensor(0.6075, device='cuda:0'), tensor(0.6200, device='cuda:0'), tensor(0.6201, device='cuda:0'), tensor(0.6308, device='cuda:0'), tensor(0.6359, de ...

# %%
train_values = loaded_results['train_loss']
val_values = loaded_results['val_loss']
print(len(train_values))
print(len(val_values))
# Out:
# 100
# 100

# %%
epochs = range(1, 101)
print(len(epochs))
# Plot and label the training and validation loss values
plt.plot(epochs, train_values, label='Training Loss')
plt.plot(epochs, val_values, label='Validation Loss')
 
# Add in a title and axes labels
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
 
# Set the tick locations
plt.xticks(np.arange(0, 101, 10))
 
# Display the plot
plt.legend(loc='best')
plt.show()
# Out:
# 100

# %%
train_acc_values = torch.stack(loaded_results['train_acc']).tolist()
val_acc_values = torch.stack(loaded_results['val_acc']).tolist()
print(len(train_acc_values))
print(len(val_acc_values))
# Out:
# 100
# 100

# %%
epochs = range(1, 101)
print(len(epochs))
# Plot and label the training and validation loss values
plt.plot(epochs, train_acc_values, label='Training Accuracy')
plt.plot(epochs, val_acc_values, label='Validation Accuracy')
 
# Add in a title and axes labels
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
 
# Set the tick locations
plt.xticks(np.arange(0, 101, 10))
 
# Display the plot
plt.legend(loc='best')
plt.show()
# Out:
# 100
