# %%
import os
import random
import torch
import numpy as np
import pickle as pkl
from analysis import *
import argparse
from sys import platform
import matplotlib

# %%
torch.manual_seed(12)
torch.cuda.manual_seed(12)
np.random.seed(12)
torch.backends.cudnn.deterministics = True
torch.set_num_threads(1)

# %%
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.current_device())


print(torch.cuda.device(0))
print(torch.cuda.get_device_name(0))
# Out:
# True
# 1
# 0
# <torch.cuda.device object at 0x7fefa16cdd30>
# NVIDIA TITAN V

# %%
# iv: image option
length = 440
channel = 128
min_CNN = 200
n_classes = 40
classes = range(n_classes)

# %%
if platform == "linux" or platform == "linux2":
    torch_models_dir = r"/media/titan/AI Research1/Data/CVPR2017"
elif platform == "win32":
    torch_models_dir = r"D:\Data\CVPR2021-02785\CVPR2021-02785\preprocessed\torch_models"
block_splits_all, block_splits_single, eeg_14_70, eeg_55_95, eeg_5_95, eeg_raw = os.listdir(torch_models_dir)
print(os.listdir(torch_models_dir))
# Out:
# ['block_splits_by_image_all.pth', 'block_splits_by_image_single.pth', 'eeg_14_70_std.pth', 'eeg_55_95_std.pth', 'eeg_5_95_std.pth', 'eeg_signals_raw_with_mean_std.pth']

# %%
eeg_dataset = os.path.join(torch_models_dir, eeg_55_95)
splits_all_path = os.path.join(torch_models_dir, block_splits_all)
splits_single_path = os.path.join(torch_models_dir, block_splits_single)
# splits_path = os.path.join(torch_models_dir, splits_shuffled_path)
print(eeg_dataset,'\n', splits_all_path, '\n', splits_single_path)
# Out:
# /media/titan/AI Research1/Data/CVPR2017/eeg_55_95_std.pth
#  /media/titan/AI Research1/Data/CVPR2017/block_splits_by_image_all.pth
#  /media/titan/AI Research1/Data/CVPR2017/block_splits_by_image_single.pth

# %%
splits_all = torch.load(splits_all_path)
splits_single = torch.load(splits_single_path)

# %%
print(len(splits_all['splits']))
print(len(splits_all['splits'][0]))

print(len(splits_all['splits'][5]['train']))
print(len(splits_all['splits'][5]['val']))
print(len(splits_all['splits'][5]['test']))
print(splits_all['splits'][0]['train'][:40])
print(splits_all['splits'][1]['train'][:40])
print(splits_all['splits'][2]['train'][:10])
print(splits_all['splits'][3]['train'][:10])
# Out:
# 6
# 3
# 7984
# 1996
# 1985
# [0, 3, 4, 5, 6, 8, 9, 10, 11, 12, 13, 15, 16, 17, 18, 19, 21, 22, 23, 24, 25, 27, 29, 33, 35, 36, 37, 38, 39, 42, 43, 44, 45, 46, 47, 48, 51, 52, 54, 55]
# [1, 2, 3, 4, 6, 8, 9, 12, 13, 20, 25, 26, 27, 28, 30, 32, 33, 35, 37, 38, 39, 40, 44, 45, 46, 50, 52, 54, 56, 58, 59, 60, 62, 65, 68, 72, 73, 74, 76, 81]
# [2, 3, 4, 5, 6, 7, 8, 10, 11, 13]
# [1, 2, 4, 7, 9, 10, 12, 13, 14, 15]

# %%
# print(splits_single)
print(len(splits_single['splits'][0]['train']))
print(len(splits_single['splits'][0]['val']))
print(len(splits_single['splits'][0]['test']))
# Out:
# 669
# 167
# 164

# %%
eeg_loaded = torch.load(eeg_dataset)

# %%
print(len(eeg_loaded))
print(eeg_loaded.keys())
dataset, labels, images = [eeg_loaded[k] for k in eeg_loaded.keys()]
print(len(labels))
print(len(images))
print(len(dataset))

print(labels)
print(images[0])
print(dataset[0]['eeg'].shape)
print(dataset[0])
# Out:
# 3
# dict_keys(['dataset', 'labels', 'images'])
# 40
# 1996
# 11965
# ['n02389026', 'n03888257', 'n03584829', 'n02607072', 'n03297495', 'n03063599', 'n03792782', 'n04086273', 'n02510455', 'n11939491', 'n02951358', 'n02281787', 'n02106662', 'n04120489', 'n03590841', 'n02992529', 'n03445777', 'n03180011', 'n02906734', 'n07873807', 'n03773504', 'n02492035', 'n03982430', 'n03709823', 'n03100240', 'n03376595', 'n03877472', 'n03775071', 'n03272010', 'n04069434', 'n03452741', 'n03792972', 'n07753592', 'n13054560', 'n03197337', 'n02504458', 'n02690373', 'n03272562', 'n04044716', 'n02124075']
# n02951358_31190
# torch.Size([128, 500])
# {'eeg': tensor([[-2.9181e-02, -2.9862e-01, -5.1430e-01,  ..., -8.4631e-01,
#          -4.8041e-01, -2.8394e-02],
#         [-2.4111e-02, -1.6960e-01, -2.8707e-01,  ..., -5.6212e-01,
#          -3.2735e-01, -3.5872e-02],
#         [ 4.7802e-02,  3.7646e-01,  6.4149e-01,  ...,  4.3011e-01,
#           2.4678e-01,  4.1414e-02],
#         ...,
#         [ 2.1368e-02,  1.2907e-01,  1.9428e-01,  ...,  7.4598e-01,
#           4.1789e-01, -9.6936e-03],
#         [ 9.9196e-04, -1.1907e-02, -2.2160e-02,  ...,  2.7170e-02,
#           1.5099e-02, -3.4801e-04],
#         [ 2.7840e-03, -3.7217e-02, -7.2385e-02,  ...,  1.1830e-01,
#           6.4887e-02, -6.0881e-03]]), 'image': 0, 'label': 10, 'subject': 4}

# %%
opt = {
    # Dataset options
#     "iv": "image",
#     "offset": None,
    "results_file": "results.pkl",
    "subject": 0,
    "time_low": 20,
    "time_high": 460,
#     "run": "none",
    "eeg_dataset": eeg_dataset,
    "model_type": "model10",
    "splits_path": splits_all_path,
    "split_num": 0,
    "split_name": "train",
#     "fold": 5,
    #Training options
    "batch_size": 16,
    "optim": "Adam",
    "learning_rate": 0.001,
    "learning_rate_decay_by": 0.5,
    "learning_rate_decay_every": 10,
    "epochs": 100,
    "GPUindex": 0,
    "kind":"from-scratch",
    #Backend options
    "no_cuda": False,
    "classifier": None
}
opt = argparse.Namespace(**opt)
print(opt.time_low)
# Out:
# 20

# %%
# %load_ext autoreload
# %autoreload 2
from torch.utils.data import DataLoader
# from data_loader import EEGDataset, Splitter, SplitterWithData
from data_loader_CVPR2017 import EEGDataset, Splitter
from EEG_Encoder.LSTM import classifier_LSTM
from EEG_Encoder.CNN import classifier_CNN
from EEG_Encoder.EEGNet import classifier_EEGNet
from EEG_Encoder.SyncNet import classifier_SyncNet
from EEG_Encoder.EEGChannelNet import classifier_EEGChannelNet
from EEG_Encoder.net_generator import Classifier
from EEG_Encoder.net_trainer import net_trainer
from matplotlib import pyplot as plt
from p_values import *
from torchinfo import summary
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def load_dataset(
#              offset,
             eeg_dataset,
             splits_path,
             split_num, # (0-5) - 6 fold cross validation
             split_name,
#              total, 
#              classes,
#              classifier,
             batch_size,
#              GPUindex,
#              length, # 500
#              channel, # 128
#              min_CNN,
             opt,
             kind="from-scratch"):        
    # Load dataset
    dataset = EEGDataset(opt, eeg_dataset)
    print("DONE: LOAD DATASET")
#     # Create loaders for LSTM/MLP/CNN/SCNN/EEGNet/SyncNet/EEGChannelNet
#     if kind=="from-scratch":
#         relabel = False
#     if kind=="incremental":
#         relabel = False
#     if kind=="no-model-file":
#         relabel = True
    splitter = {split: Splitter(dataset,
                    splits_path,
                    split_num,
                    split_name = split) for split in ["train", "val", "test"]}
    loaders = {split: DataLoader(
                        splitter[split],
                        batch_size = batch_size,
                        drop_last = False,
                        shuffle = True)
                    for split in ["train", "val", "test"]}
    channel_idx = None    
    print("DONE: Create loaders for model")            
    return dataset, loaders, splitter

# %%
# Options
opt.classifier = "EEGChannelNet"
opt.batch_size = 16
# opt.kind = "from-scratch"
# opt.run = "imagenet40-1000"
# opt.fold = 5

# %%
dataset, loaders, splitter = load_dataset(
#              offset,
             opt.eeg_dataset,
             opt.splits_path,
             opt.split_num, # (0-5) - 6 fold cross validation
             opt.split_name,
#              total, 
#              classes,
#              classifier,
             opt.batch_size,
#              GPUindex,
#              length, # 500
#              channel, # 128
#              min_CNN,
             opt,
             opt.kind)
# Out:
# DONE: LOAD DATASET
# DONE: Create loaders for model

# %%
# loaders: divide the splits data in each fold with batch_size
# Each fold has {train: 8000 idx, val: 2000 idx, test: 2000 idx}
# Each loader batch has {train: 2000 idx, val: 250 idx, test: 250 idx}
print(type(dataset))
print(type(loaders))
print(len(loaders), [len(loaders[name]) for name in ["train", "val", "test"] ])
for i, (input, target) in enumerate(loaders["train"]):
    if i<20:
        print(f"{i+1}: Target size: {target.size()}; input size: {input.size()}")
for i in range(0, 40):
    eeg, label_val = splitter["val"][i]
    eeg, label_train = splitter["train"][i]
    print(f"{i+1}: Label val: {label_val}; label train: {label_train}")
# Out:
# <class 'data_loader_CVPR2017.EEGDataset'>
# <class 'dict'>
# 3 [498, 125, 125]
# 1: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 2: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 3: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 4: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 5: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 6: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 7: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 8: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 9: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 10: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 11: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 12: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 13: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 14: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 15: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 16: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 17: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 18: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 19: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 20: Target size: torch.Size([16]); input size: torch.Size([16, 128, 440])
# 1: Label val: 37; label train: 10
# 2: Label val: 38; label train: 10
# 3: Label val: 11; label train: 30
# 4: Label val: 10; label train: 25
# 5: Label val: 7; label train: 18
# 6: Label val: 35; label train: 3
# 7: Label val: 13; label train: 8
# 8: Label val: 2; label train: 11
# 9: Label val: 14; label train: 18
# 10: Label val: 2; label train: 28
# 11: Label val: 33; label train: 38
# 12: Label val: 26; label train: 20
# 13: Label val: 34; label train: 3
# 14: Label val: 18; label train: 28
# 15: Label val: 11; label train: 23
# 16: Label val: 32; label train: 0
# 17: Label val: 6; label train: 34
# 18: Label val: 22; label train: 20
# 19: Label val: 24; label train: 23
# 20: Label val: 24; label train: 39
# 21: Label val: 29; label train: 0
# 22: Label val: 3; label train: 34
# 23: Label val: 25; label train: 21
# 24: Label val: 11; label train: 39
# 25: Label val: 22; label train: 6
# 26: Label val: 36; label train: 26
# 27: Label val: 30; label train: 20
# 28: Label val: 32; label train: 1
# 29: Label val: 22; label train: 27
# 30: Label val: 39; label train: 37
# 31: Label val: 23; label train: 19
# 32: Label val: 4; label train: 9
# 33: Label val: 10; label train: 12
# 34: Label val: 3; label train: 18
# 35: Label val: 24; label train: 25
# 36: Label val: 27; label train: 27
# 37: Label val: 20; label train: 34
# 38: Label val: 1; label train: 35
# 39: Label val: 38; label train: 8
# 40: Label val: 15; label train: 29

# %%
net, nonclasses = Classifier(
                 n_classes,
                 classes,
                 opt.classifier,
                 opt.GPUindex,
                 length,
                 channel,
                 min_CNN,
                 opt.kind)
# print(len(nonclasses))
summary(net, input_size =(1,128, 440))
# Out:
# [W NNPACK.cpp:53] Could not initialize NNPACK! Reason: Unsupported hardware.
# DONE: CREATE TORCH CLASSIFIER
# classifier_EEGChannelNet(
#   (encoder): FeaturesExtractor(
#     (temporal_block): TemporalBlock(
#       (layers): ModuleList(
#         (0): ConvLayer2D(
#           (norm): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(1, 10, kernel_size=(1, 33), stride=(1, 2), padding=(0, 16))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#         (1): ConvLayer2D(
#           (norm): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(1, 10, kernel_size=(1, 33), stride=(1, 2), padding=(0, 32), dilation=(1, 2))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#         (2): ConvLayer2D(
#           (norm): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(1, 10, kernel_size=(1, 33), stride=(1, 2), padding=(0, 64), dilation=(1, 4))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#         (3): ConvLayer2D(
#           (norm): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(1, 10, kernel_size=(1, 33), stride=(1, 2), padding=(0, 128), dilation=(1, 8))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#       )
#     )
#     (spatial_block): SpatialBlock(
#       (layers): ModuleList(
#         (0): ConvLayer2D(
#           (norm): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(40, 50, kernel_size=(128, 1), stride=(2, 1), padding=(63, 0))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#         (1): ConvLayer2D(
#           (norm): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(40, 50, kernel_size=(64, 1), stride=(2, 1), padding=(31, 0))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#         (2): ConvLayer2D(
#           (norm): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(40, 50, kernel_size=(42, 1), stride=(2, 1), padding=(20, 0))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#         (3): ConvLayer2D(
#           (norm): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(40, 50, kernel_size=(32, 1), stride=(2, 1), padding=(15, 0))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#       )
#     )
#     (res_blocks): ModuleList(
#       (0): Sequential(
#         (0): ResidualBlock(
#           (conv1): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvLayer2D(
#           (norm): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(200, 200, kernel_size=(3, 3), stride=(2, 2))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#       )
#       (1): Sequential(
#         (0): ResidualBlock(
#           (conv1): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvLayer2D(
#           (norm): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(200, 200, kernel_size=(3, 3), stride=(2, 2))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#       )
#       (2): Sequential(
#         (0): ResidualBlock(
#           (conv1): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvLayer2D(
#           (norm): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(200, 200, kernel_size=(3, 3), stride=(2, 2))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#       )
#       (3): Sequential(
#         (0): ResidualBlock(
#           (conv1): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ConvLayer2D(
#           (norm): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv): Conv2d(200, 200, kernel_size=(3, 3), stride=(2, 2))
#           (drop): Dropout2d(p=0.2, inplace=False)
#         )
#       )
#     )
#     (final_conv): ConvLayer2D(
#       (norm): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(200, 50, kernel_size=(3, 3), stride=(1, 1))
#       (drop): Dropout2d(p=0.2, inplace=False)
#     )
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=500, out_features=1000, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=1000, out_features=40, bias=True)
#   )
# )
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# classifier_EEGChannelNet                      [1, 40]                   --
# ├─FeaturesExtractor: 1-1                      [1, 50, 1, 10]            --
# │    └─TemporalBlock: 2-1                     [1, 40, 128, 220]         --
# │    │    └─ModuleList: 3-1                   --                        1,368
# │    └─SpatialBlock: 2-2                      [1, 200, 64, 220]         --
# │    │    └─ModuleList: 3-2                   --                        532,520
# │    └─ModuleList: 2-3                        --                        --
# │    │    └─Sequential: 3-3                   [1, 200, 31, 109]         1,081,400
# │    │    └─Sequential: 3-4                   [1, 200, 15, 54]          1,081,400
# │    │    └─Sequential: 3-5                   [1, 200, 7, 26]           1,081,400
# │    │    └─Sequential: 3-6                   [1, 200, 3, 12]           1,081,400
# │    └─ConvLayer2D: 2-4                       [1, 50, 1, 10]            --
# │    │    └─BatchNorm2d: 3-7                  [1, 200, 3, 12]           400
# │    │    └─ReLU: 3-8                         [1, 200, 3, 12]           --
# │    │    └─Conv2d: 3-9                       [1, 50, 1, 10]            90,050
# │    │    └─Dropout2d: 3-10                   [1, 50, 1, 10]            --
# ├─Sequential: 1-2                             [1, 40]                   --
# │    └─Linear: 2-5                            [1, 1000]                 501,000
# │    └─ReLU: 2-6                              [1, 1000]                 --
# │    └─Linear: 2-7                            [1, 40]                   40,040
# ===============================================================================================
# Total params: 5,490,978
# Trainable params: 5,490,978
# Non-trainable params: 0
# Total mult-adds (G): 22.41
# ===============================================================================================
# Input size (MB): 0.23
# Forward/backward pass size (MB): 224.12
# Params size (MB): 21.96
# Estimated Total Size (MB): 246.30
# ===============================================================================================

# %%
model_path = (   opt.classifier+
                  "-"+
                  str(length)+
                  "-"+
                  str(channel) + "_55_95" )
results_path = (  "results_"+ opt.classifier+
                  "-"+
                  str(length)+
                  "-"+
                  str(channel)+ "_55_95"  )
print(model_path)
print(results_path)
# Out:
# EEGChannelNet-440-128_55_95
# results_EEGChannelNet-440-128_55_95

# %%
print(opt)
# Out:
# Namespace(results_file='results.pkl', subject=0, time_low=20, time_high=460, eeg_dataset='/media/titan/AI Research1/Data/CVPR2017/eeg_55_95_std.pth', model_type='model10', splits_path='/media/titan/AI Research1/Data/CVPR2017/block_splits_by_image_all.pth', split_num=0, split_name='train', batch_size=16, optim='Adam', learning_rate=0.001, learning_rate_decay_by=0.5, learning_rate_decay_every=10, epochs=100, GPUindex=0, kind='from-scratch', no_cuda=False, classifier='EEGChannelNet')

# %%
channel_idx=None
non_classes=None
if opt.kind=="from-scratch":
    results = net_trainer(
            net,
            loaders,
            opt,
            channel_idx,
            nonclasses,
            None,
            True,
            model_path)
# Out:
# Epoch 1
# Train Batch 100 (every 100 batch): Loss=3.7295; accuracy=0.0331
# Train Batch 200 (every 100 batch): Loss=3.7053; accuracy=0.0306
# Train Batch 300 (every 100 batch): Loss=3.7087; accuracy=0.0298
# Train Batch 400 (every 100 batch): Loss=3.6251; accuracy=0.0270
# Epoch 1 summary: train_loss: 3.7101 | train_acc: 0.0277 | val_loss: 3.7245 | val_acc: 0.0205
# Epoch 2
# Train Batch 100 (every 100 batch): Loss=3.6778; accuracy=0.0275
# Train Batch 200 (every 100 batch): Loss=3.6701; accuracy=0.0266
# Train Batch 300 (every 100 batch): Loss=3.7374; accuracy=0.0244
# Train Batch 400 (every 100 batch): Loss=3.7025; accuracy=0.0253
# Epoch 2 summary: train_loss: 3.6951 | train_acc: 0.0264 | val_loss: 3.6962 | val_acc: 0.0150
# Epoch 3
# Train Batch 100 (every 100 batch): Loss=3.6771; accuracy=0.0269
# Train Batch 200 (every 100 batch): Loss=3.6593; accuracy=0.0228
# Train Batch 300 (every 100 batch): Loss=3.6921; accuracy=0.0265
# Train Batch 400 (every 100 batch): Loss=3.6919; accuracy=0.0253
# Epoch 3 summary: train_loss: 3.6926 | train_acc: 0.0264 | val_loss: 3.7011 | val_acc: 0.0210
# Epoch 4
# Train Batch 100 (every 100 batch): Loss=3.7314; accuracy=0.0306
# Train Batch 200 (every 100 batch): Loss=3.6702; accuracy=0.0319
# Train Batch 300 (every 100 batch): Loss=3.6804; accuracy=0.0317
# Train Batch 400 (every 100 batch): Loss=3.6849; accuracy=0.0294
# Epoch 4 summary: train_loss: 3.6899 | train_acc: 0.0282 | val_loss: 3.7007 | val_acc: 0.0185
# Epoch 5
# Train Batch 100 (every 100 batch): Loss=3.7154; accuracy=0.0294
# Train Batch 200 (every 100 batch): Loss=3.6702; accuracy=0.0287
# Train Batch 300 (every 100 batch): Loss=3.6951; accuracy=0.0283
# Train Batch 400 (every 100 batch): Loss=3.6985; accuracy=0.0289
# Epoch 5 summary: train_loss: 3.6880 | train_acc: 0.0281 | val_loss: 3.7036 | val_acc: 0.0178
# Epoch 6
# Train Batch 100 (every 100 batch): Loss=3.6443; accuracy=0.0219
# Train Batch 200 (every 100 batch): Loss=3.7325; accuracy=0.0250
# Train Batch 300 (every 100 batch): Loss=3.6844; accuracy=0.0258
# Train Batch 400 (every 100 batch): Loss=3.6551; accuracy=0.0275
# Epoch 6 summary: train_loss: 3.6883 | train_acc: 0.0294 | val_loss: 3.7071 | val_acc: 0.0175
# Epoch 7
# Train Batch 100 (every 100 batch): Loss=3.6683; accuracy=0.0200
# Train Batch 200 (every 100 batch): Loss=3.6910; accuracy=0.0225
# Train Batch 300 (every 100 batch): Loss=3.6737; accuracy=0.0258
# Train Batch 400 (every 100 batch): Loss=3.7019; accuracy=0.0247
# Epoch 7 summary: train_loss: 3.6886 | train_acc: 0.0255 | val_loss: 3.7062 | val_acc: 0.0223
# Epoch 8
# Train Batch 100 (every 100 batch): Loss=3.6683; accuracy=0.0406
# Train Batch 200 (every 100 batch): Loss=3.6519; accuracy=0.0341
# Train Batch 300 (every 100 batch): Loss=3.6856; accuracy=0.0323
# Train Batch 400 (every 100 batch): Loss=3.7122; accuracy=0.0322
# Epoch 8 summary: train_loss: 3.6850 | train_acc: 0.0324 | val_loss: 3.6989 | val_acc: 0.0220
# Epoch 9
# Train Batch 100 (every 100 batch): Loss=3.6829; accuracy=0.0244
# Train Batch 200 (every 100 batch): Loss=3.6855; accuracy=0.0300
# Train Batch 300 (every 100 batch): Loss=3.6482; accuracy=0.0350
# Train Batch 400 (every 100 batch): Loss=3.5650; accuracy=0.0378
# Epoch 9 summary: train_loss: 3.6461 | train_acc: 0.0384 | val_loss: 3.6040 | val_acc: 0.0375
# Epoch 10
# Train Batch 100 (every 100 batch): Loss=3.9699; accuracy=0.0456
# Train Batch 200 (every 100 batch): Loss=3.3557; accuracy=0.0450
# Train Batch 300 (every 100 batch): Loss=3.4954; accuracy=0.0467
# Train Batch 400 (every 100 batch): Loss=3.4523; accuracy=0.0483
# Epoch 10 summary: train_loss: 3.4828 | train_acc: 0.0482 | val_loss: 3.3734 | val_acc: 0.0555
# Epoch 11
# Train Batch 100 (every 100 batch): Loss=3.4358; accuracy=0.0644
# Train Batch 200 (every 100 batch): Loss=3.1529; accuracy=0.0672
# Train Batch 300 (every 100 batch): Loss=3.5656; accuracy=0.0685
# Train Batch 400 (every 100 batch): Loss=3.2764; accuracy=0.0683
# Epoch 11 summary: train_loss: 3.2274 | train_acc: 0.0727 | val_loss: 3.1125 | val_acc: 0.0873
# Epoch 12
# Train Batch 100 (every 100 batch): Loss=3.1941; accuracy=0.0919
# Train Batch 200 (every 100 batch): Loss=3.1057; accuracy=0.0978
# Train Batch 300 (every 100 batch): Loss=3.1377; accuracy=0.1006
# Train Batch 400 (every 100 batch): Loss=2.9375; accuracy=0.1027
# Epoch 12 summary: train_loss: 2.9200 | train_acc: 0.1062 | val_loss: 2.7720 | val_acc: 0.1026
# Epoch 13
# Train Batch 100 (every 100 batch): Loss=2.9187; accuracy=0.1281
# Train Batch 200 (every 100 batch): Loss=2.6150; accuracy=0.1284
# Train Batch 300 (every 100 batch): Loss=2.7530; accuracy=0.1350
# Train Batch 400 (every 100 batch): Loss=2.5751; accuracy=0.1333
# Epoch 13 summary: train_loss: 2.6494 | train_acc: 0.1368 | val_loss: 2.4720 | val_acc: 0.1614
# Epoch 14
# Train Batch 100 (every 100 batch): Loss=2.2266; accuracy=0.1731
# Train Batch 200 (every 100 batch): Loss=2.0954; accuracy=0.1666
# Train Batch 300 (every 100 batch): Loss=2.3826; accuracy=0.1667
# Train Batch 400 (every 100 batch): Loss=2.3248; accuracy=0.1673
# Epoch 14 summary: train_loss: 2.4600 | train_acc: 0.1696 | val_loss: 2.2612 | val_acc: 0.2110
# Epoch 15
# Train Batch 100 (every 100 batch): Loss=2.8246; accuracy=0.1831
# Train Batch 200 (every 100 batch): Loss=2.4539; accuracy=0.1894
# Train Batch 300 (every 100 batch): Loss=1.8664; accuracy=0.1894
# Train Batch 400 (every 100 batch): Loss=2.5204; accuracy=0.1928
# Epoch 15 summary: train_loss: 2.3127 | train_acc: 0.1930 | val_loss: 2.1649 | val_acc: 0.2458
# Epoch 16
# Train Batch 100 (every 100 batch): Loss=2.0881; accuracy=0.2206
# Train Batch 200 (every 100 batch): Loss=1.8971; accuracy=0.2191
# Train Batch 300 (every 100 batch): Loss=1.9421; accuracy=0.2204
# Train Batch 400 (every 100 batch): Loss=2.4216; accuracy=0.2264
# Epoch 16 summary: train_loss: 2.1867 | train_acc: 0.2273 | val_loss: 2.0559 | val_acc: 0.2347
# Epoch 17
# Train Batch 100 (every 100 batch): Loss=2.1605; accuracy=0.2444
# Train Batch 200 (every 100 batch): Loss=2.3110; accuracy=0.2406
# Train Batch 300 (every 100 batch): Loss=1.8365; accuracy=0.2417
# Train Batch 400 (every 100 batch): Loss=2.5331; accuracy=0.2458
# Epoch 17 summary: train_loss: 2.1093 | train_acc: 0.2438 | val_loss: 2.0269 | val_acc: 0.2631
# Epoch 18
# Train Batch 100 (every 100 batch): Loss=2.3735; accuracy=0.2537
# Train Batch 200 (every 100 batch): Loss=2.0633; accuracy=0.2512
# Train Batch 300 (every 100 batch): Loss=2.1123; accuracy=0.2490
# Train Batch 400 (every 100 batch): Loss=1.8668; accuracy=0.2477
# Epoch 18 summary: train_loss: 2.0236 | train_acc: 0.2542 | val_loss: 1.9754 | val_acc: 0.2747
# Epoch 19
# Train Batch 100 (every 100 batch): Loss=1.8715; accuracy=0.2844
# Train Batch 200 (every 100 batch): Loss=1.7618; accuracy=0.2884
# Train Batch 300 (every 100 batch): Loss=1.8996; accuracy=0.2783
# Train Batch 400 (every 100 batch): Loss=1.5264; accuracy=0.2823
# Epoch 19 summary: train_loss: 1.9552 | train_acc: 0.2818 | val_loss: 1.9155 | val_acc: 0.2796
# Epoch 20
# Train Batch 100 (every 100 batch): Loss=1.7005; accuracy=0.3019
# Train Batch 200 (every 100 batch): Loss=1.7491; accuracy=0.3047
# Train Batch 300 (every 100 batch): Loss=1.6354; accuracy=0.3019
# Train Batch 400 (every 100 batch): Loss=1.8270; accuracy=0.3023
# Epoch 20 summary: train_loss: 1.8908 | train_acc: 0.3012 | val_loss: 1.8846 | val_acc: 0.2829
# Epoch 21
# Train Batch 100 (every 100 batch): Loss=2.1022; accuracy=0.2987
# Train Batch 200 (every 100 batch): Loss=1.6361; accuracy=0.3072
# Train Batch 300 (every 100 batch): Loss=1.6421; accuracy=0.3017
# Train Batch 400 (every 100 batch): Loss=1.8439; accuracy=0.3072
# Epoch 21 summary: train_loss: 1.8595 | train_acc: 0.3105 | val_loss: 1.8155 | val_acc: 0.3314
# Epoch 22
# Train Batch 100 (every 100 batch): Loss=1.9419; accuracy=0.3244
# Train Batch 200 (every 100 batch): Loss=1.6476; accuracy=0.3219
# Train Batch 300 (every 100 batch): Loss=1.8318; accuracy=0.3221
# Train Batch 400 (every 100 batch): Loss=1.5997; accuracy=0.3186
# Epoch 22 summary: train_loss: 1.8106 | train_acc: 0.3228 | val_loss: 1.7389 | val_acc: 0.3339
# Epoch 23
# Train Batch 100 (every 100 batch): Loss=1.9069; accuracy=0.3337
# Train Batch 200 (every 100 batch): Loss=2.2303; accuracy=0.3434
# Train Batch 300 (every 100 batch): Loss=1.9019; accuracy=0.3331
# Train Batch 400 (every 100 batch): Loss=1.2302; accuracy=0.3336
# Epoch 23 summary: train_loss: 1.7676 | train_acc: 0.3286 | val_loss: 1.7658 | val_acc: 0.3276
# Epoch 24
# Train Batch 100 (every 100 batch): Loss=1.5528; accuracy=0.3681
# Train Batch 200 (every 100 batch): Loss=1.3971; accuracy=0.3450
# Train Batch 300 (every 100 batch): Loss=1.5830; accuracy=0.3377
# Train Batch 400 (every 100 batch): Loss=1.6008; accuracy=0.3461
# Epoch 24 summary: train_loss: 1.7216 | train_acc: 0.3470 | val_loss: 1.7822 | val_acc: 0.3175
# Epoch 25
# Train Batch 100 (every 100 batch): Loss=1.4221; accuracy=0.3644
# Train Batch 200 (every 100 batch): Loss=2.0699; accuracy=0.3675
# Train Batch 300 (every 100 batch): Loss=1.7197; accuracy=0.3627
# Train Batch 400 (every 100 batch): Loss=2.0530; accuracy=0.3589
# Epoch 25 summary: train_loss: 1.7017 | train_acc: 0.3574 | val_loss: 1.7418 | val_acc: 0.3289
# Epoch 26
# Train Batch 100 (every 100 batch): Loss=1.8595; accuracy=0.3562
# Train Batch 200 (every 100 batch): Loss=1.9038; accuracy=0.3575
# Train Batch 300 (every 100 batch): Loss=1.4730; accuracy=0.3650
# Train Batch 400 (every 100 batch): Loss=1.6783; accuracy=0.3637
# Epoch 26 summary: train_loss: 1.6646 | train_acc: 0.3668 | val_loss: 1.7308 | val_acc: 0.3480
# Epoch 27
# Train Batch 100 (every 100 batch): Loss=1.2376; accuracy=0.3856
# Train Batch 200 (every 100 batch): Loss=1.6612; accuracy=0.3862
# Train Batch 300 (every 100 batch): Loss=1.4869; accuracy=0.3852
# Train Batch 400 (every 100 batch): Loss=1.5612; accuracy=0.3791
# Epoch 27 summary: train_loss: 1.6375 | train_acc: 0.3786 | val_loss: 1.8399 | val_acc: 0.3319
# Epoch 28
# Train Batch 100 (every 100 batch): Loss=1.6146; accuracy=0.3937
# Train Batch 200 (every 100 batch): Loss=1.7900; accuracy=0.3931
# Train Batch 300 (every 100 batch): Loss=1.8328; accuracy=0.3858
# Train Batch 400 (every 100 batch): Loss=1.6685; accuracy=0.3800
# Epoch 28 summary: train_loss: 1.6022 | train_acc: 0.3768 | val_loss: 1.6810 | val_acc: 0.3607
# Epoch 29
# Train Batch 100 (every 100 batch): Loss=1.4137; accuracy=0.3856
# Train Batch 200 (every 100 batch): Loss=1.1949; accuracy=0.3962
# Train Batch 300 (every 100 batch): Loss=1.4788; accuracy=0.3910
# Train Batch 400 (every 100 batch): Loss=1.4102; accuracy=0.3895
# Epoch 29 summary: train_loss: 1.5733 | train_acc: 0.3933 | val_loss: 1.6560 | val_acc: 0.3686
# Epoch 30
# Train Batch 100 (every 100 batch): Loss=1.5558; accuracy=0.4087
# Train Batch 200 (every 100 batch): Loss=1.3563; accuracy=0.4084
# Train Batch 300 (every 100 batch): Loss=1.2295; accuracy=0.4013
# Train Batch 400 (every 100 batch): Loss=1.8800; accuracy=0.4017
# Epoch 30 summary: train_loss: 1.5406 | train_acc: 0.3984 | val_loss: 1.6748 | val_acc: 0.3795
# Epoch 31
# Train Batch 100 (every 100 batch): Loss=1.5007; accuracy=0.4144
# Train Batch 200 (every 100 batch): Loss=1.4372; accuracy=0.4153
# Train Batch 300 (every 100 batch): Loss=1.9084; accuracy=0.4163
# Train Batch 400 (every 100 batch): Loss=2.0360; accuracy=0.4183
# Epoch 31 summary: train_loss: 1.5097 | train_acc: 0.4163 | val_loss: 1.6368 | val_acc: 0.3957
# Epoch 32
# Train Batch 100 (every 100 batch): Loss=2.0324; accuracy=0.4225
# Train Batch 200 (every 100 batch): Loss=1.4222; accuracy=0.4297
# Train Batch 300 (every 100 batch): Loss=1.3428; accuracy=0.4333
# Train Batch 400 (every 100 batch): Loss=1.6006; accuracy=0.4286
# Epoch 32 summary: train_loss: 1.4808 | train_acc: 0.4280 | val_loss: 1.6106 | val_acc: 0.3864
# Epoch 33
# Train Batch 100 (every 100 batch): Loss=1.0635; accuracy=0.4637
# Train Batch 200 (every 100 batch): Loss=1.6068; accuracy=0.4394
# Train Batch 300 (every 100 batch): Loss=1.0199; accuracy=0.4356
# Train Batch 400 (every 100 batch): Loss=1.0943; accuracy=0.4350
# Epoch 33 summary: train_loss: 1.4577 | train_acc: 0.4336 | val_loss: 1.6233 | val_acc: 0.4007
# Epoch 34
# Train Batch 100 (every 100 batch): Loss=1.4269; accuracy=0.4431
# Train Batch 200 (every 100 batch): Loss=1.7725; accuracy=0.4303
# Train Batch 300 (every 100 batch): Loss=1.4220; accuracy=0.4417
# Train Batch 400 (every 100 batch): Loss=1.4683; accuracy=0.4372
# Epoch 34 summary: train_loss: 1.4435 | train_acc: 0.4365 | val_loss: 1.6292 | val_acc: 0.3956
# Epoch 35
# Train Batch 100 (every 100 batch): Loss=1.3810; accuracy=0.4506
# Train Batch 200 (every 100 batch): Loss=1.6418; accuracy=0.4419
# Train Batch 300 (every 100 batch): Loss=1.3701; accuracy=0.4423
# Train Batch 400 (every 100 batch): Loss=1.2797; accuracy=0.4458
# Epoch 35 summary: train_loss: 1.4242 | train_acc: 0.4423 | val_loss: 1.5533 | val_acc: 0.4230
# Epoch 36
# Train Batch 100 (every 100 batch): Loss=1.6493; accuracy=0.4781
# Train Batch 200 (every 100 batch): Loss=1.5054; accuracy=0.4737
# Train Batch 300 (every 100 batch): Loss=1.2456; accuracy=0.4650
# Train Batch 400 (every 100 batch): Loss=1.0809; accuracy=0.4623
# Epoch 36 summary: train_loss: 1.3912 | train_acc: 0.4604 | val_loss: 1.5731 | val_acc: 0.4368
# Epoch 37
# Train Batch 100 (every 100 batch): Loss=1.4871; accuracy=0.4606
# Train Batch 200 (every 100 batch): Loss=1.4111; accuracy=0.4584
# Train Batch 300 (every 100 batch): Loss=1.2932; accuracy=0.4642
# Train Batch 400 (every 100 batch): Loss=1.1906; accuracy=0.4667
# Epoch 37 summary: train_loss: 1.3675 | train_acc: 0.4636 | val_loss: 1.5655 | val_acc: 0.4189
# Epoch 38
# Train Batch 100 (every 100 batch): Loss=1.6796; accuracy=0.4956
# Train Batch 200 (every 100 batch): Loss=1.5649; accuracy=0.4769
# Train Batch 300 (every 100 batch): Loss=0.9987; accuracy=0.4704
# Train Batch 400 (every 100 batch): Loss=0.9881; accuracy=0.4755
# Epoch 38 summary: train_loss: 1.3531 | train_acc: 0.4751 | val_loss: 1.6756 | val_acc: 0.4043
# Epoch 39
# Train Batch 100 (every 100 batch): Loss=1.0915; accuracy=0.4988
# Train Batch 200 (every 100 batch): Loss=1.4116; accuracy=0.4912
# Train Batch 300 (every 100 batch): Loss=1.3263; accuracy=0.4879
# Train Batch 400 (every 100 batch): Loss=1.0874; accuracy=0.4834
# Epoch 39 summary: train_loss: 1.3413 | train_acc: 0.4775 | val_loss: 1.5588 | val_acc: 0.4401
# Epoch 40
# Train Batch 100 (every 100 batch): Loss=1.5127; accuracy=0.5219
# Train Batch 200 (every 100 batch): Loss=1.2965; accuracy=0.5034
# Train Batch 300 (every 100 batch): Loss=1.3172; accuracy=0.4877
# Train Batch 400 (every 100 batch): Loss=1.7024; accuracy=0.4856
# Epoch 40 summary: train_loss: 1.3220 | train_acc: 0.4845 | val_loss: 1.5183 | val_acc: 0.4422
# Epoch 41
# Train Batch 100 (every 100 batch): Loss=1.0339; accuracy=0.5025
# Train Batch 200 (every 100 batch): Loss=1.5213; accuracy=0.5003
# Train Batch 300 (every 100 batch): Loss=1.2367; accuracy=0.5000
# Train Batch 400 (every 100 batch): Loss=1.1609; accuracy=0.4914
# Epoch 41 summary: train_loss: 1.2931 | train_acc: 0.4902 | val_loss: 1.6073 | val_acc: 0.4234
# Epoch 42
# Train Batch 100 (every 100 batch): Loss=0.9042; accuracy=0.5025
# Train Batch 200 (every 100 batch): Loss=1.2071; accuracy=0.5066
# Train Batch 300 (every 100 batch): Loss=1.6509; accuracy=0.4981
# Train Batch 400 (every 100 batch): Loss=1.4026; accuracy=0.4981
# Epoch 42 summary: train_loss: 1.2731 | train_acc: 0.4997 | val_loss: 1.5022 | val_acc: 0.4617
# Epoch 43
# Train Batch 100 (every 100 batch): Loss=1.4732; accuracy=0.4869
# Train Batch 200 (every 100 batch): Loss=1.1086; accuracy=0.5003
# Train Batch 300 (every 100 batch): Loss=1.2987; accuracy=0.5096
# Train Batch 400 (every 100 batch): Loss=0.9131; accuracy=0.5092
# Epoch 43 summary: train_loss: 1.2628 | train_acc: 0.5070 | val_loss: 1.5691 | val_acc: 0.4381
# Epoch 44
# Train Batch 100 (every 100 batch): Loss=1.1333; accuracy=0.5288
# Train Batch 200 (every 100 batch): Loss=1.3872; accuracy=0.5319
# Train Batch 300 (every 100 batch): Loss=1.3324; accuracy=0.5215
# Train Batch 400 (every 100 batch): Loss=1.3155; accuracy=0.5139
# Epoch 44 summary: train_loss: 1.2433 | train_acc: 0.5121 | val_loss: 1.5013 | val_acc: 0.4616
# Epoch 45
# Train Batch 100 (every 100 batch): Loss=1.0624; accuracy=0.5288
# Train Batch 200 (every 100 batch): Loss=0.9467; accuracy=0.5125
# Train Batch 300 (every 100 batch): Loss=0.8536; accuracy=0.5227
# Train Batch 400 (every 100 batch): Loss=1.2708; accuracy=0.5200
# Epoch 45 summary: train_loss: 1.2249 | train_acc: 0.5186 | val_loss: 1.4972 | val_acc: 0.4491
# Epoch 46
# Train Batch 100 (every 100 batch): Loss=1.0594; accuracy=0.5481
# Train Batch 200 (every 100 batch): Loss=1.3563; accuracy=0.5481
# Train Batch 300 (every 100 batch): Loss=0.8637; accuracy=0.5462
# Train Batch 400 (every 100 batch): Loss=1.0377; accuracy=0.5394
# Epoch 46 summary: train_loss: 1.1881 | train_acc: 0.5332 | val_loss: 1.5193 | val_acc: 0.4694
# Epoch 47
# Train Batch 100 (every 100 batch): Loss=1.0928; accuracy=0.5437
# Train Batch 200 (every 100 batch): Loss=1.2596; accuracy=0.5469
# Train Batch 300 (every 100 batch): Loss=1.0482; accuracy=0.5479
# Train Batch 400 (every 100 batch): Loss=1.3200; accuracy=0.5402
# Epoch 47 summary: train_loss: 1.1805 | train_acc: 0.5386 | val_loss: 1.5916 | val_acc: 0.4461
# Epoch 48
# Train Batch 100 (every 100 batch): Loss=1.2236; accuracy=0.5494
# Train Batch 200 (every 100 batch): Loss=1.2011; accuracy=0.5441
# Train Batch 300 (every 100 batch): Loss=0.8611; accuracy=0.5465
# Train Batch 400 (every 100 batch): Loss=1.0433; accuracy=0.5406
# Epoch 48 summary: train_loss: 1.1660 | train_acc: 0.5410 | val_loss: 1.5633 | val_acc: 0.4559
# Epoch 49
# Train Batch 100 (every 100 batch): Loss=1.0867; accuracy=0.5544
# Train Batch 200 (every 100 batch): Loss=0.9261; accuracy=0.5444
# Train Batch 300 (every 100 batch): Loss=0.4950; accuracy=0.5510
# Train Batch 400 (every 100 batch): Loss=1.4105; accuracy=0.5489
# Epoch 49 summary: train_loss: 1.1461 | train_acc: 0.5501 | val_loss: 1.5804 | val_acc: 0.4651
# Epoch 50
# Train Batch 100 (every 100 batch): Loss=0.9185; accuracy=0.5850
# Train Batch 200 (every 100 batch): Loss=0.8919; accuracy=0.5675
# Train Batch 300 (every 100 batch): Loss=0.9371; accuracy=0.5577
# Train Batch 400 (every 100 batch): Loss=1.0874; accuracy=0.5556
# Epoch 50 summary: train_loss: 1.1391 | train_acc: 0.5535 | val_loss: 1.5411 | val_acc: 0.4575
# Epoch 51
# Train Batch 100 (every 100 batch): Loss=0.9286; accuracy=0.5894
# Train Batch 200 (every 100 batch): Loss=0.9525; accuracy=0.5741
# Train Batch 300 (every 100 batch): Loss=1.2108; accuracy=0.5775
# Train Batch 400 (every 100 batch): Loss=1.5981; accuracy=0.5711
# Epoch 51 summary: train_loss: 1.1038 | train_acc: 0.5658 | val_loss: 1.5471 | val_acc: 0.4796
# Epoch 52
# Train Batch 100 (every 100 batch): Loss=1.2687; accuracy=0.5656
# Train Batch 200 (every 100 batch): Loss=0.8819; accuracy=0.5816
# Train Batch 300 (every 100 batch): Loss=0.9640; accuracy=0.5713
# Train Batch 400 (every 100 batch): Loss=1.8626; accuracy=0.5741
# Epoch 52 summary: train_loss: 1.0876 | train_acc: 0.5715 | val_loss: 1.5747 | val_acc: 0.4640
# Epoch 53
# Train Batch 100 (every 100 batch): Loss=1.0452; accuracy=0.5781
# Train Batch 200 (every 100 batch): Loss=1.2322; accuracy=0.5800
# Train Batch 300 (every 100 batch): Loss=1.1151; accuracy=0.5792
# Train Batch 400 (every 100 batch): Loss=0.9921; accuracy=0.5841
# Epoch 53 summary: train_loss: 1.0711 | train_acc: 0.5854 | val_loss: 1.5779 | val_acc: 0.4695
# Epoch 54
# Train Batch 100 (every 100 batch): Loss=1.5773; accuracy=0.6081
# Train Batch 200 (every 100 batch): Loss=1.2653; accuracy=0.6012
# Train Batch 300 (every 100 batch): Loss=1.1202; accuracy=0.5910
# Train Batch 400 (every 100 batch): Loss=0.8318; accuracy=0.5892
# Epoch 54 summary: train_loss: 1.0549 | train_acc: 0.5874 | val_loss: 1.5802 | val_acc: 0.4615
# Epoch 55
# Train Batch 100 (every 100 batch): Loss=1.1773; accuracy=0.6162
# Train Batch 200 (every 100 batch): Loss=1.3284; accuracy=0.6062
# Train Batch 300 (every 100 batch): Loss=1.1335; accuracy=0.6104
# Train Batch 400 (every 100 batch): Loss=0.8812; accuracy=0.6045
# Epoch 55 summary: train_loss: 1.0378 | train_acc: 0.6007 | val_loss: 1.6018 | val_acc: 0.4756
# Epoch 56
# Epoch 56 summary: train_loss: 1.0149 | train_acc: 0.6083 | val_loss: 1.5294 | val_acc: 0.4793
# Epoch 57
# Train Batch 100 (every 100 batch): Loss=0.8464; accuracy=0.6287
# Train Batch 200 (every 100 batch): Loss=0.6506; accuracy=0.6281
# Train Batch 300 (every 100 batch): Loss=0.6544; accuracy=0.6254
# Train Batch 400 (every 100 batch): Loss=0.6818; accuracy=0.6164
# Epoch 57 summary: train_loss: 1.0040 | train_acc: 0.6116 | val_loss: 1.6321 | val_acc: 0.4715
# Epoch 58
# Train Batch 100 (every 100 batch): Loss=1.1696; accuracy=0.6387
# Train Batch 200 (every 100 batch): Loss=1.4558; accuracy=0.6278
# Train Batch 300 (every 100 batch): Loss=1.0146; accuracy=0.6196
# Train Batch 400 (every 100 batch): Loss=1.0717; accuracy=0.6175
# Epoch 58 summary: train_loss: 0.9956 | train_acc: 0.6174 | val_loss: 1.6725 | val_acc: 0.4718
# Epoch 59
# Train Batch 100 (every 100 batch): Loss=0.6749; accuracy=0.6294
# Train Batch 200 (every 100 batch): Loss=0.9371; accuracy=0.6269
# Train Batch 300 (every 100 batch): Loss=0.8172; accuracy=0.6269
# Train Batch 400 (every 100 batch): Loss=0.9183; accuracy=0.6258
# Epoch 59 summary: train_loss: 0.9668 | train_acc: 0.6207 | val_loss: 1.7140 | val_acc: 0.4625
# Epoch 60
# Train Batch 100 (every 100 batch): Loss=1.0291; accuracy=0.6306
# Train Batch 200 (every 100 batch): Loss=1.1055; accuracy=0.6384
# Train Batch 300 (every 100 batch): Loss=1.1979; accuracy=0.6348
# Train Batch 400 (every 100 batch): Loss=0.8146; accuracy=0.6278
# Epoch 60 summary: train_loss: 0.9682 | train_acc: 0.6239 | val_loss: 1.6258 | val_acc: 0.4939
# Epoch 61
# Train Batch 100 (every 100 batch): Loss=0.5436; accuracy=0.6300
# Train Batch 200 (every 100 batch): Loss=1.0440; accuracy=0.6200
# Train Batch 300 (every 100 batch): Loss=0.7857; accuracy=0.6302
# Train Batch 400 (every 100 batch): Loss=1.3870; accuracy=0.6355
# Epoch 61 summary: train_loss: 0.9433 | train_acc: 0.6347 | val_loss: 1.6313 | val_acc: 0.4804
# Epoch 62
# Train Batch 100 (every 100 batch): Loss=0.8211; accuracy=0.6262
# Train Batch 200 (every 100 batch): Loss=0.8182; accuracy=0.6366
# Train Batch 300 (every 100 batch): Loss=1.0182; accuracy=0.6360
# Train Batch 400 (every 100 batch): Loss=0.6739; accuracy=0.6352
# Epoch 62 summary: train_loss: 0.9410 | train_acc: 0.6366 | val_loss: 1.6934 | val_acc: 0.4716
# Epoch 63
# Train Batch 100 (every 100 batch): Loss=1.3289; accuracy=0.6406
# Train Batch 200 (every 100 batch): Loss=0.7964; accuracy=0.6403
# Train Batch 300 (every 100 batch): Loss=0.4183; accuracy=0.6406
# Train Batch 400 (every 100 batch): Loss=0.6285; accuracy=0.6425
# Epoch 63 summary: train_loss: 0.9173 | train_acc: 0.6398 | val_loss: 1.7235 | val_acc: 0.4821
# Epoch 64
# Train Batch 100 (every 100 batch): Loss=0.6703; accuracy=0.6500
# Train Batch 200 (every 100 batch): Loss=0.9369; accuracy=0.6356
# Train Batch 300 (every 100 batch): Loss=0.9148; accuracy=0.6379
# Train Batch 400 (every 100 batch): Loss=0.8620; accuracy=0.6427
# Epoch 64 summary: train_loss: 0.9072 | train_acc: 0.6433 | val_loss: 1.7652 | val_acc: 0.4938
# Epoch 65
# Train Batch 100 (every 100 batch): Loss=0.5796; accuracy=0.6612
# Train Batch 200 (every 100 batch): Loss=0.9673; accuracy=0.6706
# Train Batch 300 (every 100 batch): Loss=1.2286; accuracy=0.6610
# Train Batch 400 (every 100 batch): Loss=0.5182; accuracy=0.6595
# Epoch 65 summary: train_loss: 0.8794 | train_acc: 0.6584 | val_loss: 1.7015 | val_acc: 0.4770
# Epoch 66
# Train Batch 100 (every 100 batch): Loss=0.8110; accuracy=0.6669
# Train Batch 200 (every 100 batch): Loss=1.2071; accuracy=0.6753
# Train Batch 300 (every 100 batch): Loss=1.0837; accuracy=0.6660
# Train Batch 400 (every 100 batch): Loss=0.8747; accuracy=0.6606
# Epoch 66 summary: train_loss: 0.8799 | train_acc: 0.6614 | val_loss: 1.8101 | val_acc: 0.4633
# Epoch 67
# Train Batch 100 (every 100 batch): Loss=0.7024; accuracy=0.6669
# Train Batch 200 (every 100 batch): Loss=0.9884; accuracy=0.6606
# Train Batch 300 (every 100 batch): Loss=0.9359; accuracy=0.6575
# Train Batch 400 (every 100 batch): Loss=0.9455; accuracy=0.6642
# Epoch 67 summary: train_loss: 0.8639 | train_acc: 0.6662 | val_loss: 1.7571 | val_acc: 0.4990
# Epoch 68
# Train Batch 100 (every 100 batch): Loss=0.7376; accuracy=0.6744
# Train Batch 200 (every 100 batch): Loss=0.9475; accuracy=0.6809
# Train Batch 300 (every 100 batch): Loss=1.1796; accuracy=0.6721
# Train Batch 400 (every 100 batch): Loss=0.8874; accuracy=0.6706
# Epoch 68 summary: train_loss: 0.8503 | train_acc: 0.6708 | val_loss: 1.7292 | val_acc: 0.4934
# Epoch 69
# Train Batch 100 (every 100 batch): Loss=0.9400; accuracy=0.6962
# Train Batch 200 (every 100 batch): Loss=0.8829; accuracy=0.6831
# Train Batch 300 (every 100 batch): Loss=0.9375; accuracy=0.6792
# Train Batch 400 (every 100 batch): Loss=1.1913; accuracy=0.6789
# Epoch 69 summary: train_loss: 0.8431 | train_acc: 0.6752 | val_loss: 1.7453 | val_acc: 0.4733
# Epoch 70
# Train Batch 100 (every 100 batch): Loss=0.9426; accuracy=0.6800
# Train Batch 200 (every 100 batch): Loss=0.6364; accuracy=0.6809
# Train Batch 300 (every 100 batch): Loss=0.9753; accuracy=0.6821
# Train Batch 400 (every 100 batch): Loss=0.5191; accuracy=0.6812
# Epoch 70 summary: train_loss: 0.8191 | train_acc: 0.6789 | val_loss: 1.8853 | val_acc: 0.4659
# Epoch 71
# Train Batch 100 (every 100 batch): Loss=1.0237; accuracy=0.6856
# Train Batch 200 (every 100 batch): Loss=0.7885; accuracy=0.6934
# Train Batch 300 (every 100 batch): Loss=0.5638; accuracy=0.6860
# Train Batch 400 (every 100 batch): Loss=0.6801; accuracy=0.6858
# Epoch 71 summary: train_loss: 0.7989 | train_acc: 0.6889 | val_loss: 1.7898 | val_acc: 0.4873
# Epoch 72
# Train Batch 100 (every 100 batch): Loss=0.8478; accuracy=0.7025
# Train Batch 200 (every 100 batch): Loss=1.3316; accuracy=0.6994
# Train Batch 300 (every 100 batch): Loss=0.5328; accuracy=0.6983
# Train Batch 400 (every 100 batch): Loss=0.5719; accuracy=0.6992
# Epoch 72 summary: train_loss: 0.7816 | train_acc: 0.6968 | val_loss: 1.7894 | val_acc: 0.4720
# Epoch 73
# Train Batch 100 (every 100 batch): Loss=0.6603; accuracy=0.7300
# Train Batch 200 (every 100 batch): Loss=0.6555; accuracy=0.7206
# Train Batch 300 (every 100 batch): Loss=1.0593; accuracy=0.7083
# Train Batch 400 (every 100 batch): Loss=0.5540; accuracy=0.7028
# Epoch 73 summary: train_loss: 0.7726 | train_acc: 0.7041 | val_loss: 2.0103 | val_acc: 0.4815
# Epoch 74
# Train Batch 100 (every 100 batch): Loss=0.7095; accuracy=0.7275
# Train Batch 200 (every 100 batch): Loss=0.6287; accuracy=0.7262
# Train Batch 300 (every 100 batch): Loss=0.4464; accuracy=0.7152
# Train Batch 400 (every 100 batch): Loss=0.7535; accuracy=0.7111
# Epoch 74 summary: train_loss: 0.7596 | train_acc: 0.7099 | val_loss: 1.9082 | val_acc: 0.4918
# Epoch 75
# Train Batch 100 (every 100 batch): Loss=0.8302; accuracy=0.7163
# Train Batch 200 (every 100 batch): Loss=0.5727; accuracy=0.7078
# Train Batch 300 (every 100 batch): Loss=0.4845; accuracy=0.7102
# Train Batch 400 (every 100 batch): Loss=0.5849; accuracy=0.7092
# Epoch 75 summary: train_loss: 0.7623 | train_acc: 0.7095 | val_loss: 2.0031 | val_acc: 0.4635
# Epoch 76
# Train Batch 100 (every 100 batch): Loss=0.9445; accuracy=0.7144
# Train Batch 200 (every 100 batch): Loss=1.1541; accuracy=0.7081
# Train Batch 300 (every 100 batch): Loss=1.1624; accuracy=0.7098
# Train Batch 400 (every 100 batch): Loss=0.6789; accuracy=0.7119
# Epoch 76 summary: train_loss: 0.7551 | train_acc: 0.7087 | val_loss: 1.9279 | val_acc: 0.4851
# Epoch 77
# Train Batch 100 (every 100 batch): Loss=0.6467; accuracy=0.7531
# Train Batch 200 (every 100 batch): Loss=0.8832; accuracy=0.7353
# Train Batch 300 (every 100 batch): Loss=0.8029; accuracy=0.7325
# Train Batch 400 (every 100 batch): Loss=0.5080; accuracy=0.7286
# Epoch 77 summary: train_loss: 0.7215 | train_acc: 0.7278 | val_loss: 1.9095 | val_acc: 0.5029
# Epoch 78
# Train Batch 100 (every 100 batch): Loss=0.4665; accuracy=0.7275
# Train Batch 200 (every 100 batch): Loss=0.2949; accuracy=0.7297
# Train Batch 300 (every 100 batch): Loss=0.6523; accuracy=0.7292
# Train Batch 400 (every 100 batch): Loss=0.7619; accuracy=0.7303
# Epoch 78 summary: train_loss: 0.7111 | train_acc: 0.7278 | val_loss: 2.0450 | val_acc: 0.5046
# Epoch 79
# Train Batch 100 (every 100 batch): Loss=0.8468; accuracy=0.7587
# Train Batch 200 (every 100 batch): Loss=0.8081; accuracy=0.7478
# Train Batch 300 (every 100 batch): Loss=0.5929; accuracy=0.7467
# Train Batch 400 (every 100 batch): Loss=0.5001; accuracy=0.7420
# Epoch 79 summary: train_loss: 0.7005 | train_acc: 0.7348 | val_loss: 1.9315 | val_acc: 0.4959
# Epoch 80
# Train Batch 100 (every 100 batch): Loss=0.5429; accuracy=0.7312
# Train Batch 200 (every 100 batch): Loss=0.6550; accuracy=0.7359
# Train Batch 300 (every 100 batch): Loss=1.1709; accuracy=0.7246
# Train Batch 400 (every 100 batch): Loss=0.4973; accuracy=0.7228
# Epoch 80 summary: train_loss: 0.7258 | train_acc: 0.7196 | val_loss: 1.8368 | val_acc: 0.5049
# Epoch 81
# Train Batch 100 (every 100 batch): Loss=0.3854; accuracy=0.7525
# Train Batch 200 (every 100 batch): Loss=0.5753; accuracy=0.7559
# Train Batch 300 (every 100 batch): Loss=0.7577; accuracy=0.7575
# Train Batch 400 (every 100 batch): Loss=0.6162; accuracy=0.7612
# Epoch 81 summary: train_loss: 0.6446 | train_acc: 0.7583 | val_loss: 2.0552 | val_acc: 0.4710
# Epoch 82
# Train Batch 100 (every 100 batch): Loss=0.4323; accuracy=0.7681
# Train Batch 200 (every 100 batch): Loss=0.5953; accuracy=0.7512
# Train Batch 300 (every 100 batch): Loss=0.5573; accuracy=0.7558
# Train Batch 400 (every 100 batch): Loss=0.7858; accuracy=0.7531
# Epoch 82 summary: train_loss: 0.6650 | train_acc: 0.7489 | val_loss: 1.9983 | val_acc: 0.5027
# Epoch 83
# Train Batch 100 (every 100 batch): Loss=0.3893; accuracy=0.7650
# Train Batch 200 (every 100 batch): Loss=1.2076; accuracy=0.7622
# Train Batch 300 (every 100 batch): Loss=0.6115; accuracy=0.7606
# Train Batch 400 (every 100 batch): Loss=0.6743; accuracy=0.7569
# Epoch 83 summary: train_loss: 0.6582 | train_acc: 0.7526 | val_loss: 1.8949 | val_acc: 0.4754
# Epoch 84
# Train Batch 100 (every 100 batch): Loss=1.1348; accuracy=0.7812
# Train Batch 200 (every 100 batch): Loss=0.8233; accuracy=0.7616
# Train Batch 300 (every 100 batch): Loss=0.5301; accuracy=0.7560
# Train Batch 400 (every 100 batch): Loss=0.9520; accuracy=0.7539
# Epoch 84 summary: train_loss: 0.6604 | train_acc: 0.7493 | val_loss: 1.9100 | val_acc: 0.4880
# Epoch 85
# Train Batch 100 (every 100 batch): Loss=0.7989; accuracy=0.7606
# Train Batch 200 (every 100 batch): Loss=0.6085; accuracy=0.7569
# Train Batch 300 (every 100 batch): Loss=0.8075; accuracy=0.7554
# Train Batch 400 (every 100 batch): Loss=0.4943; accuracy=0.7533
# Epoch 85 summary: train_loss: 0.6645 | train_acc: 0.7534 | val_loss: 1.9602 | val_acc: 0.4762
# Epoch 86
# Train Batch 100 (every 100 batch): Loss=0.5366; accuracy=0.7756
# Train Batch 200 (every 100 batch): Loss=0.8979; accuracy=0.7741
# Train Batch 300 (every 100 batch): Loss=0.5724; accuracy=0.7692
# Train Batch 400 (every 100 batch): Loss=0.7797; accuracy=0.7684
# Epoch 86 summary: train_loss: 0.6202 | train_acc: 0.7653 | val_loss: 1.9266 | val_acc: 0.4846
# Epoch 87
# Train Batch 100 (every 100 batch): Loss=0.3005; accuracy=0.7831
# Train Batch 200 (every 100 batch): Loss=0.6258; accuracy=0.7731
# Train Batch 300 (every 100 batch): Loss=0.7896; accuracy=0.7660
# Train Batch 400 (every 100 batch): Loss=0.8133; accuracy=0.7631
# Epoch 87 summary: train_loss: 0.6115 | train_acc: 0.7616 | val_loss: 2.0376 | val_acc: 0.4917
# Epoch 88
# Train Batch 100 (every 100 batch): Loss=0.3724; accuracy=0.7837
# Train Batch 200 (every 100 batch): Loss=0.3360; accuracy=0.7822
# Train Batch 300 (every 100 batch): Loss=0.1537; accuracy=0.7779
# Train Batch 400 (every 100 batch): Loss=0.6778; accuracy=0.7763
# Epoch 88 summary: train_loss: 0.5932 | train_acc: 0.7724 | val_loss: 2.1482 | val_acc: 0.4753
# Epoch 89
# Train Batch 100 (every 100 batch): Loss=0.5938; accuracy=0.7594
# Train Batch 200 (every 100 batch): Loss=0.3628; accuracy=0.7706
# Train Batch 300 (every 100 batch): Loss=0.5129; accuracy=0.7748
# Train Batch 400 (every 100 batch): Loss=0.2239; accuracy=0.7744
# Epoch 89 summary: train_loss: 0.6028 | train_acc: 0.7760 | val_loss: 2.1694 | val_acc: 0.4710
# Epoch 90
# Train Batch 100 (every 100 batch): Loss=0.5722; accuracy=0.7788
# Train Batch 200 (every 100 batch): Loss=0.5340; accuracy=0.7759
# Train Batch 300 (every 100 batch): Loss=0.5635; accuracy=0.7775
# Train Batch 400 (every 100 batch): Loss=0.8882; accuracy=0.7766
# Epoch 90 summary: train_loss: 0.5936 | train_acc: 0.7768 | val_loss: 2.0436 | val_acc: 0.5008
# Epoch 91
# Train Batch 100 (every 100 batch): Loss=0.4862; accuracy=0.8062
# Train Batch 200 (every 100 batch): Loss=0.3429; accuracy=0.8056
# Train Batch 300 (every 100 batch): Loss=0.3022; accuracy=0.8025
# Train Batch 400 (every 100 batch): Loss=0.4572; accuracy=0.7955
# Epoch 91 summary: train_loss: 0.5728 | train_acc: 0.7895 | val_loss: 2.0850 | val_acc: 0.4906
# Epoch 92
# Train Batch 100 (every 100 batch): Loss=0.7496; accuracy=0.8012
# Train Batch 200 (every 100 batch): Loss=0.4173; accuracy=0.7969
# Train Batch 300 (every 100 batch): Loss=0.3211; accuracy=0.7890
# Train Batch 400 (every 100 batch): Loss=1.1778; accuracy=0.7872
# Epoch 92 summary: train_loss: 0.5538 | train_acc: 0.7864 | val_loss: 2.2336 | val_acc: 0.4788
# Epoch 93
# Train Batch 100 (every 100 batch): Loss=0.6158; accuracy=0.8012
# Train Batch 200 (every 100 batch): Loss=0.5758; accuracy=0.7941
# Train Batch 300 (every 100 batch): Loss=0.6766; accuracy=0.7929
# Train Batch 400 (every 100 batch): Loss=0.9664; accuracy=0.7952
# Epoch 93 summary: train_loss: 0.5657 | train_acc: 0.7963 | val_loss: 2.2384 | val_acc: 0.4981
# Epoch 94
# Train Batch 100 (every 100 batch): Loss=0.5529; accuracy=0.8000
# Train Batch 200 (every 100 batch): Loss=0.5330; accuracy=0.8006
# Train Batch 300 (every 100 batch): Loss=0.7585; accuracy=0.8044
# Train Batch 400 (every 100 batch): Loss=0.2381; accuracy=0.8017
# Epoch 94 summary: train_loss: 0.5603 | train_acc: 0.7993 | val_loss: 2.0452 | val_acc: 0.4950
# Epoch 95
# Train Batch 100 (every 100 batch): Loss=0.5540; accuracy=0.8181
# Train Batch 200 (every 100 batch): Loss=0.2459; accuracy=0.8044
# Train Batch 300 (every 100 batch): Loss=0.3008; accuracy=0.7994
# Train Batch 400 (every 100 batch): Loss=0.6811; accuracy=0.7916
# Epoch 95 summary: train_loss: 0.5408 | train_acc: 0.7958 | val_loss: 2.2622 | val_acc: 0.4734
# Epoch 96
# Train Batch 100 (every 100 batch): Loss=0.6882; accuracy=0.8150
# Train Batch 200 (every 100 batch): Loss=0.3239; accuracy=0.8059
# Train Batch 300 (every 100 batch): Loss=0.0855; accuracy=0.8021
# Train Batch 400 (every 100 batch): Loss=0.4258; accuracy=0.8050
# Epoch 96 summary: train_loss: 0.5414 | train_acc: 0.8032 | val_loss: 2.2000 | val_acc: 0.4977
# Epoch 97
# Train Batch 100 (every 100 batch): Loss=1.2277; accuracy=0.7956
# Train Batch 200 (every 100 batch): Loss=0.5244; accuracy=0.8000
# Train Batch 300 (every 100 batch): Loss=0.5193; accuracy=0.7975
# Train Batch 400 (every 100 batch): Loss=0.6257; accuracy=0.7980
# Epoch 97 summary: train_loss: 0.5549 | train_acc: 0.7973 | val_loss: 2.2276 | val_acc: 0.4952
# Epoch 98
# Train Batch 100 (every 100 batch): Loss=0.3764; accuracy=0.8169
# Train Batch 200 (every 100 batch): Loss=0.4461; accuracy=0.8175
# Train Batch 300 (every 100 batch): Loss=0.5301; accuracy=0.8083
# Train Batch 400 (every 100 batch): Loss=0.5087; accuracy=0.8073
# Epoch 98 summary: train_loss: 0.5206 | train_acc: 0.8061 | val_loss: 2.1957 | val_acc: 0.4939
# Epoch 99
# Train Batch 100 (every 100 batch): Loss=0.5954; accuracy=0.8287
# Train Batch 200 (every 100 batch): Loss=0.5539; accuracy=0.8203
# Train Batch 300 (every 100 batch): Loss=0.4080; accuracy=0.8204
# Train Batch 400 (every 100 batch): Loss=0.2904; accuracy=0.8170
# Epoch 99 summary: train_loss: 0.5116 | train_acc: 0.8122 | val_loss: 2.3427 | val_acc: 0.4888
# Epoch 100
# Train Batch 100 (every 100 batch): Loss=0.1224; accuracy=0.8475
# Train Batch 200 (every 100 batch): Loss=0.6095; accuracy=0.8253
# Train Batch 300 (every 100 batch): Loss=0.4435; accuracy=0.8210
# Train Batch 400 (every 100 batch): Loss=0.4391; accuracy=0.8152
# Epoch 100 summary: train_loss: 0.5016 | train_acc: 0.8127 | val_loss: 2.2776 | val_acc: 0.4830

# %%
torch.save(results, results_path+'.obj')
# val =accuracy_val
# test = accuracy_test

# print("Validation accuracy: ", val)
# print("Test accuracy: ", test)

# %%
loaded_results = torch.load(results_path+'.obj')
print(loaded_results)
# Out:
# {'train_loss': [3.7101269098649543, 3.695097721245394, 3.692555018696919, 3.6898837664041175, 3.688021965773709, 3.688252726711901, 3.688568603082833, 3.685009175515079, 3.6461453313329613, 3.4827877206495965, 3.227399045683773, 2.9199543454082137, 2.6494324231243516, 2.459970349049472, 2.312655984637249, 2.186699749954254, 2.1093350186884163, 2.0236174418744315, 1.9551633294806423, 1.8907767553406067, 1.859491357602269, 1.8106118969649196, 1.7675866896368893, 1.7215799758711972, 1.701744964563224, 1.6646166380390106, 1.6375119451538147, 1.6022173965791142, 1.5732892691849705, 1.5406322436160351, 1.5097050077943917, 1.4808224854938477, 1.4577426686583752, 1.4434610300035362, 1.4241697721213222, 1.39117188326805, 1.3675374109821625, 1.3531405438620403, 1.3413155234482395, 1.322007790267707, 1.2931389459165703, 1.2730648779725453, 1.262846373889341, 1.2432913534851917, 1.2249121504375733, 1.1880692409942428, 1.1804797187387703, 1.1659706114047024, 1.1461362307330212, 1.1390808519110622, 1.1038170876991318, 1.0875943214539066, 1.0711350604951622, 1.0548622650674069, 1.0378475285557858, 1.0148617001661815, 1.003955138016896, 0.9955920450179931, 0.9667896466202526, 0.9681541791642048, 0.9433495359846866, 0.9409505216232744, 0.917305995841103, 0.9071685046436317, 0.8794402451998737, 0.8799445784115887, 0.8639458882282058, 0.8502525126180017, 0.8431291874931998, 0.8191347433082071, 0.7989172517774574, 0.7815699246992548, 0.7725648594548903, 0.7596479334745062, 0.7623355609166574, 0.7550724008116856, 0.7214778241622879, 0.7111273555750828, 0.7005214421265575, 0.7258446665712629, 0.6445660352796675, 0.6650134957279547, 0.658172974594865, 0.6604319715116876, 0.6645210601957926, 0.6202105826522452, 0.6114848593332203, 0.593221400785877, 0.602751184987974, 0.5936171109507601, 0.5728178240328907, 0.5538323178558225, 0.5657387808279459, 0.5603350970938982, 0.5408347557526995, 0.5413998508878262, 0.5549442295029939, 0.5206447090265383, 0.5115839146735918, 0.5015830204010489], 'train_acc': [tensor(0.0277, device='cuda:0'), tensor(0.0264, device='cuda:0'), tensor(0.0264, device='cuda:0'), tensor(0.0282, device='cuda:0'), tensor(0.0281, device='cuda:0'), tensor(0.0294, device='cuda:0'), tensor(0.0255, device='cuda:0'), tensor(0.0324, device='cuda:0'), tensor(0.0384, device='cuda:0'), tensor(0.0482, device='cuda:0'), tensor(0.0727, device='cuda:0'), tensor(0.1062, device='cuda:0'), tensor(0.1368, device='cuda:0'), tensor(0.1696, device='cuda:0'), tensor(0.1930, device='cuda:0'), tensor(0.2273, device='cuda:0'), tensor(0.2438, device='cuda:0'), tensor(0.2542, device='cuda:0'), tensor(0.2818, device='cuda:0'), tensor(0.3012, device='cuda:0'), tensor(0.3105, device='cuda:0'), tensor(0.3228, device='cuda:0'), tensor(0.3286, device='cuda:0'), tensor(0.3470, device='cuda:0'), tensor(0.3574, device='cuda:0'), tensor(0.3668, device='cuda:0'), tensor(0.3786, device='cuda:0'), tensor(0.3768, device='cuda:0'), tensor(0.3933, device='cuda:0'), tensor(0.3984, device='cuda:0'), tensor(0.4163, device='cuda:0'), tensor(0.4280, device='cuda:0'), tensor(0.4336, device='cuda:0'), tensor(0.4365, device='cuda:0'), tensor(0.4423, device='cuda:0'), tensor(0.4604, device='cuda:0'), tensor(0.4636, device='cuda:0'), tensor(0.4751, device='cuda:0'), tensor(0.4775, device='cuda:0'), tensor(0.4845, device='cuda:0'), tensor(0.4902, device='cuda:0'), tensor(0.4997, device='cuda:0'), tensor(0.5070, device='cuda:0'), tensor(0.5121, device='cuda:0'), tensor(0.5186, device='cuda:0'), tensor(0.5332, device='cuda:0'), tensor(0.5386, device='cuda:0'), tensor(0.5410, device='cuda:0'), tensor(0.5501, device='cuda:0'), tensor(0.5535, device='cuda:0'), tensor(0.5658, device='cuda:0'), tensor(0.5715, device='cuda:0'), tensor(0.5854, device='cuda:0'), tensor(0.5874, device='cuda:0'), tensor(0.6007, device='cuda:0'), tensor(0.6083, device='cuda:0'), tensor(0.6116, device='cuda:0'), tensor(0.6174, device='cuda:0'), tensor(0.6207, device='cuda:0'), tensor(0.6239, device='cuda:0'), tensor(0.6 ...

# %%
train_values = loaded_results['train_loss']
val_values = loaded_results['val_loss']
print(len(train_values))
print(len(val_values))
# Out:
# 100
# 100

# %%
epochs = range(1, 101)
print(len(epochs))
# Plot and label the training and validation loss values
plt.plot(epochs, train_values, label='Training Loss')
plt.plot(epochs, val_values, label='Validation Loss')
 
# Add in a title and axes labels
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
 
# Set the tick locations
plt.xticks(np.arange(0, 101, 10))
 
# Display the plot
plt.legend(loc='best')
plt.show()
# Out:
# 100

# %%
train_acc_values = torch.stack(loaded_results['train_acc']).tolist()
val_acc_values = torch.stack(loaded_results['val_acc']).tolist()
print(len(train_acc_values))
print(len(val_acc_values))
# Out:
# 100
# 100

# %%
epochs = range(1, 101)
print(len(epochs))
# Plot and label the training and validation loss values
plt.plot(epochs, train_acc_values, label='Training Accuracy')
plt.plot(epochs, val_acc_values, label='Validation Accuracy')
 
# Add in a title and axes labels
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
 
# Set the tick locations
plt.xticks(np.arange(0, 101, 10))
 
# Display the plot
plt.legend(loc='best')
plt.show()
# Out:
# 100
