# %%
import os
import random
import torch
import numpy as np
import pickle as pkl
from analysis import *
import argparse
from sys import platform
# %load_ext autoreload
# %autoreload 2

# %%
torch.manual_seed(12)
torch.cuda.manual_seed(12)
np.random.seed(12)
torch.backends.cudnn.deterministics = True
torch.set_num_threads(1)

# %%
import sys
import os
import random
import math
import time
import torch; torch.utils.backcompat.broadcast_warning.enabled = True
from torchvision import transforms, datasets
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim
import torch.backends.cudnn as cudnn; cudnn.benchmark = True
import numpy as np

# %%
import sys
import os
import random
import math
import time
import torch; torch.utils.backcompat.broadcast_warning.enabled = True
from torch.utils.data import DataLoader
from torchvision import transforms, datasets
import torch.nn as nn
import torch.nn.functional as F
import torch.optim
import torch.backends.cudnn as cudnn; cudnn.benchmark = True
from scipy.fftpack import fft, rfft, fftfreq, irfft, ifft, rfftfreq
from scipy import signal
import numpy as np
import importlib

# %%
class Model(nn.Module):

    def __init__(self, input_size=128, lstm_size=128, lstm_layers=1, output_size=128):
        # Call parent
        super().__init__()
        # Define parameters
        self.input_size = input_size
        self.lstm_size = lstm_size
        self.lstm_layers = lstm_layers
        self.output_size = output_size

        # Define internal modules
        self.lstm = nn.LSTM(input_size, lstm_size, num_layers=lstm_layers, batch_first=True)
        self.output = nn.Linear(lstm_size, output_size)
        self.classifier = nn.Linear(output_size,40)
        
    def forward(self, x):
        # Prepare LSTM initiale state
        batch_size = x.size(0)
        lstm_init = (torch.zeros(self.lstm_layers, batch_size, self.lstm_size), torch.zeros(self.lstm_layers, batch_size, self.lstm_size))
        if x.is_cuda: lstm_init = (lstm_init[0].cuda(), lstm_init[0].cuda())
        lstm_init = (Variable(lstm_init[0], volatile=x.volatile), Variable(lstm_init[1], volatile=x.volatile))

        # Forward LSTM and get final state
        x = self.lstm(x, lstm_init)[0][:,-1,:]
        
        # Forward output
        x = F.relu(self.output(x))
        x = self.classifier((x))
        return x

# %%
# Define options
import argparse
parser = argparse.ArgumentParser(description="Template")
# Dataset options

#Data - Data needs to be pre-filtered and filtered data is available

### BLOCK DESIGN ###
#Data
#parser.add_argument('-ed', '--eeg-dataset', default=r"data\block\eeg_55_95_std.pth", help="EEG dataset path") #55-95Hz
parser.add_argument('-ed', '--eeg-dataset', default=r"/media/mountHDD1/LanxHuyen/CVPR2017/eeg_5_95_std.pth", help="EEG dataset path") #5-95Hz
#parser.add_argument('-ed', '--eeg-dataset', default=r"data\block\eeg_14_70_std.pth", help="EEG dataset path") #14-70Hz
#Splits
parser.add_argument('-sp', '--splits-path', default=r"/media/mountHDD1/LanxHuyen/CVPR2017/block_splits_by_image_all.pth", help="splits path") #All subjects
#parser.add_argument('-sp', '--splits-path', default=r"data\block\block_splits_by_image_single.pth", help="splits path") #Single subject
### BLOCK DESIGN ###

parser.add_argument('-sn', '--split-num', default=0, type=int, help="split number") #leave this always to zero.

#Subject selecting
parser.add_argument('-sub','--subject', default=0   , type=int, help="choose a subject from 1 to 6, default is 0 (all subjects)")

#Time options: select from 20 to 460 samples from EEG data
parser.add_argument('-tl', '--time_low', default=20, type=float, help="lowest time value")
parser.add_argument('-th', '--time_high', default=460,  type=float, help="highest time value")

# Model type/options
parser.add_argument('-mt','--model_type', default='lstm', help='specify which generator should be used: lstm|EEGChannelNet')
# It is possible to test out multiple deep classifiers:
# - lstm is the model described in the paper "Deep Learning Human Mind for Automated Visual Classification”, in CVPR 2017
# - model10 is the model described in the paper "Decoding brain representations by multimodal learning of neural activity and visual features", TPAMI 2020
parser.add_argument('-mp','--model_params', default='', nargs='*', help='list of key=value pairs of model options')
parser.add_argument('--pretrained_net', default='', help="path to pre-trained net (to continue training)")

# Training options
parser.add_argument("-b", "--batch_size", default=16, type=int, help="batch size")
parser.add_argument('-o', '--optim', default="Adam", help="optimizer")
parser.add_argument('-lr', '--learning-rate', default=0.001, type=float, help="learning rate")
parser.add_argument('-lrdb', '--learning-rate-decay-by', default=0.5, type=float, help="learning rate decay factor")
parser.add_argument('-lrde', '--learning-rate-decay-every', default=10, type=int, help="learning rate decay period")
parser.add_argument('-dw', '--data-workers', default=4, type=int, help="data loading workers")
parser.add_argument('-e', '--epochs', default=200, type=int, help="training epochs")

# Save options
parser.add_argument('-sc', '--saveCheck', default=100, type=int, help="learning rate")

# Backend options
parser.add_argument('--no-cuda', default=False, help="disable CUDA", action="store_true")

# Parse arguments
opt, unknown = parser.parse_known_args()
print(opt)
# Out:
# Namespace(eeg_dataset='/media/mountHDD1/LanxHuyen/CVPR2017/eeg_5_95_std.pth', splits_path='/media/mountHDD1/LanxHuyen/CVPR2017/block_splits_by_image_all.pth', split_num=0, subject=0, time_low=20, time_high=460, model_type='lstm', model_params='', pretrained_net='', batch_size=16, optim='Adam', learning_rate=0.001, learning_rate_decay_by=0.5, learning_rate_decay_every=10, data_workers=4, epochs=200, saveCheck=100, no_cuda=False)

# %%
# Dataset class
class EEGDataset:
    
    # Constructor
    def __init__(self, eeg_signals_path):
        # Load EEG signals
        loaded = torch.load(eeg_signals_path)
        if opt.subject!=0:
            self.data = [loaded['dataset'][i] for i in range(len(loaded['dataset']) ) if loaded['dataset'][i]['subject']==opt.subject]
        else:
            self.data=loaded['dataset']        
        self.labels = loaded["labels"]
        self.images = loaded["images"]
        
        # Compute size
        self.size = len(self.data)

    # Get size
    def __len__(self):
        return self.size

    # Get item
    def __getitem__(self, i):
        # Process EEG
        eeg = self.data[i]["eeg"].float().t()
        eeg = eeg[opt.time_low:opt.time_high,:]

        if opt.model_type == "model10":
            eeg = eeg.t()
            eeg = eeg.view(1,128,opt.time_high-opt.time_low)
        # Get label
        label = self.data[i]["label"]
        # Return
        return eeg, label

# Splitter class
class Splitter:

    def __init__(self, dataset, split_path, split_num=0, split_name="train"):
        # Set EEG dataset
        self.dataset = dataset
        # Load split
        loaded = torch.load(split_path)
        self.split_idx = loaded["splits"][split_num][split_name]
        # Filter data
        self.split_idx = [i for i in self.split_idx if 450 <= self.dataset.data[i]["eeg"].size(1) <= 600]
        # Compute size
        self.size = len(self.split_idx)

    # Get size
    def __len__(self):
        return self.size

    # Get item
    def __getitem__(self, i):
        # Get sample from dataset
        eeg, label = self.dataset[self.split_idx[i]]
        # Return
        return eeg, label

# %%
# Load dataset
dataset = EEGDataset(opt.eeg_dataset)
# Create loaders
loaders = {split: DataLoader(Splitter(dataset, split_path = opt.splits_path, split_num = opt.split_num, split_name = split), batch_size = opt.batch_size, drop_last = True, shuffle = True) for split in ["train", "val", "test"]}

# %%
# Load model

model_options = {key: int(value) if value.isdigit() else (float(value) if value[0].isdigit() else value) for (key, value) in [x.split("=") for x in opt.model_params]}
# Create discriminator model/optimizer
# module = importlib.import_module(Model() + opt.model_type)
model = Model(**model_options)
optimizer = getattr(torch.optim, opt.optim)(model.parameters(), lr = opt.learning_rate)

# %%
# Setup CUDA
if not opt.no_cuda:
    model.cuda()
    print("Copied to CUDA")

if opt.pretrained_net != '':
        model = torch.load(opt.pretrained_net)
        print(model)
# Out:
# Copied to CUDA

# %%
#initialize training,validation, test losses and accuracy list
losses_per_epoch={"train":[], "val":[],"test":[]}
accuracies_per_epoch={"train":[],"val":[],"test":[]}

best_accuracy = 0
best_accuracy_val = 0
best_epoch = 0

# %%
for epoch in range(1, opt.epochs+1):
    # Initialize loss/accuracy variables
    losses = {"train": 0, "val": 0, "test": 0}
    accuracies = {"train": 0, "val": 0, "test": 0}
    counts = {"train": 0, "val": 0, "test": 0}
    # Adjust learning rate for SGD
    if opt.optim == "SGD":
        lr = opt.learning_rate * (opt.learning_rate_decay_by ** (epoch // opt.learning_rate_decay_every))
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
    # Process each split
    for split in ("train", "val", "test"):
        # Set network mode
        if split == "train":
            model.train()
            torch.set_grad_enabled(True)
        else:
            model.eval()
            torch.set_grad_enabled(False)
        # Process all split batches
        for i, (input, target) in enumerate(loaders[split]):
            # Check CUDA
            if not opt.no_cuda:
                input = input.to("cuda") 
                target = target.to("cuda") 
            # Forward
            output = model(input)

            # Compute loss
            loss = F.cross_entropy(output, target)
            losses[split] += loss.item()
            # Compute accuracy
            _,pred = output.data.max(1)
            correct = pred.eq(target.data).sum().item()
            accuracy = correct/input.data.size(0)   
            accuracies[split] += accuracy
            counts[split] += 1
            # Backward and optimize
            if split == "train":
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
    
    # Print info at the end of the epoch
    if accuracies["val"]/counts["val"] >= best_accuracy_val:
        best_accuracy_val = accuracies["val"]/counts["val"]
        best_accuracy = accuracies["test"]/counts["test"]
        best_epoch = epoch
    
    TrL,TrA,VL,VA,TeL,TeA=  losses["train"]/counts["train"],accuracies["train"]/counts["train"],losses["val"]/counts["val"],accuracies["val"]/counts["val"],losses["test"]/counts["test"],accuracies["test"]/counts["test"]
    print("Model: {11} - Subject {12} - Time interval: [{9}-{10}]  [{9}-{10} Hz] - Epoch {0}: TrL={1:.4f}, TrA={2:.4f}, VL={3:.4f}, VA={4:.4f}, TeL={5:.4f}, TeA={6:.4f}, TeA at max VA = {7:.4f} at epoch {8:d}".format(epoch,
                                                                                                         losses["train"]/counts["train"],
                                                                                                         accuracies["train"]/counts["train"],
                                                                                                         losses["val"]/counts["val"],
                                                                                                         accuracies["val"]/counts["val"],
                                                                                                         losses["test"]/counts["test"],
                                                                                                         accuracies["test"]/counts["test"],
                                                                                                         best_accuracy, best_epoch, opt.time_low,opt.time_high, opt.model_type,opt.subject))

    losses_per_epoch['train'].append(TrL)
    losses_per_epoch['val'].append(VL)
    losses_per_epoch['test'].append(TeL)
    accuracies_per_epoch['train'].append(TrA)
    accuracies_per_epoch['val'].append(VA)
    accuracies_per_epoch['test'].append(TeA)

    if epoch%opt.saveCheck == 0:
                torch.save(model, '%s__subject%d_epoch_%d.pth' % (opt.model_type, opt.subject,epoch))
# Out:
# /tmp/ipykernel_47743/3429136109.py:22: UserWarning: volatile was removed (Variable.volatile is always False)
#   lstm_init = (Variable(lstm_init[0], volatile=x.volatile), Variable(lstm_init[1], volatile=x.volatile))
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 1: TrL=3.6423, TrA=0.0389, VL=3.5429, VA=0.0393, TeL=3.5627, TeA=0.0413, TeA at max VA = 0.0413 at epoch 1
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 2: TrL=3.3629, TrA=0.0638, VL=3.2920, VA=0.0635, TeL=3.3130, TeA=0.0685, TeA at max VA = 0.0685 at epoch 2
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 3: TrL=3.2217, TrA=0.0869, VL=3.1831, VA=0.0781, TeL=3.1850, TeA=0.0811, TeA at max VA = 0.0811 at epoch 3
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 4: TrL=3.0164, TrA=0.1132, VL=3.7909, VA=0.0610, TeL=3.7777, TeA=0.0640, TeA at max VA = 0.0811 at epoch 3
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 5: TrL=2.9806, TrA=0.1246, VL=2.9468, VA=0.1114, TeL=2.9754, TeA=0.1023, TeA at max VA = 0.1023 at epoch 5
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 6: TrL=2.7351, TrA=0.1514, VL=3.0547, VA=0.0902, TeL=3.0468, TeA=0.0988, TeA at max VA = 0.1023 at epoch 5
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 7: TrL=2.5786, TrA=0.1850, VL=2.8116, VA=0.1184, TeL=2.8438, TeA=0.1169, TeA at max VA = 0.1169 at epoch 7
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 8: TrL=2.4570, TrA=0.2176, VL=2.8817, VA=0.1200, TeL=2.8975, TeA=0.1245, TeA at max VA = 0.1245 at epoch 8
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 9: TrL=2.3243, TrA=0.2525, VL=2.8089, VA=0.1310, TeL=2.8431, TeA=0.1351, TeA at max VA = 0.1351 at epoch 9
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 10: TrL=2.2112, TrA=0.2885, VL=2.8380, VA=0.1255, TeL=2.8632, TeA=0.1482, TeA at max VA = 0.1351 at epoch 9
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 11: TrL=2.0701, TrA=0.3222, VL=2.8737, VA=0.1426, TeL=2.8894, TeA=0.1260, TeA at max VA = 0.1260 at epoch 11
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 12: TrL=1.9633, TrA=0.3584, VL=2.9079, VA=0.1331, TeL=2.9911, TeA=0.1381, TeA at max VA = 0.1260 at epoch 11
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 13: TrL=1.8388, TrA=0.3984, VL=2.9606, VA=0.1376, TeL=3.0347, TeA=0.1331, TeA at max VA = 0.1260 at epoch 11
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 14: TrL=1.7168, TrA=0.4308, VL=2.9375, VA=0.1557, TeL=2.9970, TeA=0.1462, TeA at max VA = 0.1462 at epoch 14
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 15: TrL=1.6051, TrA=0.4674, VL=3.1469, VA=0.1305, TeL=3.2264, TeA=0.1316, TeA at max VA = 0.1462 at epoch 14
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 16: TrL=1.5092, TrA=0.5058, VL=3.1102, VA=0.1396, TeL=3.1539, TeA=0.1578, TeA at max VA = 0.1462 at epoch 14
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 17: TrL=1.3645, TrA=0.5502, VL=3.1914, VA=0.1512, TeL=3.3458, TeA=0.1411, TeA at max VA = 0.1462 at epoch 14
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 18: TrL=1.2794, TrA=0.5840, VL=3.4132, VA=0.1356, TeL=3.5096, TeA=0.1527, TeA at max VA = 0.1462 at epoch 14
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 19: TrL=1.1744, TrA=0.6178, VL=3.4314, VA=0.1663, TeL=3.5462, TeA=0.1452, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 20: TrL=1.0671, TrA=0.6542, VL=3.5370, VA=0.1462, TeL=3.6249, TeA=0.1442, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 21: TrL=0.9725, TrA=0.6905, VL=3.6091, VA=0.1658, TeL=3.7343, TeA=0.1472, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 22: TrL=0.9222, TrA=0.7046, VL=3.8046, VA=0.1562, TeL=3.9564, TeA=0.1411, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 23: TrL=0.8411, TrA=0.7355, VL=4.0473, VA=0.1431, TeL=4.1403, TeA=0.1280, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 24: TrL=0.7397, TrA=0.7686, VL=4.0267, VA=0.1507, TeL=4.1590, TeA=0.1517, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 25: TrL=0.6724, TrA=0.7959, VL=4.3128, VA=0.1406, TeL=4.5049, TeA=0.1472, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 26: TrL=0.6161, TrA=0.8072, VL=4.5832, VA=0.1406, TeL=4.7056, TeA=0.1421, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 27: TrL=0.5943, TrA=0.8173, VL=4.5192, VA=0.1578, TeL=4.5931, TeA=0.1583, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 28: TrL=0.5206, TrA=0.8384, VL=4.6594, VA=0.1603, TeL=4.7993, TeA=0.1477, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 29: TrL=0.5362, TrA=0.8334, VL=4.8963, VA=0.1366, TeL=4.9647, TeA=0.1336, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 30: TrL=0.4850, TrA=0.8521, VL=4.9644, VA=0.1537, TeL=4.9789, TeA=0.1542, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 31: TrL=0.4167, TrA=0.8754, VL=5.2135, VA=0.1457, TeL=5.3465, TeA=0.1477, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 32: TrL=0.3781, TrA=0.8864, VL=5.2941, VA=0.1482, TeL=5.4735, TeA=0.1467, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 33: TrL=0.3726, TrA=0.8869, VL=5.3657, VA=0.1573, TeL=5.5395, TeA=0.1532, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 34: TrL=0.3569, TrA=0.8926, VL=5.5702, VA=0.1482, TeL=5.8141, TeA=0.1401, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 35: TrL=0.3303, TrA=0.8988, VL=5.8115, VA=0.1381, TeL=5.8802, TeA=0.1442, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 36: TrL=0.2943, TrA=0.9135, VL=5.8375, VA=0.1517, TeL=6.0959, TeA=0.1290, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 37: TrL=0.3472, TrA=0.8973, VL=5.9929, VA=0.1502, TeL=6.0087, TeA=0.1442, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 38: TrL=0.3050, TrA=0.9058, VL=6.0734, VA=0.1356, TeL=6.2519, TeA=0.1487, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 39: TrL=0.2881, TrA=0.9132, VL=6.1356, VA=0.1537, TeL=6.2780, TeA=0.1452, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 40: TrL=0.2179, TrA=0.9394, VL=6.3158, VA=0.1386, TeL=6.3233, TeA=0.1517, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 41: TrL=0.2683, TrA=0.9242, VL=6.3541, VA=0.1447, TeL=6.4089, TeA=0.1492, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 42: TrL=0.2491, TrA=0.9258, VL=6.3977, VA=0.1411, TeL=6.4910, TeA=0.1361, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 43: TrL=0.2730, TrA=0.9184, VL=6.4779, VA=0.1346, TeL=6.7228, TeA=0.1326, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 44: TrL=0.2723, TrA=0.9209, VL=6.5929, VA=0.1452, TeL=6.5752, TeA=0.1502, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 45: TrL=0.1284, TrA=0.9674, VL=6.7520, VA=0.1487, TeL=6.7002, TeA=0.1568, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 46: TrL=0.2700, TrA=0.9251, VL=6.8113, VA=0.1376, TeL=6.9881, TeA=0.1310, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 47: TrL=0.2630, TrA=0.9175, VL=6.6996, VA=0.1457, TeL=6.8857, TeA=0.1452, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 48: TrL=0.1993, TrA=0.9425, VL=6.9295, VA=0.1416, TeL=7.0168, TeA=0.1316, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 49: TrL=0.1535, TrA=0.9584, VL=6.9140, VA=0.1436, TeL=7.0561, TeA=0.1436, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 50: TrL=0.1520, TrA=0.9604, VL=7.1537, VA=0.1447, TeL=7.2634, TeA=0.1431, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 51: TrL=0.2618, TrA=0.9186, VL=7.1430, VA=0.1386, TeL=7.2548, TeA=0.1391, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 52: TrL=0.2389, TrA=0.9247, VL=7.2596, VA=0.1331, TeL=7.3421, TeA=0.1527, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 53: TrL=0.1855, TrA=0.9487, VL=7.1964, VA=0.1346, TeL=7.4472, TeA=0.1371, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 54: TrL=0.1102, TrA=0.9708, VL=7.2970, VA=0.1462, TeL=7.4291, TeA=0.1517, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 55: TrL=0.1008, TrA=0.9728, VL=7.5971, VA=0.1351, TeL=7.6624, TeA=0.1517, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 56: TrL=0.2589, TrA=0.9234, VL=7.5065, VA=0.1406, TeL=7.6051, TeA=0.1472, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 57: TrL=0.2799, TrA=0.9156, VL=7.5279, VA=0.1326, TeL=7.6119, TeA=0.1502, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 58: TrL=0.1362, TrA=0.9604, VL=7.4722, VA=0.1341, TeL=7.5764, TeA=0.1411, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 59: TrL=0.0638, TrA=0.9860, VL=7.5066, VA=0.1396, TeL=7.6532, TeA=0.1487, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 60: TrL=0.0619, TrA=0.9855, VL=7.6255, VA=0.1431, TeL=7.7363, TeA=0.1482, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 61: TrL=0.2709, TrA=0.9251, VL=8.0445, VA=0.1230, TeL=8.1472, TeA=0.1260, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 62: TrL=0.3637, TrA=0.8866, VL=7.5546, VA=0.1381, TeL=7.7956, TeA=0.1386, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 63: TrL=0.0915, TrA=0.9757, VL=7.5438, VA=0.1477, TeL=7.7614, TeA=0.1457, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 64: TrL=0.0282, TrA=0.9962, VL=7.6278, VA=0.1431, TeL=7.7743, TeA=0.1477, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 65: TrL=0.0122, TrA=0.9996, VL=7.6215, VA=0.1406, TeL=7.8227, TeA=0.1477, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 66: TrL=0.4211, TrA=0.8828, VL=7.9155, VA=0.1396, TeL=8.1186, TeA=0.1401, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 67: TrL=0.3439, TrA=0.8946, VL=7.5445, VA=0.1391, TeL=7.8060, TeA=0.1386, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 68: TrL=0.1066, TrA=0.9711, VL=7.6334, VA=0.1467, TeL=7.8164, TeA=0.1416, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 69: TrL=0.0555, TrA=0.9888, VL=7.7796, VA=0.1376, TeL=7.9715, TeA=0.1346, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 70: TrL=0.0536, TrA=0.9891, VL=7.8487, VA=0.1401, TeL=8.0015, TeA=0.1406, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 71: TrL=0.1424, TrA=0.9586, VL=8.1618, VA=0.1260, TeL=8.3920, TeA=0.1371, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 72: TrL=0.3188, TrA=0.8989, VL=7.9842, VA=0.1406, TeL=8.1634, TeA=0.1406, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 73: TrL=0.1452, TrA=0.9576, VL=8.0848, VA=0.1341, TeL=8.1286, TeA=0.1361, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 74: TrL=0.1267, TrA=0.9634, VL=8.2797, VA=0.1310, TeL=8.3744, TeA=0.1290, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 75: TrL=0.1344, TrA=0.9611, VL=8.2366, VA=0.1230, TeL=8.3819, TeA=0.1421, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 76: TrL=0.1224, TrA=0.9630, VL=8.2347, VA=0.1290, TeL=8.3686, TeA=0.1396, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 77: TrL=0.0553, TrA=0.9850, VL=8.4552, VA=0.1310, TeL=8.4044, TeA=0.1421, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 78: TrL=0.1540, TrA=0.9591, VL=8.4141, VA=0.1295, TeL=8.6129, TeA=0.1361, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 79: TrL=0.2481, TrA=0.9267, VL=8.4739, VA=0.1255, TeL=8.5833, TeA=0.1411, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 80: TrL=0.1308, TrA=0.9586, VL=8.2367, VA=0.1341, TeL=8.3222, TeA=0.1552, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 81: TrL=0.0509, TrA=0.9882, VL=8.5288, VA=0.1305, TeL=8.4376, TeA=0.1416, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 82: TrL=0.0301, TrA=0.9932, VL=8.4218, VA=0.1416, TeL=8.5087, TeA=0.1492, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 83: TrL=0.1099, TrA=0.9674, VL=8.6718, VA=0.1300, TeL=8.8447, TeA=0.1346, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 84: TrL=0.3184, TrA=0.9035, VL=8.4793, VA=0.1310, TeL=8.6125, TeA=0.1411, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 85: TrL=0.1127, TrA=0.9660, VL=8.4903, VA=0.1341, TeL=8.6007, TeA=0.1522, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 86: TrL=0.1835, TrA=0.9481, VL=8.6057, VA=0.1285, TeL=8.6281, TeA=0.1467, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 87: TrL=0.1070, TrA=0.9677, VL=8.6728, VA=0.1305, TeL=8.7242, TeA=0.1447, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 88: TrL=0.0379, TrA=0.9911, VL=8.6710, VA=0.1331, TeL=8.7770, TeA=0.1467, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 89: TrL=0.0184, TrA=0.9967, VL=8.7294, VA=0.1310, TeL=8.8071, TeA=0.1457, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 90: TrL=0.0497, TrA=0.9870, VL=8.9148, VA=0.1316, TeL=9.1286, TeA=0.1295, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 91: TrL=0.4644, TrA=0.8631, VL=8.9030, VA=0.1250, TeL=8.8666, TeA=0.1275, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 92: TrL=0.1539, TrA=0.9521, VL=8.5586, VA=0.1310, TeL=8.7896, TeA=0.1462, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 93: TrL=0.0559, TrA=0.9848, VL=8.6082, VA=0.1265, TeL=8.8111, TeA=0.1487, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 94: TrL=0.0284, TrA=0.9947, VL=8.6509, VA=0.1351, TeL=8.7879, TeA=0.1452, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 95: TrL=0.0114, TrA=0.9987, VL=8.7003, VA=0.1310, TeL=8.8821, TeA=0.1502, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 96: TrL=0.0085, TrA=0.9989, VL=8.7720, VA=0.1295, TeL=8.8988, TeA=0.1487, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 97: TrL=0.4235, TrA=0.8916, VL=8.8979, VA=0.1295, TeL=9.0343, TeA=0.1290, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 98: TrL=0.2866, TrA=0.9111, VL=8.5836, VA=0.1396, TeL=8.8246, TeA=0.1341, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 99: TrL=0.1037, TrA=0.9696, VL=8.7928, VA=0.1391, TeL=8.8575, TeA=0.1381, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 100: TrL=0.0403, TrA=0.9887, VL=8.6207, VA=0.1401, TeL=8.8049, TeA=0.1411, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 101: TrL=0.0185, TrA=0.9969, VL=8.6457, VA=0.1351, TeL=8.8264, TeA=0.1426, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 102: TrL=0.0136, TrA=0.9977, VL=8.5676, VA=0.1447, TeL=8.9416, TeA=0.1376, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 103: TrL=0.0202, TrA=0.9956, VL=8.8868, VA=0.1295, TeL=9.2586, TeA=0.1351, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 104: TrL=0.4414, TrA=0.8799, VL=8.8250, VA=0.1250, TeL=8.8188, TeA=0.1436, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 105: TrL=0.2734, TrA=0.9155, VL=8.6246, VA=0.1316, TeL=8.7581, TeA=0.1452, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 106: TrL=0.0869, TrA=0.9745, VL=8.6148, VA=0.1326, TeL=8.7892, TeA=0.1431, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 107: TrL=0.0416, TrA=0.9909, VL=8.7353, VA=0.1351, TeL=8.8509, TeA=0.1431, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 108: TrL=0.0119, TrA=0.9984, VL=8.7129, VA=0.1361, TeL=8.8813, TeA=0.1477, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 109: TrL=0.0038, TrA=1.0000, VL=8.7517, VA=0.1401, TeL=8.9209, TeA=0.1467, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 110: TrL=0.0024, TrA=1.0000, VL=8.7910, VA=0.1386, TeL=8.9526, TeA=0.1472, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 111: TrL=0.0019, TrA=1.0000, VL=8.8549, VA=0.1396, TeL=9.0024, TeA=0.1467, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 112: TrL=0.0016, TrA=1.0000, VL=8.9176, VA=0.1401, TeL=9.0414, TeA=0.1472, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 113: TrL=0.0013, TrA=1.0000, VL=8.9562, VA=0.1391, TeL=9.1123, TeA=0.1477, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 114: TrL=0.0011, TrA=1.0000, VL=9.0310, VA=0.1386, TeL=9.1703, TeA=0.1487, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 115: TrL=0.0009, TrA=1.0000, VL=9.1060, VA=0.1401, TeL=9.2373, TeA=0.1497, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 116: TrL=0.0008, TrA=1.0000, VL=9.1920, VA=0.1396, TeL=9.3121, TeA=0.1527, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 117: TrL=0.0007, TrA=1.0000, VL=9.2739, VA=0.1381, TeL=9.3936, TeA=0.1532, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 118: TrL=0.0005, TrA=1.0000, VL=9.3418, VA=0.1426, TeL=9.4855, TeA=0.1557, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 119: TrL=0.0005, TrA=1.0000, VL=9.4413, VA=0.1406, TeL=9.5813, TeA=0.1568, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 120: TrL=0.0004, TrA=1.0000, VL=9.5544, VA=0.1426, TeL=9.6952, TeA=0.1568, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 121: TrL=0.0003, TrA=1.0000, VL=9.6328, VA=0.1426, TeL=9.8047, TeA=0.1573, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 122: TrL=0.0002, TrA=1.0000, VL=9.7731, VA=0.1457, TeL=9.9250, TeA=0.1562, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 123: TrL=0.0002, TrA=1.0000, VL=9.9128, VA=0.1447, TeL=10.0420, TeA=0.1562, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 124: TrL=0.0002, TrA=1.0000, VL=10.0382, VA=0.1426, TeL=10.1801, TeA=0.1568, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 125: TrL=0.0001, TrA=1.0000, VL=10.1210, VA=0.1452, TeL=10.3042, TeA=0.1542, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 126: TrL=0.0001, TrA=1.0000, VL=10.2745, VA=0.1436, TeL=10.4580, TeA=0.1542, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 127: TrL=0.0001, TrA=1.0000, VL=10.4185, VA=0.1442, TeL=10.5801, TeA=0.1573, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 128: TrL=0.0001, TrA=1.0000, VL=10.5779, VA=0.1426, TeL=10.7600, TeA=0.1588, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 129: TrL=0.3842, TrA=0.9469, VL=12.1294, VA=0.1003, TeL=12.4462, TeA=0.1013, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 130: TrL=1.7796, TrA=0.6354, VL=9.1043, VA=0.1331, TeL=9.2181, TeA=0.1255, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 131: TrL=0.2561, TrA=0.9189, VL=8.9139, VA=0.1396, TeL=8.8440, TeA=0.1421, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 132: TrL=0.0667, TrA=0.9828, VL=8.9216, VA=0.1381, TeL=8.9588, TeA=0.1467, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 133: TrL=0.0275, TrA=0.9957, VL=8.9554, VA=0.1351, TeL=8.9678, TeA=0.1421, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 134: TrL=0.0264, TrA=0.9946, VL=9.0679, VA=0.1381, TeL=9.0697, TeA=0.1386, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 135: TrL=0.0597, TrA=0.9842, VL=9.2569, VA=0.1381, TeL=9.2399, TeA=0.1326, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 136: TrL=0.1925, TrA=0.9467, VL=9.4550, VA=0.1305, TeL=9.5905, TeA=0.1421, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 137: TrL=0.2985, TrA=0.9097, VL=9.2349, VA=0.1341, TeL=9.3331, TeA=0.1492, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 138: TrL=0.1134, TrA=0.9654, VL=9.2167, VA=0.1366, TeL=9.3263, TeA=0.1371, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 139: TrL=0.0430, TrA=0.9883, VL=9.2689, VA=0.1305, TeL=9.3169, TeA=0.1442, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 140: TrL=0.0698, TrA=0.9808, VL=9.4360, VA=0.1316, TeL=9.5427, TeA=0.1426, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 141: TrL=0.1438, TrA=0.9588, VL=9.3301, VA=0.1391, TeL=9.4813, TeA=0.1452, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 142: TrL=0.1664, TrA=0.9481, VL=9.5081, VA=0.1265, TeL=9.6935, TeA=0.1310, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 143: TrL=0.1258, TrA=0.9613, VL=9.4002, VA=0.1310, TeL=9.4627, TeA=0.1361, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 144: TrL=0.0774, TrA=0.9750, VL=9.4695, VA=0.1290, TeL=9.6408, TeA=0.1381, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 145: TrL=0.0566, TrA=0.9843, VL=9.5877, VA=0.1200, TeL=9.7034, TeA=0.1326, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 146: TrL=0.1253, TrA=0.9665, VL=9.7740, VA=0.1321, TeL=9.6870, TeA=0.1341, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 147: TrL=0.0985, TrA=0.9718, VL=9.4924, VA=0.1285, TeL=9.7284, TeA=0.1381, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 148: TrL=0.1071, TrA=0.9649, VL=9.6425, VA=0.1270, TeL=9.6636, TeA=0.1326, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 149: TrL=0.1169, TrA=0.9650, VL=9.7213, VA=0.1270, TeL=9.8718, TeA=0.1305, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 150: TrL=0.1110, TrA=0.9659, VL=9.5986, VA=0.1341, TeL=9.7308, TeA=0.1391, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 151: TrL=0.0764, TrA=0.9771, VL=9.5501, VA=0.1341, TeL=9.7066, TeA=0.1295, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 152: TrL=0.1307, TrA=0.9645, VL=9.8490, VA=0.1235, TeL=10.0439, TeA=0.1351, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 153: TrL=0.0949, TrA=0.9694, VL=9.8686, VA=0.1240, TeL=9.9592, TeA=0.1411, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 154: TrL=0.1458, TrA=0.9589, VL=9.9006, VA=0.1336, TeL=9.8042, TeA=0.1391, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 155: TrL=0.1127, TrA=0.9652, VL=9.8277, VA=0.1361, TeL=9.8429, TeA=0.1356, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 156: TrL=0.0814, TrA=0.9759, VL=9.8477, VA=0.1371, TeL=9.7539, TeA=0.1376, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 157: TrL=0.0732, TrA=0.9785, VL=10.0343, VA=0.1285, TeL=10.1061, TeA=0.1351, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 158: TrL=0.0556, TrA=0.9828, VL=9.9756, VA=0.1174, TeL=10.1022, TeA=0.1326, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 159: TrL=0.0714, TrA=0.9810, VL=10.1645, VA=0.1351, TeL=10.1052, TeA=0.1285, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 160: TrL=0.1773, TrA=0.9499, VL=10.3296, VA=0.1230, TeL=10.2376, TeA=0.1275, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 161: TrL=0.1820, TrA=0.9472, VL=10.1578, VA=0.1346, TeL=10.2393, TeA=0.1275, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 162: TrL=0.0983, TrA=0.9694, VL=9.7875, VA=0.1336, TeL=9.9082, TeA=0.1356, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 163: TrL=0.0268, TrA=0.9920, VL=9.8834, VA=0.1321, TeL=9.9996, TeA=0.1356, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 164: TrL=0.0144, TrA=0.9972, VL=9.9892, VA=0.1265, TeL=10.1199, TeA=0.1401, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 165: TrL=0.0328, TrA=0.9925, VL=10.4843, VA=0.1210, TeL=10.4277, TeA=0.1310, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 166: TrL=0.2479, TrA=0.9283, VL=10.0756, VA=0.1225, TeL=10.2475, TeA=0.1305, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 167: TrL=0.2225, TrA=0.9307, VL=9.6955, VA=0.1305, TeL=9.8925, TeA=0.1351, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 168: TrL=0.0479, TrA=0.9858, VL=9.7731, VA=0.1285, TeL=9.8989, TeA=0.1366, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 169: TrL=0.0293, TrA=0.9928, VL=9.7513, VA=0.1366, TeL=9.9831, TeA=0.1507, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 170: TrL=0.0173, TrA=0.9960, VL=9.9876, VA=0.1341, TeL=9.9276, TeA=0.1411, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 171: TrL=0.0066, TrA=0.9990, VL=10.0039, VA=0.1285, TeL=10.0738, TeA=0.1341, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 172: TrL=0.2385, TrA=0.9345, VL=10.0876, VA=0.1225, TeL=9.9756, TeA=0.1351, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 173: TrL=0.2783, TrA=0.9210, VL=10.0466, VA=0.1270, TeL=10.2245, TeA=0.1336, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 174: TrL=0.0954, TrA=0.9710, VL=9.8421, VA=0.1305, TeL=10.1471, TeA=0.1346, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 175: TrL=0.0371, TrA=0.9907, VL=9.9758, VA=0.1230, TeL=10.2365, TeA=0.1310, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 176: TrL=0.0755, TrA=0.9806, VL=10.2062, VA=0.1149, TeL=10.1640, TeA=0.1371, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 177: TrL=0.0424, TrA=0.9876, VL=10.2918, VA=0.1250, TeL=10.1971, TeA=0.1492, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 178: TrL=0.0244, TrA=0.9935, VL=10.2766, VA=0.1250, TeL=10.2709, TeA=0.1457, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 179: TrL=0.0575, TrA=0.9837, VL=10.3393, VA=0.1159, TeL=10.4068, TeA=0.1336, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 180: TrL=0.2626, TrA=0.9272, VL=10.2956, VA=0.1179, TeL=10.3663, TeA=0.1386, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 181: TrL=0.1789, TrA=0.9459, VL=10.0086, VA=0.1300, TeL=10.0932, TeA=0.1381, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 182: TrL=0.0727, TrA=0.9775, VL=10.1535, VA=0.1290, TeL=10.3648, TeA=0.1356, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 183: TrL=0.0389, TrA=0.9899, VL=10.1734, VA=0.1326, TeL=10.3631, TeA=0.1336, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 184: TrL=0.0344, TrA=0.9916, VL=10.2079, VA=0.1250, TeL=10.2568, TeA=0.1391, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 185: TrL=0.1172, TrA=0.9660, VL=10.4261, VA=0.1265, TeL=10.5640, TeA=0.1255, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 186: TrL=0.1866, TrA=0.9428, VL=10.2426, VA=0.1200, TeL=10.3379, TeA=0.1361, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 187: TrL=0.0673, TrA=0.9794, VL=10.2413, VA=0.1285, TeL=10.2222, TeA=0.1452, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 188: TrL=0.0650, TrA=0.9795, VL=10.3894, VA=0.1235, TeL=10.3763, TeA=0.1416, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 189: TrL=0.0486, TrA=0.9855, VL=10.3924, VA=0.1169, TeL=10.3910, TeA=0.1371, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 190: TrL=0.0449, TrA=0.9865, VL=10.5157, VA=0.1250, TeL=10.4268, TeA=0.1421, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 191: TrL=0.1542, TrA=0.9533, VL=10.6903, VA=0.1280, TeL=10.4538, TeA=0.1376, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 192: TrL=0.1348, TrA=0.9581, VL=10.4764, VA=0.1240, TeL=10.4712, TeA=0.1235, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 193: TrL=0.0934, TrA=0.9708, VL=10.4412, VA=0.1205, TeL=10.4215, TeA=0.1316, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 194: TrL=0.0459, TrA=0.9868, VL=10.4123, VA=0.1164, TeL=10.5662, TeA=0.1356, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 195: TrL=0.0444, TrA=0.9868, VL=10.6327, VA=0.1179, TeL=10.6690, TeA=0.1316, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 196: TrL=0.0279, TrA=0.9921, VL=10.6453, VA=0.1230, TeL=10.6342, TeA=0.1326, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 197: TrL=0.0405, TrA=0.9903, VL=10.9483, VA=0.1190, TeL=10.7278, TeA=0.1371, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 198: TrL=0.2675, TrA=0.9258, VL=10.9444, VA=0.1205, TeL=10.7641, TeA=0.1351, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 199: TrL=0.1339, TrA=0.9588, VL=10.6097, VA=0.1240, TeL=10.6669, TeA=0.1316, TeA at max VA = 0.1452 at epoch 19
# Model: lstm - Subject 0 - Time interval: [20-460]  [20-460 Hz] - Epoch 200: TrL=0.0676, TrA=0.9815, VL=10.6066, VA=0.1295, TeL=10.6345, TeA=0.1260, TeA at max VA = 0.1452 at epoch 19
